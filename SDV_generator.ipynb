# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd # data processing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D,Dropout,LSTM, Bidirectional
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.layers import BatchNormalization, Dropout
from keras.layers import Dense, Activation
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import torch
from torch.nn import Transformer
from sklearn.preprocessing import StandardScaler #good
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
from sklearn import metrics #accuracy measure
import joblib
import warnings
import sdv

# %%
def second_turn(label,dif):
    if label>0:
        return 0
    if label==0:
        return dif
def fturn(df):
    if list(df['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0
def fturn_test():
    if list(df['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0

training_set=os.listdir("./training_set_df_acc_windowsize3_with_pre_feat3s/")
# training_set=['./gan_win6.csv','./gan_win6.csv']
df=None
for data in training_set:
    if data.endswith('.csv'):
        file=f"./training_set_df_acc_windowsize3_with_pre_feat3s/{data}"
        if df is None:
            df=pd.read_csv(file)
            df=df.astype(float)
            print(df.shape)
            df['previous_label']=df['label']
            
            df['label']=df['label'].astype("category")
            df['previous_label']=df['label']
            df['previous_label']=df['previous_label'].astype(int)
            df['second_turn']=df['previous_label'].diff()
            df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
            turn=list(df['second_turn'])
            turn_2=[]
            
            if (df['label'][0].item()>0): 
                count=2
            else: 
                count=1
            for i in range(len(turn)):

                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            df['turn']=turn
            df['second_turn']=turn_2
            after1=[]
            
# print(list(df['label'])[0])

            after0=fturn(df)
            sturn=True
            for i in range(len(df.label)):

                if (list(df['label'])[i]==1)|(list(df['label'])[i]==2)|(list(df['label'])[i]==3):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(df)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after1.append(1) 
                else:
                    after1.append(0) 
            df['after1']=after1
            after4=[]
            after0=fturn(df)
            sturn=True
            for i in range(len(df['label'])):
                if (list(df['label'])[i]==4)|(list(df['label'])[i]==5)|(list(df['label'])[i]==6):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(df)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after4.append(1) 
                else:
                    after4.append(0) 

            df['after4']=after4
            df=df.reset_index().rename(columns={df.index.name:'time'})
        else:
            d=pd.read_csv(file)
            d['previous_label']=d['label']
            d['previous_label']=d['previous_label'].astype(int)
            d['label']=d['label'].astype("category")
            d['second_turn']=d['previous_label'].diff()
            d['second_turn']=d.apply(lambda d:second_turn(d['label'],d['second_turn']),axis=1)
            turn=list(d['second_turn'])
            turn_2=[]
            if (d['label'][0].item()>0): 
                count=2
            else: count=1
            for i in range(len(turn)):
                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            d['second_turn']=turn_2
            d['turn']=turn
            after1=[]
            
# print(list(df['label'])[0])

            after0=fturn(d)
            sturn=True
            for i in range(len(d.label)):

                if (list(d['label'])[i]==1)|(list(d['label'])[i]==2)|(list(d['label'])[i]==3):
                    after0-=1
                if (list(d['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(d)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after1.append(1) 
                else:
                    after1.append(0) 
            d['after1']=after1
            after4=[]
            after0=fturn(d)
            sturn=True
            for i in range(len(d['label'])):
                if (list(d['label'])[i]==4)|(list(d['label'])[i]==5)|(list(d['label'])[i]==6):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(d)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after4.append(1) 
                else:
                    after4.append(0) 

            d['after4']=after4
            d=d.reset_index().rename(columns={d.index.name:'time'})
            df=pd.concat([df,d])

df=df.drop(['second_turn','turn'],axis=1)
df_train=df

print(df_train.shape)

print(df_train.isna().sum())
df_train[['after1','after4','label','previous_label']]=df_train[['after1','after4','label','previous_label']].astype(int)
# df_train=df_train.dropna(axis=0)
# Out:
# (211, 8682)
# (0, 8685)
# index                                      0
# left_elbow_shoulder_hip mean_ft            0
# left_elbow_shoulder_hip std_ft             0
# left_elbow_shoulder_hip max_ft             0
# left_elbow_shoulder_hip min_ft             0
#                                           ..
# movingcenter_y quantile75e previous 3 s    0
# previous_label                             0
# label                                      0
# after1                                     0
# after4                                     0
# Length: 8685, dtype: int64

# %%
print(df_train.isna().sum())
# Out:
# index                                      0
# left_elbow_shoulder_hip mean_ft            0
# left_elbow_shoulder_hip std_ft             0
# left_elbow_shoulder_hip max_ft             0
# left_elbow_shoulder_hip min_ft             0
#                                           ..
# movingcenter_y quantile75e previous 3 s    0
# previous_label                             0
# label                                      0
# after1                                     0
# after4                                     0
# Length: 8685, dtype: int64

# %%
# from ctgan import CTGAN
# df_train=df_train
# df_train=df_train.reset_index(drop=True)
# # print(df_train)
# gan=CTGAN(verbose=True,batch_size=1146)
# print('fit')
# gan.fit(df_train,df_train.columns, epochs=4)
# sample=gan.sample(4000)
# sample

# %%
# model.save('ctgan_model.pkl')
df_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 8685 columns):
#  #     Column                                                          Dtype
# ---    ------                                                          -----
#  0     index                                                           object
#  1     left_elbow_shoulder_hip mean_ft                                 object
#  2     left_elbow_shoulder_hip std_ft                                  object
#  3     left_elbow_shoulder_hip max_ft                                  object
#  4     left_elbow_shoulder_hip min_ft                                  object
#  5     left_elbow_shoulder_hip var_ft                                  object
#  6     left_elbow_shoulder_hip med_ft                                  object
#  7     left_elbow_shoulder_hip sum_ft                                  object
#  8     left_elbow_shoulder_hip kurtosis                                object
#  9     left_elbow_shoulder_hip skew                                    object
#  10    left_elbow_shoulder_hip quantile 25                             object
#  11    left_elbow_shoulder_hip quantile 75                             object
#  12    left_elbow_shoulder_hip RMS                                     object
#  13    left_elbow_shoulder_hip MAV                                     object
#  14    left_elbow_shoulder_hip rmse                                    object
#  15    left_elbow_shoulder_hip mae                                     object
#  16    left_elbow_shoulder_hip maxerror                                object
#  17    left_elbow_shoulder_hip minerror                                object
#  18    left_elbow_shoulder_hip stderror                                object
#  19    left_elbow_shoulder_hip quantile25e                             object
#  20    left_elbow_shoulder_hip quantile75e                             object
#  21    right_elbow_shoulder_hip mean_ft                                object
#  22    right_elbow_shoulder_hip std_ft                                 object
#  23    right_elbow_shoulder_hip max_ft                                 object
#  24    right_elbow_shoulder_hip min_ft                                 object
#  25    right_elbow_shoulder_hip var_ft                                 object
#  26    right_elbow_shoulder_hip med_ft                                 object
#  27    right_elbow_shoulder_hip sum_ft                                 object
#  28    right_elbow_shoulder_hip kurtosis                               object
#  29    right_elbow_shoulder_hip skew                                   object
#  30    right_elbow_shoulder_hip quantile 25                            object
#  31    right_elbow_shoulder_hip quantile 75                            object
#  32    right_elbow_shoulder_hip RMS                                    object
#  33    right_elbow_shoulder_hip MAV                                    object
#  34    right_elbow_shoulder_hip rmse                                   object
#  35    right_elbow_shoulder_hip mae                                    object
#  36    right_elbow_shoulder_hip maxerror                               object
#  37    right_elbow_shoulder_hip minerror                               object
#  38    right_elbow_shoulder_hip stderror                               object
#  39    right_elbow_shoulder_hip quantile25e                            object
#  40    right_elbow_shoulder_hip quantile75e                            object
#  41    left_wrist_elbow_shoulder mean_ft                               object
#  42    left_wrist_elbow_shoulder std_ft                                object
#  43    left_wrist_elbow_shoulder max_ft                                object
#  44    left_wrist_elbow_shoulder min_ft                                object
#  45    left_wrist_elbow_shoulder var_ft                                object
#  46    left_wrist_elbow_shoulder med_ft                                object
#  47    left_wrist_elbow_shoulder sum_ft                                object
#  48    left_wrist_elbow_shoulder kurtosis                              object
#  49    left_wrist_elbow_shoulder skew                                  object
#  50    left_wrist_elbow_shoulder quantile 25                           object
#  51    left_wrist_elbow_shoulder quantile 75                           object
#  52    left_wrist_elbow_shoulder RMS                                   object
#  53    left_wrist_elbow_shoulder MAV                                   object
#  54    left_wrist_elbow_shoulder rmse                                  object
#  55    left_wrist_elbow_shoulder mae                                   object
#  56    left_wrist_elbow_shoulder maxerror                              object
#  57    left_wrist_elbow_shoulder minerror                              object
#  58    left_wrist_elbow_shoulder stderror                              object
#  59    left_wrist_elbow_shoulder quantile25e                           object
#  60    left_wrist_elbow_shoulder quantile75e                           object
#  61    right_wrist_elbow_shoulder mean_ft                              object
#  62    right_wrist_elbow_shoulder std_ft                               object
#  63    right_wrist_elbow_shoulder max_ft                               object
#  64    right_wrist_elbow_shoulder min_ft                               object
#  65    right_wrist_elbow_shoulder var_ft                               object
#  66    right_wrist_elbow_shoulder med_ft                               object
#  67    right_wrist_elbow_shoulder sum_ft                               object
#  68    right_wrist_elbow_shoulder kurtosis                             object
#  69    right_wrist_elbow_shoulder skew                                 object
#  70    right_wrist_elbow_shoulder quantile 25                          object
#  71    right_wrist_elbow_shoulder quantile 75                          object
#  72    right_wrist_elbow_shoulder RMS                                  object
#  73    right_wrist_elbow_shoulder MAV                                  object
#  74    right_wrist_elbow_shoulder rmse                                 object
#  75    right_wrist_elbow_shoulder mae                                  object
#  76    right_wrist_elbow_shoulder maxerror                             object
#  77    right_wrist_elbow_shoulder minerror                             object
#  78    right_wrist_elbow_shoulder stderror                             object
#  79    right_wrist_elbow_shoulder quantile25e                          object
#  80    right_wrist_elbow_shoulder quantile75e                          object
#  81     right_elbow_shoulder mean_ft                                   object
#  82     right_elbow_shoulder std_ft                                    object
#  83     right_elbow_shoulder max_ft                                    object
#  84     right_elbow_shoulder min_ft                                    object
#  85     right_elbow_shoulder var_ft                                    object
#  86     right_elbow_shoulder med_ft                                    object
#  87     right_elbow_shoulder sum_ft                                    object
#  88     right_elbow_shoulder kurtosis                                  object
#  89     right_elbow_shoulder skew                                      object
#  90     right_elbow_shoulder quantile 25                               object
#  91     right_elbow_shoulder quantile 75                               object
#  92     right_elbow_shoulder RMS                                       object
#  93     right_elbow_shoulder MAV                                       object
#  94     right_elbow_shoulder rmse                                      object
#  95     right_elbow_shoulder mae                                       object
#  96     right_elbow_shoulder maxerror                                  object
#  97     right_elbow_shoulder minerror                                  object
#  98     right_elbow_shoulder stderror                                  object
#  99     right_elbow_shoulder quantile25e                               object
#  100    right_elbow_shoulder quantile75e                               object
#  101   left_elbow_shoulder mean_ft                                     object
#  102   left_elbow_shoulder std_ft                                      object
#  103   left_elbow_shoulder max_ft                                      object
#  104   left_elbow_shoulder min_ft                                      object
#  105   left_elbow_shoulder var_ft                                      object
#  106   left_elbow_shoulder med_ft                                      object
#  107   left_elbow_shoulder sum_ft                                      object
#  108   left_elbow_shoulder kurtosis                                    object
#  109   left_elbow_shoulder skew                                        object
#  110   left_elbow_shoulder quantile 25                                 object
#  111   left_elbow_shoulder quantile 75                                 object
#  112   left_elbow_shoulder RMS                                         object
#  113   left_elbow_shoulder MAV                                         object
#  114   left_elbow_shoulder rmse                                        object
#  115   left_elbow_shoulder mae                                         object
#  116   left_elbow_shoulder maxerror                                    object
#  117   left_elbow_shoulder minerror                                    object
#  118   left_elbow_shoulder stderror                                    object
#  119   left_elbow_shoulder quantile25e                                 object
#  120   left_elbow_shoulder quantile75e                                 object
#  121   elbow_center_elbow mean_ft                                      object
#  122   elbow_center_elbow std_ft                                       object
#  123   elbow_center_elbow max_ft                                       object
#  124   elbow_center_elbow min_ft                                       object
#  125   elbow_center_elbow var_ft                                       object
#  126   elbow_center_elbow med_ft                                       object
#  127   elbow_center_elbow sum_ft                                       object
#  128   elbow_center_elbow kurtosis                                     object
#  129   elbow_center_elbow skew                                         object
#  130   elbow_center_elbow quantile 25                                  object
#  131   elbow_center_elbow quantile 75                                  object
#  132   elbow_center_elbow RMS                                          object
#  133   elbow_center_elbow MAV                                          object
#  134   elbow_center_elbow rmse                                         object
#  135   elbow_center_elbow mae                                          object
#  136   elbow_center_elbow maxerror                                     object
#  137   elbow_center_elbow minerror                                     object
#  138   elbow_center_elbow stderror                                     object
#  139   elbow_center_elbow quantile25e                                  object
#  140   elbow_center_elbow quantile75e                                  object
#  141   shoulder_center_shoulder mean_ft                                object
#  142   shoulder_center_shoulder std_ft                                 object
#  143   shoulder_center_shoulder max_ft                                 object
#  144   shoulder_center_shoulder min_ft                                 object
#  145   shoulder_center_shoulder var_ft                                 object
#  146   shoulder_center_shoulder med_ft                                 object
#  147   shoulder_center_shoulder sum_ft                                 object
#  148   shoulder_center_shoulder kurtosis                               object
#  149   shoulder_center_shoulder skew                                   object
#  150   shoulder_center_shoulder quantile 25                            object
#  151   shoulder_center_shoulder quantile 75                            object
#  152   shoulder_center_shoulder RMS                                    object
#  153   shoulder_center_shoulder MAV                                    object
#  154   shoulder_center_shoulder rmse                                   object
#  155   shoulder_center_shoulder mae                                    object
#  156   shoulder_center_shoulder maxerror                               object
#  157   shoulder_center_shoulder minerror                               object
#  158   shoulder_center_shoulder stderror                               object
#  159   shoulder_center_shoulder quantile25e                            object
#  160   shoulder_center_shoulder quantile75e                            object
#  161   wrist_center_wrist mean_ft                                      object
#  162   wrist_center_wrist std_ft                                       object
#  163   wrist_center_wrist max_ft                                       object
#  164   wrist_center_wrist min_ft                                       object
#  165   wrist_center_wrist var_ft                                       object
#  166   wrist_center_wrist med_ft                                       object
#  167   wrist_center_wrist sum_ft                                       object
#  168   wrist_center_wrist kurtosis                                     object
#  169   wrist_center_wrist skew                                         object
#  170   wrist_center_wrist quantile 25                                  object
#  171   wrist_center_wrist quantile 75                                  object
#  172   wrist_center_wrist RMS                                          object
#  173   wrist_center_wrist MAV                                          object
#  174   wrist_center_wrist rmse                                         object
#  175   wrist_center_wrist mae                                          object
#  176   wrist_center_wrist maxerror                                     object
#  177   wrist_center_wrist minerror                                     object
#  178   wrist_center_wrist stderror                                     object
#  179   wrist_center_wrist quantile25e                                  object
#  180   wrist_center_wrist quantile75e                                  object
#  181   nose_x mean_ft                                                  object
#  182   nose_x std_ft                                                   object
#  183   nose_x max_ft                                                   object
#  184   nose_x min_ft                                                   object
#  185   nose_x var_ft                                                   object
#  186   nose_x med_ft                                                   object
#  187   nose_x sum_ft                                                   object
#  188   nose_x kurtosis                                                 object
#  189   nose_x skew                                                     object
#  190   nose_x quantile 25                                              object
#  191   nose_x quantile 75                                              object
#  192   nose_x RMS                                                      object
#  193   nose_x MAV                                                      object
#  194   nose_x rmse                                                     object
#  195   nose_x mae                                                      object
#  196   nose_x maxerror                                                 object
#  197   nose_x minerror                                                 object
#  198   nose_x stderror                                                 object
#  199   nose_x quantile25e                                              object
#  200   nose_x quantile75e                                              object
#  201   nose_y mean_ft                                                  object
#  202   nose_y std_ft                                                   object
#  203   nose_y max_ft                                                   object
#  204   nose_y min_ft                                                   object
#  205   nose_y var_ft                                                   object
#  206   nose_y med_ft                                                   object
#  207   nose_y sum_ft                                                   object
#  208   nose_y kurtosis                                                 object
#  209   nose_y skew                                                     object
#  210   nose_y quantile 25                                              object
#  211   nose_y quantile 75                                              object
#  212   nose_y RMS                                                      object
#  213   nose_y MAV                                                      object
#  214   nose_y rmse                                                     object
#  215   nose_y mae                                                      object
#  216   nose_y maxerror                                                 object
#  217   nose_y minerror                                                 object
#  218   nose_y stderror                                                 object
#  219   nose_y quantile25e                                              object
#  220   nose_y quantile75e                                              object
#  221   left_eye_x mean_ft                                              object
#  222   left_eye_x std_ft                                               object
#  223   left_eye_x max_ft                                               object
#  224   left_eye_x min_ft                                               object
#  225   left_eye_x var_ft                                               object
#  226   left_eye_x med_ft                                               object
#  227   left_eye_x sum_ft                                               object
#  228   left_eye_x kurtosis                                             object
#  229   left_eye_x skew                                                 object
#  230   left_eye_x quantile 25                                          object
#  231   left_eye_x quantile 75                                          object
#  232   left_eye_x RMS                                                  object
#  233   left_eye_x MAV                                                  object
#  234   left_eye_x rmse                                                 object
#  235   left_eye_x mae                                                  object
#  236   left_eye_x maxerror                                             object
#  237   left_eye_x minerror                                             object
#  238   left_eye_x stderror                                             object
#  239   left_eye_x quantile25e                                          object
#  240   left_eye_x quantile75e                                          object
#  241   left_eye_y mean_ft                                              object
#  242   left_eye_y std_ft                                               object
#  243   left_eye_y max_ft                                               object
#  244   left_eye_y min_ft                                               object
#  245   left_eye_y var_ft                                               object
#  246   left_eye_y med_ft                                               object
#  247   left_eye_y sum_ft                                               object
#  248   left_eye_y kurtosis                                             object
#  249   left_eye_y skew                                                 object
#  250   left_eye_y quantile 25                                          object
#  251   left_eye_y quantile 75                                          object
#  252   left_eye_y RMS                                                  object
#  253   left_eye_y MAV                                                  object
#  254   left_eye_y rmse                                                 object
#  255   left_eye_y mae                                                  object
#  256   left_eye_y maxerror                                             object
#  257   left_eye_y minerror                                             object
#  258   left_eye_y stderror                                             object
#  259   left_eye_y quantile25e                                          object
#  260   left_eye_y quantile75e                                          object
#  261   right_eye_x mean_ft                                             object
#  262   right_eye_x std_ft                                              object
#  263   right_eye_x max_ft                                              object
#  264   right_eye_x min_ft                                              object
#  265   right_eye_x var_ft                                              object
#  266   right_eye_x med_ft                                              object
#  267   right_eye_x sum_ft                                              object
#  268   right_eye_x kurtosis                                            object
#  269   right_eye_x skew                                                object
#  270   right_eye_x quantile 25                                         object
#  271   right_eye_x quantile 75                                         object
#  272   right_eye_x RMS                                                 object
#  273   right_eye_x MAV                                                 object
#  274   right_eye_x rmse                                                object
#  275   right_eye_x mae                                                 object
#  276   right_eye_x maxerror                                            object
#  277   right_eye_x minerror                                            object
#  278   right_eye_x stderror                                            object
#  279   right_eye_x quantile25e                                         object
#  280   right_eye_x quantile75e                                         object
#  281   right_eye_y mean_ft                                             object
#  282   right_eye_y std_ft                                              object
#  283   right_eye_y max_ft                                              object
#  284   right_eye_y min_ft                                              object
#  285   right_eye_y var_ft                                              object
#  286   right_eye_y med_ft                                              object
#  287   right_eye_y sum_ft                                              object
#  288   right_eye_y kurtosis                                            object
#  289   right_eye_y skew                                                object
#  290   right_eye_y quantile 25                                         object
#  291   right_eye_y quantile 75                                         object
#  292   right_eye_y RMS                                                 object
#  293   right_eye_y MAV                                                 object
#  294   right_eye_y rmse                                                object
#  295   right_eye_y mae                                                 object
#  296   right_eye_y maxerror                                            object
#  297   right_eye_y minerror                                            object
#  298   right_eye_y stderror                                            object
#  299   right_eye_y quantile25e                                         object
#  300   right_eye_y quantile75e                                         object
#  301   left_ear_x mean_ft                                              object
#  302   left_ear_x std_ft                                               object
#  303   left_ear_x max_ft                                               object
#  304   left_ear_x min_ft                                               object
#  305   left_ear_x var_ft                                               object
#  306   left_ear_x med_ft                                               object
#  307   left_ear_x sum_ft                                               object
#  308   left_ear_x kurtosis                                             object
#  309   left_ear_x skew                                                 object
#  310   left_ear_x quantile 25                                          object
#  311   left_ear_x quantile 75                                          object
#  312   left_ear_x RMS                                                  object
#  313   left_ear_x MAV                                                  object
#  314   left_ear_x rmse                                                 object
#  315   left_ear_x mae                                                  object
#  316   left_ear_x maxerror                                             object
#  317   left_ear_x minerror                                             object
#  318   left_ear_x stderror                                             object
#  319   left_ear_x quantile25e                                          object
#  320   left_ear_x quantile75e                                          object
#  321   left_ear_y mean_ft                                              object
#  322   left_ear_y std_ft                                               object
#  323   left_ear_y max_ft                                               object
#  324   left_ear_y min_ft                                               object
#  325   left_ear_y var_ft                                               object
#  326   left_ear_y med_ft                                               object
#  327   left_ear_y sum_ft                                               object
#  328   left_ear_y kurtosis                                             object
#  329   left_ear_y skew                                                 object
#  330   left_ear_y quantile 25                                          object
#  331   left_ear_y quantile 75                                          object
#  332   left_ear_y RMS                                                  object
#  333   left_ear_y MAV                                                  object
#  334   left_ear_y rmse                                                 object
#  335   left_ear_y mae                                                  object
#  336   left_ear_y maxerror                                             object
#  337   left_ear_y minerror                                             object
#  338   left_ear_y stderror                                             object
#  339   left_ear_y quantile25e                                          object
#  340   left_ear_y quantile75e                                          object
#  341   right_ear_x mean_ft                                             object
#  342   right_ear_x std_ft                                              object
#  343   right_ear_x max_ft                                              object
#  344   right_ear_x min_ft                                              object
#  345   right_ear_x var_ft                                              object
#  346   right_ear_x med_ft                                              object
#  347   right_ear_x sum_ft                                              object
#  348   right_ear_x kurtosis                                            object
#  349   right_ear_x skew                                                object
#  350   right_ear_x quantile 25                                         object
#  351   right_ear_x quantile 75                                         object
#  352   right_ear_x RMS                                                 object
#  353   right_ear_x MAV                                                 object
#  354   right_ear_x rmse                                                object
#  355   right_ear_x mae                                                 object
#  356   right_ear_x maxerror                                            object
#  357   right_ear_x minerror                                            object
#  358   right_ear_x stderror                                            object
#  359   right_ear_x quantile25e                                         object
#  360   right_ear_x quantile75e                                         object
#  361   right_ear_y mean_ft                                             object
#  362   right_ear_y std_ft                                              object
#  363   right_ear_y max_ft                                              object
#  364   right_ear_y min_ft                                              object
#  365   right_ear_y var_ft                                              object
#  366   right_ear_y med_ft                                              object
#  367   right_ear_y sum_ft                                              object
#  368   right_ear_y kurtosis                                            object
#  369   right_ear_y skew                                                object
#  370   right_ear_y quantile 25                                         object
#  371   right_ear_y quantile 75                                         object
#  372   right_ear_y RMS                                                 object
#  373   right_ear_y MAV                                                 object
#  374   right_ear_y rmse                                                object
#  375   right_ear_y mae                                                 object
#  376   right_ear_y maxerror                                            object
#  377   right_ear_y minerror                                            object
#  378   right_ear_y stderror                                            object
#  379   right_ear_y quantile25e                                         object
#  380   right_ear_y quantile75e                                         object
#  381   left_shoulder_x mean_ft                                         object
#  382   left_shoulder_x std_ft                                          object
#  383   left_shoulder_x max_ft                                          object
#  384   left_shoulder_x min_ft                                          object
#  385   left_shoulder_x var_ft                                          object
#  386   left_shoulder_x med_ft                                          object
#  387   left_shoulder_x sum_ft                                          object
#  388   left_shoulder_x kurtosis                                        object
#  389   left_shoulder_x skew                                            object
#  390   left_shoulder_x quantile 25                                     object
#  391   left_shoulder_x quantile 75                                     object
#  392   left_shoulder_x RMS                                             object
#  393   left_shoulder_x MAV                                             object
#  394   left_shoulder_x rmse                                            object
#  395   left_shoulder_x mae                                             object
#  396   left_shoulder_x maxerror                                        object
#  397   left_shoulder_x minerror                                        object
#  398   left_shoulder_x stderror                                        object
#  399   left_shoulder_x quantile25e                                     object
#  400   left_shoulder_x quantile75e                                     object
#  401   left_shoulder_y mean_ft                                         object
#  402   left_shoulder_y std_ft                                          object
#  403   left_shoulder_y max_ft                                          object
#  404   left_shoulder_y min_ft                                          object
#  405   left_shoulder_y var_ft                                          object
#  406   left_shoulder_y med_ft                                          object
#  407   left_shoulder_y sum_ft                                          object
#  408   left_shoulder_y kurtosis                                        object
#  409   left_shoulder_y skew                                            object
#  410   left_shoulder_y quantile 25                                     object
#  411   left_shoulder_y quantile 75                                     object
#  412   left_shoulder_y RMS                                             object
#  413   left_shoulder_y MAV                                             object
#  414   left_shoulder_y rmse                                            object
#  415   left_shoulder_y mae                                             object
#  416   left_shoulder_y maxerror                                        object
#  417   left_shoulder_y minerror                                        object
#  418   left_shoulder_y stderror                                        object
#  419   left_shoulder_y quantile25e                                     object
#  420   left_shoulder_y quantile75e                                     object
#  421   right_shoulder_x mean_ft                                        object
#  422   right_shoulder_x std_ft                                         object
#  423   right_shoulder_x max_ft                                         object
#  424   right_shoulder_x min_ft                                         object
#  425   right_shoulder_x var_ft                                         object
#  426   right_shoulder_x med_ft                                         object
#  427   right_shoulder_x sum_ft                                         object
#  428   right_shoulder_x kurtosis                                       object
#  429   right_shoulder_x skew                                           object
#  430   right_shoulder_x quantile 25                                    object
#  431   right_shoulder_x quantile 75                                    object
#  432   right_shoulder_x RMS                                            object
#  433   right_shoulder_x MAV                                            object
#  434   right_shoulder_x rmse                                           object
#  435   right_shoulder_x mae                                            object
#  436   right_shoulder_x maxerror                                       object
#  437   right_shoulder_x minerror                                       object
#  438   right_shoulder_x stderror                                       object
#  439   right_shoulder_x quantile25e                                    object
#  440   right_shoulder_x quantile75e                                    object
#  441   right_shoulder_y mean_ft                                        object
#  442   right_shoulder_y std_ft                                         object
#  443   right_shoulder_y max_ft                                         object
#  444   right_shoulder_y min_ft                                         object
#  445   right_shoulder_y var_ft                                         object
#  446   right_shoulder_y med_ft                                         object
#  447   right_shoulder_y sum_ft                                         object
#  448   right_shoulder_y kurtosis                                       object
#  449   right_shoulder_y skew                                           object
#  450   right_shoulder_y quantile 25                                    object
#  451   right_shoulder_y quantile 75                                    object
#  452   right_shoulder_y RMS                                            object
#  453   right_shoulder_y MAV                                            object
#  454   right_shoulder_y rmse                                           object
#  455   right_shoulder_y mae                                            object
#  456   right_shoulder_y maxerror                                       object
#  457   right_shoulder_y minerror                                       object
#  458   right_shoulder_y stderror                                       object
#  459   right_shoulder_y quantile25e                                    object
#  460   right_shoulder_y quantile75e                                    object
#  461   left_elbow_x mean_ft                                            object
#  462   left_elbow_x std_ft                                             object
#  463   left_elbow_x max_ft                                             object
#  464   left_elbow_x min_ft                                             object
#  465   left_elbow_x var_ft                                             object
#  466   left_elbow_x med_ft                                             object
#  467   left_elbow_x sum_ft                                             object
#  468   left_elbow_x kurtosis                                           object
#  469   left_elbow_x skew                                               object
#  470   left_elbow_x quantile 25                                        object
#  471   left_elbow_x quantile 75                                        object
#  472   left_elbow_x RMS                                                object
#  473   left_elbow_x MAV                                                object
#  474   left_elbow_x rmse                                               object
#  475   left_elbow_x mae                                                object
#  476   left_elbow_x maxerror                                           object
#  477   left_elbow_x minerror                                           object
#  478   left_elbow_x stderror                                           object
#  479   left_elbow_x quantile25e                                        object
#  480   left_elbow_x quantile75e                                        object
#  481   left_elbow_y mean_ft                                            object
#  482   left_elbow_y std_ft                                             object
#  483   left_elbow_y max_ft                                             object
#  484   left_elbow_y min_ft                                             object
#  485   left_elbow_y var_ft                                             object
#  486   left_elbow_y med_ft                                             object
#  487   left_elbow_y sum_ft                                             object
#  488   left_elbow_y kurtosis                                           object
#  489   left_elbow_y skew                                               object
#  490   left_elbow_y quantile 25                                        object
#  491   left_elbow_y quantile 75                                        object
#  492   left_elbow_y RMS                                                object
#  493   left_elbow_y MAV                                                object
#  494   left_elbow_y rmse                                               object
#  495   left_elbow_y mae                                                object
#  496   left_elbow_y maxerror                                           object
#  497   left_elbow_y minerror                                           object
#  498   left_elbow_y stderror                                           object
#  499   left_elbow_y quantile25e                                        object
#  500   left_elbow_y quantile75e                                        object
#  501   right_elbow_x mean_ft                                           object
#  502   right_elbow_x std_ft                                            object
#  503   right_elbow_x max_ft                                            object
#  504   right_elbow_x min_ft                                            object
#  505   right_elbow_x var_ft                                            object
#  506   right_elbow_x med_ft                                            object
#  507   right_elbow_x sum_ft                                            object
#  508   right_elbow_x kurtosis                                          object
#  509   right_elbow_x skew                                              object
#  510   right_elbow_x quantile 25                                       object
#  511   right_elbow_x quantile 75                                       object
#  512   right_elbow_x RMS                                               object
#  513   right_elbow_x MAV                                               object
#  514   right_elbow_x rmse                                              object
#  515   right_elbow_x mae                                               object
#  516   right_elbow_x maxerror                                          object
#  517   right_elbow_x minerror                                          object
#  518   right_elbow_x stderror                                          object
#  519   right_elbow_x quantile25e                                       object
#  520   right_elbow_x quantile75e                                       object
#  521   right_elbow_y mean_ft                                           object
#  522   right_elbow_y std_ft                                            object
#  523   right_elbow_y max_ft                                            object
#  524   right_elbow_y min_ft                                            object
#  525   right_elbow_y var_ft                                            object
#  526   right_elbow_y med_ft                                            object
#  527   right_elbow_y sum_ft                                            object
#  528   right_elbow_y kurtosis                                          object
#  529   right_elbow_y skew                                              object
#  530   right_elbow_y quantile 25                                       object
#  531   right_elbow_y quantile 75                                       object
#  532   right_elbow_y RMS                                               object
#  533   right_elbow_y MAV                                               object
#  534   right_elbow_y rmse                                              object
#  535   right_elbow_y mae                                               object
#  536   right_elbow_y maxerror                                          object
#  537   right_elbow_y minerror                                          object
#  538   right_elbow_y stderror                                          object
#  539   right_elbow_y quantile25e                                       object
#  540   right_elbow_y quantile75e                                       object
#  541   left_wrist_x mean_ft                                            object
#  542   left_wrist_x std_ft                                             object
#  543   left_wrist_x max_ft                                             object
#  544   left_wrist_x min_ft                                             object
#  545   left_wrist_x var_ft                                             object
#  546   left_wrist_x med_ft                                             object
#  547   left_wrist_x sum_ft                                             object
#  548   left_wrist_x kurtosis                                           object
#  549   left_wrist_x skew                                               object
#  550   left_wrist_x quantile 25                                        object
#  551   left_wrist_x quantile 75                                        object
#  552   left_wrist_x RMS                                                object
#  553   left_wrist_x MAV                                                object
#  554   left_wrist_x rmse                                               object
#  555   left_wrist_x mae                                                object
#  556   left_wrist_x maxerror                                           object
#  557   left_wrist_x minerror                                           object
#  558   left_wrist_x stderror                                           object
#  559   left_wrist_x quantile25e                                        object
#  560   left_wrist_x quantile75e                                        object
#  561   left_wrist_y mean_ft                                            object
#  562   left_wrist_y std_ft                                             object
#  563   left_wrist_y max_ft                                             object
#  564   left_wrist_y min_ft                                             object
#  565   left_wrist_y var_ft                                             object
#  566   left_wrist_y med_ft                                             object
#  567   left_wrist_y sum_ft                                             object
#  568   left_wrist_y kurtosis                                           object
#  569   left_wrist_y skew                                               object
#  570   left_wrist_y quantile 25                                        object
#  571   left_wrist_y quantile 75                                        object
#  572   left_wrist_y RMS                                                object
#  573   left_wrist_y MAV                                                object
#  574   left_wrist_y rmse                                               object
#  575   left_wrist_y mae                                                object
#  576   left_wrist_y maxerror                                           object
#  577   left_wrist_y minerror                                           object
#  578   left_wrist_y stderror                                           object
#  579   left_wrist_y quantile25e                                        object
#  580   left_wrist_y quantile75e                                        object
#  581   right_wrist_x mean_ft                                           object
#  582   right_wrist_x std_ft                                            object
#  583   right_wrist_x max_ft                                            object
#  584   right_wrist_x min_ft                                            object
#  585   right_wrist_x var_ft                                            object
#  586   right_wrist_x med_ft                                            object
#  587   right_wrist_x sum_ft                                            object
#  588   right_wrist_x kurtosis                                          object
#  589   right_wrist_x skew                                              object
#  590   right_wrist_x quantile 25                                       object
#  591   right_wrist_x quantile 75                                       object
#  592   right_wrist_x RMS                                               object
#  593   right_wrist_x MAV                                               object
#  594   right_wrist_x rmse                                              object
#  595   right_wrist_x mae                                               object
#  596   right_wrist_x maxerror                                          object
#  597   right_wrist_x minerror                                          object
#  598   right_wrist_x stderror                                          object
#  599   right_wrist_x quantile25e                                       object
#  600   right_wrist_x quantile75e                                       object
#  601   right_wrist_y mean_ft                                           object
#  602   right_wrist_y std_ft                                            object
#  603   right_wrist_y max_ft                                            object
#  604   right_wrist_y min_ft                                            object
#  605   right_wrist_y var_ft                                            object
#  606   right_wrist_y med_ft                                            object
#  607   right_wrist_y sum_ft                                            object
#  608   right_wrist_y kurtosis                                          object
#  609   right_wrist_y skew                                              object
#  610   right_wrist_y quantile 25                                       object
#  611   right_wrist_y quantile 75                                       object
# ...
#  8481  movingright_shoulder left_wrist dx mean_ft previous 3 s         object
#  8482  movingright_shoulder left_wrist dx std_ft previous 3 s          object
#  8483  movingright_shoulder left_wrist dx max_ft previous 3 s          object
#  8484  movingright_shoulder left_wrist dx min_ft previous 3 s          object
#  8485  movingright_shoulder left_wrist dx var_ft previous 3 s          object
#  8486  movingright_shoulder left_wrist dx med_ft previous 3 s          object
#  8487  movingright_shoulder left_wrist dx sum_ft previous 3 s          object
#  8488  movingright_shoulder left_wrist dx kurtosis previous 3 s        object
#  8489  movingright_shoulder left_wrist dx skew previous 3 s            object
#  8490  movingright_shoulder left_wrist dx quantile 25 previous 3 s     object
#  8491  movingright_shoulder left_wrist dx quantile 75 previous 3 s     object
#  8492  movingright_shoulder left_wrist dx RMS previous 3 s             object
#  8493  movingright_shoulder left_wrist dx MAV previous 3 s             object
#  8494  movingright_shoulder left_wrist dx rmse previous 3 s            object
#  8495  movingright_shoulder left_wrist dx mae previous 3 s             object
#  8496  movingright_shoulder left_wrist dx maxerror previous 3 s        object
#  8497  movingright_shoulder left_wrist dx minerror previous 3 s        object
#  8498  movingright_shoulder left_wrist dx stderror previous 3 s        object
#  8499  movingright_shoulder left_wrist dx quantile25e previous 3 s     object
#  8500  movingright_shoulder left_wrist dx quantile75e previous 3 s     object
#  8501  movingright_shoulder left_wrist dy mean_ft previous 3 s         object
#  8502  movingright_shoulder left_wrist dy std_ft previous 3 s          object
#  8503  movingright_shoulder left_wrist dy max_ft previous 3 s          object
#  8504  movingright_shoulder left_wrist dy min_ft previous 3 s          object
#  8505  movingright_shoulder left_wrist dy var_ft previous 3 s          object
#  8506  movingright_shoulder left_wrist dy med_ft previous 3 s          object
#  8507  movingright_shoulder left_wrist dy sum_ft previous 3 s          object
#  8508  movingright_shoulder left_wrist dy kurtosis previous 3 s        object
#  8509  movingright_shoulder left_wrist dy skew previous 3 s            object
#  8510  movingright_shoulder left_wrist dy quantile 25 previous 3 s     object
#  8511  movingright_shoulder left_wrist dy quantile 75 previous 3 s     object
#  8512  movingright_shoulder left_wrist dy RMS previous 3 s             object
#  8513  movingright_shoulder left_wrist dy MAV previous 3 s             object
#  8514  movingright_shoulder left_wrist dy rmse previous 3 s            object
#  8515  movingright_shoulder left_wrist dy mae previous 3 s             object
#  8516  movingright_shoulder left_wrist dy maxerror previous 3 s        object
#  8517  movingright_shoulder left_wrist dy minerror previous 3 s        object
#  8518  movingright_shoulder left_wrist dy stderror previous 3 s        object
#  8519  movingright_shoulder left_wrist dy quantile25e previous 3 s     object
#  8520  movingright_shoulder left_wrist dy quantile75e previous 3 s     object
#  8521  movingright_shoulder right_wrist dx mean_ft previous 3 s        object
#  8522  movingright_shoulder right_wrist dx std_ft previous 3 s         object
#  8523  movingright_shoulder right_wrist dx max_ft previous 3 s         object
#  8524  movingright_shoulder right_wrist dx min_ft previous 3 s         object
#  8525  movingright_shoulder right_wrist dx var_ft previous 3 s         object
#  8526  movingright_shoulder right_wrist dx med_ft previous 3 s         object
#  8527  movingright_shoulder right_wrist dx sum_ft previous 3 s         object
#  8528  movingright_shoulder right_wrist dx kurtosis previous 3 s       object
#  8529  movingright_shoulder right_wrist dx skew previous 3 s           object
#  8530  movingright_shoulder right_wrist dx quantile 25 previous 3 s    object
#  8531  movingright_shoulder right_wrist dx quantile 75 previous 3 s    object
#  8532  movingright_shoulder right_wrist dx RMS previous 3 s            object
#  8533  movingright_shoulder right_wrist dx MAV previous 3 s            object
#  8534  movingright_shoulder right_wrist dx rmse previous 3 s           object
#  8535  movingright_shoulder right_wrist dx mae previous 3 s            object
#  8536  movingright_shoulder right_wrist dx maxerror previous 3 s       object
#  8537  movingright_shoulder right_wrist dx minerror previous 3 s       object
#  8538  movingright_shoulder right_wrist dx stderror previous 3 s       object
#  8539  movingright_shoulder right_wrist dx quantile25e previous 3 s    object
#  8540  movingright_shoulder right_wrist dx quantile75e previous 3 s    object
#  8541  movingright_shoulder right_wrist dy mean_ft previous 3 s        object
#  8542  movingright_shoulder right_wrist dy std_ft previous 3 s         object
#  8543  movingright_shoulder right_wrist dy max_ft previous 3 s         object
#  8544  movingright_shoulder right_wrist dy min_ft previous 3 s         object
#  8545  movingright_shoulder right_wrist dy var_ft previous 3 s         object
#  8546  movingright_shoulder right_wrist dy med_ft previous 3 s         object
#  8547  movingright_shoulder right_wrist dy sum_ft previous 3 s         object
#  8548  movingright_shoulder right_wrist dy kurtosis previous 3 s       object
#  8549  movingright_shoulder right_wrist dy skew previous 3 s           object
#  8550  movingright_shoulder right_wrist dy quantile 25 previous 3 s    object
#  8551  movingright_shoulder right_wrist dy quantile 75 previous 3 s    object
#  8552  movingright_shoulder right_wrist dy RMS previous 3 s            object
#  8553  movingright_shoulder right_wrist dy MAV previous 3 s            object
#  8554  movingright_shoulder right_wrist dy rmse previous 3 s           object
#  8555  movingright_shoulder right_wrist dy mae previous 3 s            object
#  8556  movingright_shoulder right_wrist dy maxerror previous 3 s       object
#  8557  movingright_shoulder right_wrist dy minerror previous 3 s       object
#  8558  movingright_shoulder right_wrist dy stderror previous 3 s       object
#  8559  movingright_shoulder right_wrist dy quantile25e previous 3 s    object
#  8560  movingright_shoulder right_wrist dy quantile75e previous 3 s    object
#  8561  movingright_shoulder left_hip dx mean_ft previous 3 s           object
#  8562  movingright_shoulder left_hip dx std_ft previous 3 s            object
#  8563  movingright_shoulder left_hip dx max_ft previous 3 s            object
#  8564  movingright_shoulder left_hip dx min_ft previous 3 s            object
#  8565  movingright_shoulder left_hip dx var_ft previous 3 s            object
#  8566  movingright_shoulder left_hip dx med_ft previous 3 s            object
#  8567  movingright_shoulder left_hip dx sum_ft previous 3 s            object
#  8568  movingright_shoulder left_hip dx kurtosis previous 3 s          object
#  8569  movingright_shoulder left_hip dx skew previous 3 s              object
#  8570  movingright_shoulder left_hip dx quantile 25 previous 3 s       object
#  8571  movingright_shoulder left_hip dx quantile 75 previous 3 s       object
#  8572  movingright_shoulder left_hip dx RMS previous 3 s               object
#  8573  movingright_shoulder left_hip dx MAV previous 3 s               object
#  8574  movingright_shoulder left_hip dx rmse previous 3 s              object
#  8575  movingright_shoulder left_hip dx mae previous 3 s               object
#  8576  movingright_shoulder left_hip dx maxerror previous 3 s          object
#  8577  movingright_shoulder left_hip dx minerror previous 3 s          object
#  8578  movingright_shoulder left_hip dx stderror previous 3 s          object
#  8579  movingright_shoulder left_hip dx quantile25e previous 3 s       object
#  8580  movingright_shoulder left_hip dx quantile75e previous 3 s       object
#  8581  movingright_shoulder left_hip dy mean_ft previous 3 s           object
#  8582  movingright_shoulder left_hip dy std_ft previous 3 s            object
#  8583  movingright_shoulder left_hip dy max_ft previous 3 s            object
#  8584  movingright_shoulder left_hip dy min_ft previous 3 s            object
#  8585  movingright_shoulder left_hip dy var_ft previous 3 s            object
#  8586  movingright_shoulder left_hip dy med_ft previous 3 s            object
#  8587  movingright_shoulder left_hip dy sum_ft previous 3 s            object
#  8588  movingright_shoulder left_hip dy kurtosis previous 3 s          object
#  8589  movingright_shoulder left_hip dy skew previous 3 s              object
#  8590  movingright_shoulder left_hip dy quantile 25 previous 3 s       object
#  8591  movingright_shoulder left_hip dy quantile 75 previous 3 s       object
#  8592  movingright_shoulder left_hip dy RMS previous 3 s               object
#  8593  movingright_shoulder left_hip dy MAV previous 3 s               object
#  8594  movingright_shoulder left_hip dy rmse previous 3 s              object
#  8595  movingright_shoulder left_hip dy mae previous 3 s               object
#  8596  movingright_shoulder left_hip dy maxerror previous 3 s          object
#  8597  movingright_shoulder left_hip dy minerror previous 3 s          object
#  8598  movingright_shoulder left_hip dy stderror previous 3 s          object
#  8599  movingright_shoulder left_hip dy quantile25e previous 3 s       object
#  8600  movingright_shoulder left_hip dy quantile75e previous 3 s       object
#  8601  movingright_shoulder right_hip dx mean_ft previous 3 s          object
#  8602  movingright_shoulder right_hip dx std_ft previous 3 s           object
#  8603  movingright_shoulder right_hip dx max_ft previous 3 s           object
#  8604  movingright_shoulder right_hip dx min_ft previous 3 s           object
#  8605  movingright_shoulder right_hip dx var_ft previous 3 s           object
#  8606  movingright_shoulder right_hip dx med_ft previous 3 s           object
#  8607  movingright_shoulder right_hip dx sum_ft previous 3 s           object
#  8608  movingright_shoulder right_hip dx kurtosis previous 3 s         object
#  8609  movingright_shoulder right_hip dx skew previous 3 s             object
#  8610  movingright_shoulder right_hip dx quantile 25 previous 3 s      object
#  8611  movingright_shoulder right_hip dx quantile 75 previous 3 s      object
#  8612  movingright_shoulder right_hip dx RMS previous 3 s              object
#  8613  movingright_shoulder right_hip dx MAV previous 3 s              object
#  8614  movingright_shoulder right_hip dx rmse previous 3 s             object
#  8615  movingright_shoulder right_hip dx mae previous 3 s              object
#  8616  movingright_shoulder right_hip dx maxerror previous 3 s         object
#  8617  movingright_shoulder right_hip dx minerror previous 3 s         object
#  8618  movingright_shoulder right_hip dx stderror previous 3 s         object
#  8619  movingright_shoulder right_hip dx quantile25e previous 3 s      object
#  8620  movingright_shoulder right_hip dx quantile75e previous 3 s      object
#  8621  movingright_shoulder right_hip dy mean_ft previous 3 s          object
#  8622  movingright_shoulder right_hip dy std_ft previous 3 s           object
#  8623  movingright_shoulder right_hip dy max_ft previous 3 s           object
#  8624  movingright_shoulder right_hip dy min_ft previous 3 s           object
#  8625  movingright_shoulder right_hip dy var_ft previous 3 s           object
#  8626  movingright_shoulder right_hip dy med_ft previous 3 s           object
#  8627  movingright_shoulder right_hip dy sum_ft previous 3 s           object
#  8628  movingright_shoulder right_hip dy kurtosis previous 3 s         object
#  8629  movingright_shoulder right_hip dy skew previous 3 s             object
#  8630  movingright_shoulder right_hip dy quantile 25 previous 3 s      object
#  8631  movingright_shoulder right_hip dy quantile 75 previous 3 s      object
#  8632  movingright_shoulder right_hip dy RMS previous 3 s              object
#  8633  movingright_shoulder right_hip dy MAV previous 3 s              object
#  8634  movingright_shoulder right_hip dy rmse previous 3 s             object
#  8635  movingright_shoulder right_hip dy mae previous 3 s              object
#  8636  movingright_shoulder right_hip dy maxerror previous 3 s         object
#  8637  movingright_shoulder right_hip dy minerror previous 3 s         object
#  8638  movingright_shoulder right_hip dy stderror previous 3 s         object
#  8639  movingright_shoulder right_hip dy quantile25e previous 3 s      object
#  8640  movingright_shoulder right_hip dy quantile75e previous 3 s      object
#  8641  movingcenter_x mean_ft previous 3 s                             object
#  8642  movingcenter_x std_ft previous 3 s                              object
#  8643  movingcenter_x max_ft previous 3 s                              object
#  8644  movingcenter_x min_ft previous 3 s                              object
#  8645  movingcenter_x var_ft previous 3 s                              object
#  8646  movingcenter_x med_ft previous 3 s                              object
#  8647  movingcenter_x sum_ft previous 3 s                              object
#  8648  movingcenter_x kurtosis previous 3 s                            object
#  8649  movingcenter_x skew previous 3 s                                object
#  8650  movingcenter_x quantile 25 previous 3 s                         object
#  8651  movingcenter_x quantile 75 previous 3 s                         object
#  8652  movingcenter_x RMS previous 3 s                                 object
#  8653  movingcenter_x MAV previous 3 s                                 object
#  8654  movingcenter_x rmse previous 3 s                                object
#  8655  movingcenter_x mae previous 3 s                                 object
#  8656  movingcenter_x maxerror previous 3 s                            object
#  8657  movingcenter_x minerror previous 3 s                            object
#  8658  movingcenter_x stderror previous 3 s                            object
#  8659  movingcenter_x quantile25e previous 3 s                         object
#  8660  movingcenter_x quantile75e previous 3 s                         object
#  8661  movingcenter_y mean_ft previous 3 s                             object
#  8662  movingcenter_y std_ft previous 3 s                              object
#  8663  movingcenter_y max_ft previous 3 s                              object
#  8664  movingcenter_y min_ft previous 3 s                              object
#  8665  movingcenter_y var_ft previous 3 s                              object
#  8666  movingcenter_y med_ft previous 3 s                              object
#  8667  movingcenter_y sum_ft previous 3 s                              object
#  8668  movingcenter_y kurtosis previous 3 s                            object
#  8669  movingcenter_y skew previous 3 s                                object
#  8670  movingcenter_y quantile 25 previous 3 s                         object
#  8671  movingcenter_y quantile 75 previous 3 s                         object
#  8672  movingcenter_y RMS previous 3 s                                 object
#  8673  movingcenter_y MAV previous 3 s                                 object
#  8674  movingcenter_y rmse previous 3 s                                object
#  8675  movingcenter_y mae previous 3 s                                 object
#  8676  movingcenter_y maxerror previous 3 s                            object
#  8677  movingcenter_y minerror previous 3 s                            object
#  8678  movingcenter_y stderror previous 3 s                            object
#  8679  movingcenter_y quantile25e previous 3 s                         object
#  8680  movingcenter_y quantile75e previous 3 s                         object
#  8681  previous_label                                                  int64
#  8682  label                                                           int64
#  8683  after1                                                          int64
#  8684  after4                                                          int64
# dtypes: int64(4), object(8681)
# memory usage: 124.0+ bytes

# %%
import sdv
from sdv.metadata import SingleTableMetadata
print(df_train)
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df_train)
print(metadata)
# Out:
# Empty DataFrame
# Columns: [index, left_elbow_shoulder_hip mean_ft, left_elbow_shoulder_hip std_ft, left_elbow_shoulder_hip max_ft, left_elbow_shoulder_hip min_ft, left_elbow_shoulder_hip var_ft, left_elbow_shoulder_hip med_ft, left_elbow_shoulder_hip sum_ft, left_elbow_shoulder_hip kurtosis, left_elbow_shoulder_hip skew, left_elbow_shoulder_hip quantile 25, left_elbow_shoulder_hip quantile 75, left_elbow_shoulder_hip RMS, left_elbow_shoulder_hip MAV, left_elbow_shoulder_hip rmse, left_elbow_shoulder_hip mae, left_elbow_shoulder_hip maxerror, left_elbow_shoulder_hip minerror, left_elbow_shoulder_hip stderror, left_elbow_shoulder_hip quantile25e, left_elbow_shoulder_hip quantile75e, right_elbow_shoulder_hip mean_ft, right_elbow_shoulder_hip std_ft, right_elbow_shoulder_hip max_ft, right_elbow_shoulder_hip min_ft, right_elbow_shoulder_hip var_ft, right_elbow_shoulder_hip med_ft, right_elbow_shoulder_hip sum_ft, right_elbow_shoulder_hip kurtosis, right_elbow_shoulder_hip skew, right_elbow_shoulder_hip quantile 25, right_elbow_shoulder_hip quantile 75, right_elbow_shoulder_hip RMS, right_elbow_shoulder_hip MAV, right_elbow_shoulder_hip rmse, right_elbow_shoulder_hip mae, right_elbow_shoulder_hip maxerror, right_elbow_shoulder_hip minerror, right_elbow_shoulder_hip stderror, right_elbow_shoulder_hip quantile25e, right_elbow_shoulder_hip quantile75e, left_wrist_elbow_shoulder mean_ft, left_wrist_elbow_shoulder std_ft, left_wrist_elbow_shoulder max_ft, left_wrist_elbow_shoulder min_ft, left_wrist_elbow_shoulder var_ft, left_wrist_elbow_shoulder med_ft, left_wrist_elbow_shoulder sum_ft, left_wrist_elbow_shoulder kurtosis, left_wrist_elbow_shoulder skew, left_wrist_elbow_shoulder quantile 25, left_wrist_elbow_shoulder quantile 75, left_wrist_elbow_shoulder RMS, left_wrist_elbow_shoulder MAV, left_wrist_elbow_shoulder rmse, left_wrist_elbow_shoulder mae, left_wrist_elbow_shoulder maxerror, left_wrist_elbow_shoulder minerror, left_wrist_elbow_shoulder stderror, left_wrist_elbow_shoulder quantile25e, left_wrist_elbow_shoulder quantile75e, right_wrist_elbow_shoulder mean_ft, right_wrist_elbow_shoulder std_ft, right_wrist_elbow_shoulder max_ft, right_wrist_elbow_shoulder min_ft, right_wrist_elbow_shoulder var_ft, right_wrist_elbow_shoulder med_ft, right_wrist_elbow_shoulder sum_ft, right_wrist_elbow_shoulder kurtosis, right_wrist_elbow_shoulder skew, right_wrist_elbow_shoulder quantile 25, right_wrist_elbow_shoulder quantile 75, right_wrist_elbow_shoulder RMS, right_wrist_elbow_shoulder MAV, right_wrist_elbow_shoulder rmse, right_wrist_elbow_shoulder mae, right_wrist_elbow_shoulder maxerror, right_wrist_elbow_shoulder minerror, right_wrist_elbow_shoulder stderror, right_wrist_elbow_shoulder quantile25e, right_wrist_elbow_shoulder quantile75e,  right_elbow_shoulder mean_ft,  right_elbow_shoulder std_ft,  right_elbow_shoulder max_ft,  right_elbow_shoulder min_ft,  right_elbow_shoulder var_ft,  right_elbow_shoulder med_ft,  right_elbow_shoulder sum_ft,  right_elbow_shoulder kurtosis,  right_elbow_shoulder skew,  right_elbow_shoulder quantile 25,  right_elbow_shoulder quantile 75,  right_elbow_shoulder RMS,  right_elbow_shoulder MAV,  right_elbow_shoulder rmse,  right_elbow_shoulder mae,  right_elbow_shoulder maxerror,  right_elbow_shoulder minerror,  right_elbow_shoulder stderror,  right_elbow_shoulder quantile25e, ...]
# Index: []
#
# [0 rows x 8685 columns]
# {
#     "columns": {
#         "index": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip skew": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip RMS": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip MAV": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip rmse": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip mae": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip minerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip stderror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder_hip quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip skew": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip RMS": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip MAV": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip rmse": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip mae": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip minerror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip stderror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_shoulder_hip quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder skew": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder RMS": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder MAV": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder rmse": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder mae": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder minerror": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder stderror": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_wrist_elbow_shoulder quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder skew": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder RMS": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder MAV": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder rmse": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder mae": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder minerror": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder stderror": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_wrist_elbow_shoulder quantile75e": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder mean_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder std_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder max_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder min_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder var_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder med_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder sum_ft": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder kurtosis": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder skew": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder quantile 25": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder quantile 75": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder RMS": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder MAV": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder rmse": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder mae": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder maxerror": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder minerror": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder stderror": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder quantile25e": {
#             "sdtype": "categorical"
#         },
#         " right_elbow_shoulder quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder skew": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder RMS": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder MAV": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder rmse": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder mae": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder minerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder stderror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_shoulder quantile75e": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow mean_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow std_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow max_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow min_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow var_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow med_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow sum_ft": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow kurtosis": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow skew": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow quantile 25": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow quantile 75": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow RMS": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow MAV": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow rmse": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow mae": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow maxerror": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow minerror": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow stderror": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow quantile25e": {
#             "sdtype": "categorical"
#         },
#         "elbow_center_elbow quantile75e": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder mean_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder std_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder max_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder min_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder var_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder med_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder sum_ft": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder kurtosis": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder skew": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder quantile 25": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder quantile 75": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder RMS": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder MAV": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder rmse": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder mae": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder maxerror": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder minerror": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder stderror": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder quantile25e": {
#             "sdtype": "categorical"
#         },
#         "shoulder_center_shoulder quantile75e": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist mean_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist std_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist max_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist min_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist var_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist med_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist sum_ft": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist kurtosis": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist skew": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist quantile 25": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist quantile 75": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist RMS": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist MAV": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist rmse": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist mae": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist maxerror": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist minerror": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist stderror": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist quantile25e": {
#             "sdtype": "categorical"
#         },
#         "wrist_center_wrist quantile75e": {
#             "sdtype": "categorical"
#         },
#         "nose_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "nose_x skew": {
#             "sdtype": "categorical"
#         },
#         "nose_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "nose_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "nose_x RMS": {
#             "sdtype": "categorical"
#         },
#         "nose_x MAV": {
#             "sdtype": "categorical"
#         },
#         "nose_x rmse": {
#             "sdtype": "categorical"
#         },
#         "nose_x mae": {
#             "sdtype": "categorical"
#         },
#         "nose_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "nose_x minerror": {
#             "sdtype": "categorical"
#         },
#         "nose_x stderror": {
#             "sdtype": "categorical"
#         },
#         "nose_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "nose_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "nose_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "nose_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "nose_y skew": {
#             "sdtype": "categorical"
#         },
#         "nose_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "nose_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "nose_y RMS": {
#             "sdtype": "categorical"
#         },
#         "nose_y MAV": {
#             "sdtype": "categorical"
#         },
#         "nose_y rmse": {
#             "sdtype": "categorical"
#         },
#         "nose_y mae": {
#             "sdtype": "categorical"
#         },
#         "nose_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "nose_y minerror": {
#             "sdtype": "categorical"
#         },
#         "nose_y stderror": {
#             "sdtype": "categorical"
#         },
#         "nose_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "nose_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x skew": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x RMS": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x MAV": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x rmse": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x mae": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x minerror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x stderror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_eye_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y skew": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y RMS": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y MAV": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y rmse": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y mae": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y minerror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y stderror": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_eye_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x skew": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x RMS": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x MAV": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x rmse": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x mae": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x minerror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x stderror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_eye_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y skew": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y RMS": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y MAV": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y rmse": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y mae": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y minerror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y stderror": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_eye_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x skew": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x RMS": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x MAV": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x rmse": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x mae": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x minerror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x stderror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_ear_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y skew": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y RMS": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y MAV": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y rmse": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y mae": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y minerror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y stderror": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_ear_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x skew": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x RMS": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x MAV": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x rmse": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x mae": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x minerror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x stderror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_ear_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y skew": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y RMS": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y MAV": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y rmse": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y mae": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y minerror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y stderror": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_ear_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x skew": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x RMS": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x MAV": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x rmse": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x mae": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x minerror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x stderror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y skew": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y RMS": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y MAV": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y rmse": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y mae": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y minerror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y stderror": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_shoulder_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x skew": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x RMS": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x MAV": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x rmse": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x mae": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x minerror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x stderror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y skew": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y RMS": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y MAV": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y rmse": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y mae": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y minerror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y stderror": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_shoulder_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x skew": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x RMS": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x MAV": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x rmse": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x mae": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x minerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x stderror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y skew": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y quantile 75": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y RMS": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y MAV": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y rmse": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y mae": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y maxerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y minerror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y stderror": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y quantile25e": {
#             "sdtype": "categorical"
#         },
#         "left_elbow_y quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x skew": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x quantile 75": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x RMS": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x MAV": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x rmse": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x mae": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x maxerror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x minerror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x stderror": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x quantile25e": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_x quantile75e": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y mean_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y std_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y max_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y min_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y var_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y med_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y sum_ft": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y kurtosis": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y skew": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y quantile 25": {
#             "sdtype": "categorical"
#         },
#         "right_elbow_y quantile 75": {
# ...
#         "movingright_shoulder right_wrist dx stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dx quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dx quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_wrist dy quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dx quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder left_hip dy quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dx quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingright_shoulder right_hip dy quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_x quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y mean_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y std_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y max_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y min_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y var_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y med_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y sum_ft previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y kurtosis previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y skew previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y quantile 25 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y quantile 75 previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y RMS previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y MAV previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y rmse previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y mae previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y maxerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y minerror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y stderror previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y quantile25e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "movingcenter_y quantile75e previous 3 s": {
#             "sdtype": "categorical"
#         },
#         "previous_label": {
#             "sdtype": "numerical"
#         },
#         "label": {
#             "sdtype": "numerical"
#         },
#         "after1": {
#             "sdtype": "numerical"
#         },
#         "after4": {
#             "sdtype": "numerical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }

# %%
model = sdv.lite.SingleTablePreset(name='FAST_ML', metadata=metadata)
model.fit(df_train)
model.save('./fast_ml_model.pkl')
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sdv/single_table/base.py:79: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 model = sdv.lite.SingleTablePreset(name='FAST_ML', metadata=metadata)
# ----> 2 model.fit(df_train)
#       3 model.save('./fast_ml_model.pkl')
#
# File ~/anaconda3/lib/python3.10/site-packages/sdv/lite/single_table.py:75, in SingleTablePreset.fit(self, data)
#      68 def fit(self, data):
#      69     """Fit this model to the data.
#      70
#      71     Args:
#      72         data (pandas.DataFrame):
#      73             Data to fit the model to.
#      74     """
# ---> 75     self._synthesizer.fit(data)
#
# File ~/anaconda3/lib/python3.10/site-packages/sdv/single_table/base.py:395, in BaseSynthesizer.fit(self, data)
#     393 self._data_processor.reset_sampling()
#     394 self._random_state_set = False
# --> 395 processed_data = self._preprocess(data)
#     396 self.fit_processed_data(processed_data)
#
# File ~/anaconda3/lib/python3.10/site-packages/sdv/single_table/base.py:339, in BaseSynthesizer._preprocess(self, data)
#     337 def _preprocess(self, data):
#     338     self.validate(data)
# --> 339     self._data_processor.fit(data)
#     340     return self._data_processor.transform(data)
#
# File ~/anaconda3/lib/python3.10/site-packages/sdv/data_processing/data_processor.py:746, in DataProcessor.fit(self, data)
#     739 """Fit this metadata to the given data.
#     740
#     741 Args:
#     742     data (pandas.DataFrame):
#     743         Table to be analyzed.
#     744 """
#     745 if data.empty:
# --> 746     raise ValueError('The fit dataframe is empty, synthesizer will not be fitted.')
#     747 self._prepared_for_fitting = False
#     748 self.prepare_for_fitting(data)
#
# ValueError: The fit dataframe is empty, synthesizer will not be fitted.

# %%
model.save('./fast_ml_model.pkl')

# %%
model = sdv.lite.SingleTablePreset.load('./fast_ml_model.pkl')

# %%
df_gen=model.sample(num_rows=50000)

# %%
df_gen.to_csv('./SDV_gen_50k.csv')

# %%
df_gen.label.value_counts()
