# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd # data processing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D,Dropout,LSTM, Bidirectional
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.layers import BatchNormalization, Dropout
from keras.layers import Dense, Activation
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import torch
from torch.nn import Transformer
from sklearn.preprocessing import StandardScaler #good
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
from sklearn import metrics #accuracy measure
import joblib
import warnings

# %%
def second_turn(label,dif):
    if label>0:
        return 0
    if label==0:
        return dif

# %%
training_set=os.listdir("./training_set_df_acc_win6/")
df=None
for data in training_set:
    if data.endswith('.csv'):
        file=f"./training_set_df_acc_win6/{data}"
        if df is None:
            df=pd.read_csv(file)
            df=df.astype(float)
            df['previous_label']=df['label']
            
            df['label']=df['label'].astype("category")
            df['previous_label']=df['label']
            df['previous_label']=df['previous_label'].astype(int)
            df['second_turn']=df['previous_label'].diff()
            df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
            turn=list(df['second_turn'])
            turn_2=[]
            
            if (df['label'][0].item()>0): 
                count=2
            else: 
                count=1
            for i in range(len(turn)):

                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            df['turn']=turn
            df['second_turn']=turn_2
            
        else:
            d=pd.read_csv(file)
            d['previous_label']=d['label']
            d['previous_label']=d['previous_label'].astype(int)
            d['label']=d['label'].astype("category")
            d['second_turn']=d['previous_label'].diff()
            d['second_turn']=d.apply(lambda d:second_turn(d['label'],d['second_turn']),axis=1)
            turn=list(d['second_turn'])
            turn_2=[]
            if (d['label'][0].item()>0): 
                count=2
            else: count=1
            for i in range(len(turn)):
                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            d['second_turn']=turn_2
            d['turn']=turn
            df=pd.concat([df,d])
# # turn2
# df['previous_label']=df['label']
# df['second_turn']=df['previous_label'].diff()
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
# turn=list(df['second_turn'])
# turn_2=[]

# if (df['label'][0].item()>0): 
#     count=2
# else: 
#     count=1
# for i in range(len(turn)):

#     if turn[i]<-3:
#         count-=1
#     if count<=0:
#         turn_2.append(1) 
#     else:
#         turn_2.append(0) 
# df['turn']=turn
# df['second_turn']=turn_2

after1=[]
            
# print(list(df['label'])[0])
def fturn():
    if list((df['label'])[0]>0): 
        after0=1
    else: after0=1
    return after0
after0=fturn()
sturn=True
for i in range(len(df.label)):

    if (list(df['label'])[i]==1)|(list(df['label'])[i]==2)|(list(df['label'])[i]==3):
        after0-=1
    if (list(df['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after1.append(1) 
    else:
        after1.append(0) 
df['after1']=after1

# %%
df[['label','second_turn','turn','after1']].to_csv('./check/check.csv')

# %%
df=df.drop(['second_turn','turn'],axis=1)

# %%
# df=df.astype(float)
# df['previous_label']=df['label']
# df['label']=df['label'].astype(int)
# df['label']=df['label'].astype("category")
# df['second_turn']=df['previous_label'].diff
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['dif']))
# turn=list(df['second_turn'])

# %%
# is_2=False
# turn_2=[]
# for i in len(turn):
#     if turn[i]>2:
#         is_2=True
#     if !is_2:
#         return 0
#     return 1
# df['second_turn']=turn_2

# %%
test=pd.read_csv('./test_set_df_acc_win6/S08T1.csv')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3883 entries, 0 to 171
# Data columns (total 2999 columns):
#  #     Column                                             Dtype
# ---    ------                                             -----
#  0     left_elbow_shoulder_hip mean_ft                    float64
#  1     left_elbow_shoulder_hip std_ft                     float64
#  2     left_elbow_shoulder_hip max_ft                     float64
#  3     left_elbow_shoulder_hip min_ft                     float64
#  4     left_elbow_shoulder_hip var_ft                     float64
#  5     left_elbow_shoulder_hip med_ft                     float64
#  6     left_elbow_shoulder_hip sum_ft                     float64
#  7     left_elbow_shoulder_hip std                        float64
#  8     left_elbow_shoulder_hip kurtosis                   float64
#  9     left_elbow_shoulder_hip skew                       float64
#  10    left_elbow_shoulder_hip quantile 25                float64
#  11    left_elbow_shoulder_hip quantile 75                float64
#  12    left_elbow_shoulder_hip RMS                        float64
#  13    left_elbow_shoulder_hip MAV                        float64
#  14    right_elbow_shoulder_hip mean_ft                   float64
#  15    right_elbow_shoulder_hip std_ft                    float64
#  16    right_elbow_shoulder_hip max_ft                    float64
#  17    right_elbow_shoulder_hip min_ft                    float64
#  18    right_elbow_shoulder_hip var_ft                    float64
#  19    right_elbow_shoulder_hip med_ft                    float64
#  20    right_elbow_shoulder_hip sum_ft                    float64
#  21    right_elbow_shoulder_hip std                       float64
#  22    right_elbow_shoulder_hip kurtosis                  float64
#  23    right_elbow_shoulder_hip skew                      float64
#  24    right_elbow_shoulder_hip quantile 25               float64
#  25    right_elbow_shoulder_hip quantile 75               float64
#  26    right_elbow_shoulder_hip RMS                       float64
#  27    right_elbow_shoulder_hip MAV                       float64
#  28    left_wrist_elbow_shoulder mean_ft                  float64
#  29    left_wrist_elbow_shoulder std_ft                   float64
#  30    left_wrist_elbow_shoulder max_ft                   float64
#  31    left_wrist_elbow_shoulder min_ft                   float64
#  32    left_wrist_elbow_shoulder var_ft                   float64
#  33    left_wrist_elbow_shoulder med_ft                   float64
#  34    left_wrist_elbow_shoulder sum_ft                   float64
#  35    left_wrist_elbow_shoulder std                      float64
#  36    left_wrist_elbow_shoulder kurtosis                 float64
#  37    left_wrist_elbow_shoulder skew                     float64
#  38    left_wrist_elbow_shoulder quantile 25              float64
#  39    left_wrist_elbow_shoulder quantile 75              float64
#  40    left_wrist_elbow_shoulder RMS                      float64
#  41    left_wrist_elbow_shoulder MAV                      float64
#  42    right_wrist_elbow_shoulder mean_ft                 float64
#  43    right_wrist_elbow_shoulder std_ft                  float64
#  44    right_wrist_elbow_shoulder max_ft                  float64
#  45    right_wrist_elbow_shoulder min_ft                  float64
#  46    right_wrist_elbow_shoulder var_ft                  float64
#  47    right_wrist_elbow_shoulder med_ft                  float64
#  48    right_wrist_elbow_shoulder sum_ft                  float64
#  49    right_wrist_elbow_shoulder std                     float64
#  50    right_wrist_elbow_shoulder kurtosis                float64
#  51    right_wrist_elbow_shoulder skew                    float64
#  52    right_wrist_elbow_shoulder quantile 25             float64
#  53    right_wrist_elbow_shoulder quantile 75             float64
#  54    right_wrist_elbow_shoulder RMS                     float64
#  55    right_wrist_elbow_shoulder MAV                     float64
#  56     right_elbow_shoulder mean_ft                      float64
#  57     right_elbow_shoulder std_ft                       float64
#  58     right_elbow_shoulder max_ft                       float64
#  59     right_elbow_shoulder min_ft                       float64
#  60     right_elbow_shoulder var_ft                       float64
#  61     right_elbow_shoulder med_ft                       float64
#  62     right_elbow_shoulder sum_ft                       float64
#  63     right_elbow_shoulder std                          float64
#  64     right_elbow_shoulder kurtosis                     float64
#  65     right_elbow_shoulder skew                         float64
#  66     right_elbow_shoulder quantile 25                  float64
#  67     right_elbow_shoulder quantile 75                  float64
#  68     right_elbow_shoulder RMS                          float64
#  69     right_elbow_shoulder MAV                          float64
#  70    left_elbow_shoulder mean_ft                        float64
#  71    left_elbow_shoulder std_ft                         float64
#  72    left_elbow_shoulder max_ft                         float64
#  73    left_elbow_shoulder min_ft                         float64
#  74    left_elbow_shoulder var_ft                         float64
#  75    left_elbow_shoulder med_ft                         float64
#  76    left_elbow_shoulder sum_ft                         float64
#  77    left_elbow_shoulder std                            float64
#  78    left_elbow_shoulder kurtosis                       float64
#  79    left_elbow_shoulder skew                           float64
#  80    left_elbow_shoulder quantile 25                    float64
#  81    left_elbow_shoulder quantile 75                    float64
#  82    left_elbow_shoulder RMS                            float64
#  83    left_elbow_shoulder MAV                            float64
#  84    nose_x mean_ft                                     float64
#  85    nose_x std_ft                                      float64
#  86    nose_x max_ft                                      float64
#  87    nose_x min_ft                                      float64
#  88    nose_x var_ft                                      float64
#  89    nose_x med_ft                                      float64
#  90    nose_x sum_ft                                      float64
#  91    nose_x std                                         float64
#  92    nose_x kurtosis                                    float64
#  93    nose_x skew                                        float64
#  94    nose_x quantile 25                                 float64
#  95    nose_x quantile 75                                 float64
#  96    nose_x RMS                                         float64
#  97    nose_x MAV                                         float64
#  98    nose_y mean_ft                                     float64
#  99    nose_y std_ft                                      float64
#  100   nose_y max_ft                                      float64
#  101   nose_y min_ft                                      float64
#  102   nose_y var_ft                                      float64
#  103   nose_y med_ft                                      float64
#  104   nose_y sum_ft                                      float64
#  105   nose_y std                                         float64
#  106   nose_y kurtosis                                    float64
#  107   nose_y skew                                        float64
#  108   nose_y quantile 25                                 float64
#  109   nose_y quantile 75                                 float64
#  110   nose_y RMS                                         float64
#  111   nose_y MAV                                         float64
#  112   left_eye_x mean_ft                                 float64
#  113   left_eye_x std_ft                                  float64
#  114   left_eye_x max_ft                                  float64
#  115   left_eye_x min_ft                                  float64
#  116   left_eye_x var_ft                                  float64
#  117   left_eye_x med_ft                                  float64
#  118   left_eye_x sum_ft                                  float64
#  119   left_eye_x std                                     float64
#  120   left_eye_x kurtosis                                float64
#  121   left_eye_x skew                                    float64
#  122   left_eye_x quantile 25                             float64
#  123   left_eye_x quantile 75                             float64
#  124   left_eye_x RMS                                     float64
#  125   left_eye_x MAV                                     float64
#  126   left_eye_y mean_ft                                 float64
#  127   left_eye_y std_ft                                  float64
#  128   left_eye_y max_ft                                  float64
#  129   left_eye_y min_ft                                  float64
#  130   left_eye_y var_ft                                  float64
#  131   left_eye_y med_ft                                  float64
#  132   left_eye_y sum_ft                                  float64
#  133   left_eye_y std                                     float64
#  134   left_eye_y kurtosis                                float64
#  135   left_eye_y skew                                    float64
#  136   left_eye_y quantile 25                             float64
#  137   left_eye_y quantile 75                             float64
#  138   left_eye_y RMS                                     float64
#  139   left_eye_y MAV                                     float64
#  140   right_eye_x mean_ft                                float64
#  141   right_eye_x std_ft                                 float64
#  142   right_eye_x max_ft                                 float64
#  143   right_eye_x min_ft                                 float64
#  144   right_eye_x var_ft                                 float64
#  145   right_eye_x med_ft                                 float64
#  146   right_eye_x sum_ft                                 float64
#  147   right_eye_x std                                    float64
#  148   right_eye_x kurtosis                               float64
#  149   right_eye_x skew                                   float64
#  150   right_eye_x quantile 25                            float64
#  151   right_eye_x quantile 75                            float64
#  152   right_eye_x RMS                                    float64
#  153   right_eye_x MAV                                    float64
#  154   right_eye_y mean_ft                                float64
#  155   right_eye_y std_ft                                 float64
#  156   right_eye_y max_ft                                 float64
#  157   right_eye_y min_ft                                 float64
#  158   right_eye_y var_ft                                 float64
#  159   right_eye_y med_ft                                 float64
#  160   right_eye_y sum_ft                                 float64
#  161   right_eye_y std                                    float64
#  162   right_eye_y kurtosis                               float64
#  163   right_eye_y skew                                   float64
#  164   right_eye_y quantile 25                            float64
#  165   right_eye_y quantile 75                            float64
#  166   right_eye_y RMS                                    float64
#  167   right_eye_y MAV                                    float64
#  168   left_ear_x mean_ft                                 float64
#  169   left_ear_x std_ft                                  float64
#  170   left_ear_x max_ft                                  float64
#  171   left_ear_x min_ft                                  float64
#  172   left_ear_x var_ft                                  float64
#  173   left_ear_x med_ft                                  float64
#  174   left_ear_x sum_ft                                  float64
#  175   left_ear_x std                                     float64
#  176   left_ear_x kurtosis                                float64
#  177   left_ear_x skew                                    float64
#  178   left_ear_x quantile 25                             float64
#  179   left_ear_x quantile 75                             float64
#  180   left_ear_x RMS                                     float64
#  181   left_ear_x MAV                                     float64
#  182   left_ear_y mean_ft                                 float64
#  183   left_ear_y std_ft                                  float64
#  184   left_ear_y max_ft                                  float64
#  185   left_ear_y min_ft                                  float64
#  186   left_ear_y var_ft                                  float64
#  187   left_ear_y med_ft                                  float64
#  188   left_ear_y sum_ft                                  float64
#  189   left_ear_y std                                     float64
#  190   left_ear_y kurtosis                                float64
#  191   left_ear_y skew                                    float64
#  192   left_ear_y quantile 25                             float64
#  193   left_ear_y quantile 75                             float64
#  194   left_ear_y RMS                                     float64
#  195   left_ear_y MAV                                     float64
#  196   right_ear_x mean_ft                                float64
#  197   right_ear_x std_ft                                 float64
#  198   right_ear_x max_ft                                 float64
#  199   right_ear_x min_ft                                 float64
#  200   right_ear_x var_ft                                 float64
#  201   right_ear_x med_ft                                 float64
#  202   right_ear_x sum_ft                                 float64
#  203   right_ear_x std                                    float64
#  204   right_ear_x kurtosis                               float64
#  205   right_ear_x skew                                   float64
#  206   right_ear_x quantile 25                            float64
#  207   right_ear_x quantile 75                            float64
#  208   right_ear_x RMS                                    float64
#  209   right_ear_x MAV                                    float64
#  210   right_ear_y mean_ft                                float64
#  211   right_ear_y std_ft                                 float64
#  212   right_ear_y max_ft                                 float64
#  213   right_ear_y min_ft                                 float64
#  214   right_ear_y var_ft                                 float64
#  215   right_ear_y med_ft                                 float64
#  216   right_ear_y sum_ft                                 float64
#  217   right_ear_y std                                    float64
#  218   right_ear_y kurtosis                               float64
#  219   right_ear_y skew                                   float64
#  220   right_ear_y quantile 25                            float64
#  221   right_ear_y quantile 75                            float64
#  222   right_ear_y RMS                                    float64
#  223   right_ear_y MAV                                    float64
#  224   left_shoulder_x mean_ft                            float64
#  225   left_shoulder_x std_ft                             float64
#  226   left_shoulder_x max_ft                             float64
#  227   left_shoulder_x min_ft                             float64
#  228   left_shoulder_x var_ft                             float64
#  229   left_shoulder_x med_ft                             float64
#  230   left_shoulder_x sum_ft                             float64
#  231   left_shoulder_x std                                float64
#  232   left_shoulder_x kurtosis                           float64
#  233   left_shoulder_x skew                               float64
#  234   left_shoulder_x quantile 25                        float64
#  235   left_shoulder_x quantile 75                        float64
#  236   left_shoulder_x RMS                                float64
#  237   left_shoulder_x MAV                                float64
#  238   left_shoulder_y mean_ft                            float64
#  239   left_shoulder_y std_ft                             float64
#  240   left_shoulder_y max_ft                             float64
#  241   left_shoulder_y min_ft                             float64
#  242   left_shoulder_y var_ft                             float64
#  243   left_shoulder_y med_ft                             float64
#  244   left_shoulder_y sum_ft                             float64
#  245   left_shoulder_y std                                float64
#  246   left_shoulder_y kurtosis                           float64
#  247   left_shoulder_y skew                               float64
#  248   left_shoulder_y quantile 25                        float64
#  249   left_shoulder_y quantile 75                        float64
#  250   left_shoulder_y RMS                                float64
#  251   left_shoulder_y MAV                                float64
#  252   right_shoulder_x mean_ft                           float64
#  253   right_shoulder_x std_ft                            float64
#  254   right_shoulder_x max_ft                            float64
#  255   right_shoulder_x min_ft                            float64
#  256   right_shoulder_x var_ft                            float64
#  257   right_shoulder_x med_ft                            float64
#  258   right_shoulder_x sum_ft                            float64
#  259   right_shoulder_x std                               float64
#  260   right_shoulder_x kurtosis                          float64
#  261   right_shoulder_x skew                              float64
#  262   right_shoulder_x quantile 25                       float64
#  263   right_shoulder_x quantile 75                       float64
#  264   right_shoulder_x RMS                               float64
#  265   right_shoulder_x MAV                               float64
#  266   right_shoulder_y mean_ft                           float64
#  267   right_shoulder_y std_ft                            float64
#  268   right_shoulder_y max_ft                            float64
#  269   right_shoulder_y min_ft                            float64
#  270   right_shoulder_y var_ft                            float64
#  271   right_shoulder_y med_ft                            float64
#  272   right_shoulder_y sum_ft                            float64
#  273   right_shoulder_y std                               float64
#  274   right_shoulder_y kurtosis                          float64
#  275   right_shoulder_y skew                              float64
#  276   right_shoulder_y quantile 25                       float64
#  277   right_shoulder_y quantile 75                       float64
#  278   right_shoulder_y RMS                               float64
#  279   right_shoulder_y MAV                               float64
#  280   left_elbow_x mean_ft                               float64
#  281   left_elbow_x std_ft                                float64
#  282   left_elbow_x max_ft                                float64
#  283   left_elbow_x min_ft                                float64
#  284   left_elbow_x var_ft                                float64
#  285   left_elbow_x med_ft                                float64
#  286   left_elbow_x sum_ft                                float64
#  287   left_elbow_x std                                   float64
#  288   left_elbow_x kurtosis                              float64
#  289   left_elbow_x skew                                  float64
#  290   left_elbow_x quantile 25                           float64
#  291   left_elbow_x quantile 75                           float64
#  292   left_elbow_x RMS                                   float64
#  293   left_elbow_x MAV                                   float64
#  294   left_elbow_y mean_ft                               float64
#  295   left_elbow_y std_ft                                float64
#  296   left_elbow_y max_ft                                float64
#  297   left_elbow_y min_ft                                float64
#  298   left_elbow_y var_ft                                float64
#  299   left_elbow_y med_ft                                float64
#  300   left_elbow_y sum_ft                                float64
#  301   left_elbow_y std                                   float64
#  302   left_elbow_y kurtosis                              float64
#  303   left_elbow_y skew                                  float64
#  304   left_elbow_y quantile 25                           float64
#  305   left_elbow_y quantile 75                           float64
#  306   left_elbow_y RMS                                   float64
#  307   left_elbow_y MAV                                   float64
#  308   right_elbow_x mean_ft                              float64
#  309   right_elbow_x std_ft                               float64
#  310   right_elbow_x max_ft                               float64
#  311   right_elbow_x min_ft                               float64
#  312   right_elbow_x var_ft                               float64
#  313   right_elbow_x med_ft                               float64
#  314   right_elbow_x sum_ft                               float64
#  315   right_elbow_x std                                  float64
#  316   right_elbow_x kurtosis                             float64
#  317   right_elbow_x skew                                 float64
#  318   right_elbow_x quantile 25                          float64
#  319   right_elbow_x quantile 75                          float64
#  320   right_elbow_x RMS                                  float64
#  321   right_elbow_x MAV                                  float64
#  322   right_elbow_y mean_ft                              float64
#  323   right_elbow_y std_ft                               float64
#  324   right_elbow_y max_ft                               float64
#  325   right_elbow_y min_ft                               float64
#  326   right_elbow_y var_ft                               float64
#  327   right_elbow_y med_ft                               float64
#  328   right_elbow_y sum_ft                               float64
#  329   right_elbow_y std                                  float64
#  330   right_elbow_y kurtosis                             float64
#  331   right_elbow_y skew                                 float64
#  332   right_elbow_y quantile 25                          float64
#  333   right_elbow_y quantile 75                          float64
#  334   right_elbow_y RMS                                  float64
#  335   right_elbow_y MAV                                  float64
#  336   left_wrist_x mean_ft                               float64
#  337   left_wrist_x std_ft                                float64
#  338   left_wrist_x max_ft                                float64
#  339   left_wrist_x min_ft                                float64
#  340   left_wrist_x var_ft                                float64
#  341   left_wrist_x med_ft                                float64
#  342   left_wrist_x sum_ft                                float64
#  343   left_wrist_x std                                   float64
#  344   left_wrist_x kurtosis                              float64
#  345   left_wrist_x skew                                  float64
#  346   left_wrist_x quantile 25                           float64
#  347   left_wrist_x quantile 75                           float64
#  348   left_wrist_x RMS                                   float64
#  349   left_wrist_x MAV                                   float64
#  350   left_wrist_y mean_ft                               float64
#  351   left_wrist_y std_ft                                float64
#  352   left_wrist_y max_ft                                float64
#  353   left_wrist_y min_ft                                float64
#  354   left_wrist_y var_ft                                float64
#  355   left_wrist_y med_ft                                float64
#  356   left_wrist_y sum_ft                                float64
#  357   left_wrist_y std                                   float64
#  358   left_wrist_y kurtosis                              float64
#  359   left_wrist_y skew                                  float64
#  360   left_wrist_y quantile 25                           float64
#  361   left_wrist_y quantile 75                           float64
#  362   left_wrist_y RMS                                   float64
#  363   left_wrist_y MAV                                   float64
#  364   right_wrist_x mean_ft                              float64
#  365   right_wrist_x std_ft                               float64
#  366   right_wrist_x max_ft                               float64
#  367   right_wrist_x min_ft                               float64
#  368   right_wrist_x var_ft                               float64
#  369   right_wrist_x med_ft                               float64
#  370   right_wrist_x sum_ft                               float64
#  371   right_wrist_x std                                  float64
#  372   right_wrist_x kurtosis                             float64
#  373   right_wrist_x skew                                 float64
#  374   right_wrist_x quantile 25                          float64
#  375   right_wrist_x quantile 75                          float64
#  376   right_wrist_x RMS                                  float64
#  377   right_wrist_x MAV                                  float64
#  378   right_wrist_y mean_ft                              float64
#  379   right_wrist_y std_ft                               float64
#  380   right_wrist_y max_ft                               float64
#  381   right_wrist_y min_ft                               float64
#  382   right_wrist_y var_ft                               float64
#  383   right_wrist_y med_ft                               float64
#  384   right_wrist_y sum_ft                               float64
#  385   right_wrist_y std                                  float64
#  386   right_wrist_y kurtosis                             float64
#  387   right_wrist_y skew                                 float64
#  388   right_wrist_y quantile 25                          float64
#  389   right_wrist_y quantile 75                          float64
#  390   right_wrist_y RMS                                  float64
#  391   right_wrist_y MAV                                  float64
#  392   left_hip_x mean_ft                                 float64
#  393   left_hip_x std_ft                                  float64
#  394   left_hip_x max_ft                                  float64
#  395   left_hip_x min_ft                                  float64
#  396   left_hip_x var_ft                                  float64
#  397   left_hip_x med_ft                                  float64
#  398   left_hip_x sum_ft                                  float64
#  399   left_hip_x std                                     float64
#  400   left_hip_x kurtosis                                float64
#  401   left_hip_x skew                                    float64
#  402   left_hip_x quantile 25                             float64
#  403   left_hip_x quantile 75                             float64
#  404   left_hip_x RMS                                     float64
#  405   left_hip_x MAV                                     float64
#  406   left_hip_y mean_ft                                 float64
#  407   left_hip_y std_ft                                  float64
#  408   left_hip_y max_ft                                  float64
#  409   left_hip_y min_ft                                  float64
#  410   left_hip_y var_ft                                  float64
#  411   left_hip_y med_ft                                  float64
#  412   left_hip_y sum_ft                                  float64
#  413   left_hip_y std                                     float64
#  414   left_hip_y kurtosis                                float64
#  415   left_hip_y skew                                    float64
#  416   left_hip_y quantile 25                             float64
#  417   left_hip_y quantile 75                             float64
#  418   left_hip_y RMS                                     float64
#  419   left_hip_y MAV                                     float64
#  420   right_hip_x mean_ft                                float64
#  421   right_hip_x std_ft                                 float64
#  422   right_hip_x max_ft                                 float64
#  423   right_hip_x min_ft                                 float64
#  424   right_hip_x var_ft                                 float64
#  425   right_hip_x med_ft                                 float64
#  426   right_hip_x sum_ft                                 float64
#  427   right_hip_x std                                    float64
#  428   right_hip_x kurtosis                               float64
#  429   right_hip_x skew                                   float64
#  430   right_hip_x quantile 25                            float64
#  431   right_hip_x quantile 75                            float64
#  432   right_hip_x RMS                                    float64
#  433   right_hip_x MAV                                    float64
#  434   right_hip_y mean_ft                                float64
#  435   right_hip_y std_ft                                 float64
#  436   right_hip_y max_ft                                 float64
#  437   right_hip_y min_ft                                 float64
#  438   right_hip_y var_ft                                 float64
#  439   right_hip_y med_ft                                 float64
#  440   right_hip_y sum_ft                                 float64
#  441   right_hip_y std                                    float64
#  442   right_hip_y kurtosis                               float64
#  443   right_hip_y skew                                   float64
#  444   right_hip_y quantile 25                            float64
#  445   right_hip_y quantile 75                            float64
#  446   right_hip_y RMS                                    float64
#  447   right_hip_y MAV                                    float64
#  448   right_shoulder nose dx mean_ft                     float64
#  449   right_shoulder nose dx std_ft                      float64
#  450   right_shoulder nose dx max_ft                      float64
#  451   right_shoulder nose dx min_ft                      float64
#  452   right_shoulder nose dx var_ft                      float64
#  453   right_shoulder nose dx med_ft                      float64
#  454   right_shoulder nose dx sum_ft                      float64
#  455   right_shoulder nose dx std                         float64
#  456   right_shoulder nose dx kurtosis                    float64
#  457   right_shoulder nose dx skew                        float64
#  458   right_shoulder nose dx quantile 25                 float64
#  459   right_shoulder nose dx quantile 75                 float64
#  460   right_shoulder nose dx RMS                         float64
#  461   right_shoulder nose dx MAV                         float64
#  462   right_shoulder nose dy mean_ft                     float64
#  463   right_shoulder nose dy std_ft                      float64
#  464   right_shoulder nose dy max_ft                      float64
#  465   right_shoulder nose dy min_ft                      float64
#  466   right_shoulder nose dy var_ft                      float64
#  467   right_shoulder nose dy med_ft                      float64
#  468   right_shoulder nose dy sum_ft                      float64
#  469   right_shoulder nose dy std                         float64
#  470   right_shoulder nose dy kurtosis                    float64
#  471   right_shoulder nose dy skew                        float64
#  472   right_shoulder nose dy quantile 25                 float64
#  473   right_shoulder nose dy quantile 75                 float64
#  474   right_shoulder nose dy RMS                         float64
#  475   right_shoulder nose dy MAV                         float64
#  476   right_shoulder left_eye dx mean_ft                 float64
#  477   right_shoulder left_eye dx std_ft                  float64
#  478   right_shoulder left_eye dx max_ft                  float64
#  479   right_shoulder left_eye dx min_ft                  float64
#  480   right_shoulder left_eye dx var_ft                  float64
#  481   right_shoulder left_eye dx med_ft                  float64
#  482   right_shoulder left_eye dx sum_ft                  float64
#  483   right_shoulder left_eye dx std                     float64
#  484   right_shoulder left_eye dx kurtosis                float64
#  485   right_shoulder left_eye dx skew                    float64
#  486   right_shoulder left_eye dx quantile 25             float64
#  487   right_shoulder left_eye dx quantile 75             float64
#  488   right_shoulder left_eye dx RMS                     float64
#  489   right_shoulder left_eye dx MAV                     float64
#  490   right_shoulder left_eye dy mean_ft                 float64
#  491   right_shoulder left_eye dy std_ft                  float64
#  492   right_shoulder left_eye dy max_ft                  float64
#  493   right_shoulder left_eye dy min_ft                  float64
#  494   right_shoulder left_eye dy var_ft                  float64
#  495   right_shoulder left_eye dy med_ft                  float64
#  496   right_shoulder left_eye dy sum_ft                  float64
#  497   right_shoulder left_eye dy std                     float64
#  498   right_shoulder left_eye dy kurtosis                float64
#  499   right_shoulder left_eye dy skew                    float64
#  500   right_shoulder left_eye dy quantile 25             float64
#  501   right_shoulder left_eye dy quantile 75             float64
#  502   right_shoulder left_eye dy RMS                     float64
#  503   right_shoulder left_eye dy MAV                     float64
#  504   right_shoulder right_eye dx mean_ft                float64
#  505   right_shoulder right_eye dx std_ft                 float64
#  506   right_shoulder right_eye dx max_ft                 float64
#  507   right_shoulder right_eye dx min_ft                 float64
#  508   right_shoulder right_eye dx var_ft                 float64
#  509   right_shoulder right_eye dx med_ft                 float64
#  510   right_shoulder right_eye dx sum_ft                 float64
#  511   right_shoulder right_eye dx std                    float64
#  512   right_shoulder right_eye dx kurtosis               float64
#  513   right_shoulder right_eye dx skew                   float64
#  514   right_shoulder right_eye dx quantile 25            float64
#  515   right_shoulder right_eye dx quantile 75            float64
#  516   right_shoulder right_eye dx RMS                    float64
#  517   right_shoulder right_eye dx MAV                    float64
#  518   right_shoulder right_eye dy mean_ft                float64
#  519   right_shoulder right_eye dy std_ft                 float64
#  520   right_shoulder right_eye dy max_ft                 float64
#  521   right_shoulder right_eye dy min_ft                 float64
#  522   right_shoulder right_eye dy var_ft                 float64
#  523   right_shoulder right_eye dy med_ft                 float64
#  524   right_shoulder right_eye dy sum_ft                 float64
#  525   right_shoulder right_eye dy std                    float64
#  526   right_shoulder right_eye dy kurtosis               float64
#  527   right_shoulder right_eye dy skew                   float64
#  528   right_shoulder right_eye dy quantile 25            float64
#  529   right_shoulder right_eye dy quantile 75            float64
#  530   right_shoulder right_eye dy RMS                    float64
#  531   right_shoulder right_eye dy MAV                    float64
#  532   right_shoulder left_ear dx mean_ft                 float64
#  533   right_shoulder left_ear dx std_ft                  float64
#  534   right_shoulder left_ear dx max_ft                  float64
#  535   right_shoulder left_ear dx min_ft                  float64
#  536   right_shoulder left_ear dx var_ft                  float64
#  537   right_shoulder left_ear dx med_ft                  float64
#  538   right_shoulder left_ear dx sum_ft                  float64
#  539   right_shoulder left_ear dx std                     float64
#  540   right_shoulder left_ear dx kurtosis                float64
#  541   right_shoulder left_ear dx skew                    float64
#  542   right_shoulder left_ear dx quantile 25             float64
#  543   right_shoulder left_ear dx quantile 75             float64
#  544   right_shoulder left_ear dx RMS                     float64
#  545   right_shoulder left_ear dx MAV                     float64
#  546   right_shoulder left_ear dy mean_ft                 float64
#  547   right_shoulder left_ear dy std_ft                  float64
#  548   right_shoulder left_ear dy max_ft                  float64
#  549   right_shoulder left_ear dy min_ft                  float64
#  550   right_shoulder left_ear dy var_ft                  float64
#  551   right_shoulder left_ear dy med_ft                  float64
#  552   right_shoulder left_ear dy sum_ft                  float64
#  553   right_shoulder left_ear dy std                     float64
#  554   right_shoulder left_ear dy kurtosis                float64
#  555   right_shoulder left_ear dy skew                    float64
#  556   right_shoulder left_ear dy quantile 25             float64
#  557   right_shoulder left_ear dy quantile 75             float64
#  558   right_shoulder left_ear dy RMS                     float64
#  559   right_shoulder left_ear dy MAV                     float64
#  560   right_shoulder right_ear dx mean_ft                float64
#  561   right_shoulder right_ear dx std_ft                 float64
#  562   right_shoulder right_ear dx max_ft                 float64
#  563   right_shoulder right_ear dx min_ft                 float64
#  564   right_shoulder right_ear dx var_ft                 float64
#  565   right_shoulder right_ear dx med_ft                 float64
#  566   right_shoulder right_ear dx sum_ft                 float64
#  567   right_shoulder right_ear dx std                    float64
#  568   right_shoulder right_ear dx kurtosis               float64
#  569   right_shoulder right_ear dx skew                   float64
#  570   right_shoulder right_ear dx quantile 25            float64
#  571   right_shoulder right_ear dx quantile 75            float64
#  572   right_shoulder right_ear dx RMS                    float64
#  573   right_shoulder right_ear dx MAV                    float64
#  574   right_shoulder right_ear dy mean_ft                float64
#  575   right_shoulder right_ear dy std_ft                 float64
#  576   right_shoulder right_ear dy max_ft                 float64
#  577   right_shoulder right_ear dy min_ft                 float64
#  578   right_shoulder right_ear dy var_ft                 float64
#  579   right_shoulder right_ear dy med_ft                 float64
#  580   right_shoulder right_ear dy sum_ft                 float64
#  581   right_shoulder right_ear dy std                    float64
#  582   right_shoulder right_ear dy kurtosis               float64
#  583   right_shoulder right_ear dy skew                   float64
#  584   right_shoulder right_ear dy quantile 25            float64
#  585   right_shoulder right_ear dy quantile 75            float64
#  586   right_shoulder right_ear dy RMS                    float64
#  587   right_shoulder right_ear dy MAV                    float64
#  588   right_shoulder left_shoulder dx mean_ft            float64
#  589   right_shoulder left_shoulder dx std_ft             float64
#  590   right_shoulder left_shoulder dx max_ft             float64
#  591   right_shoulder left_shoulder dx min_ft             float64
#  592   right_shoulder left_shoulder dx var_ft             float64
#  593   right_shoulder left_shoulder dx med_ft             float64
#  594   right_shoulder left_shoulder dx sum_ft             float64
#  595   right_shoulder left_shoulder dx std                float64
#  596   right_shoulder left_shoulder dx kurtosis           float64
#  597   right_shoulder left_shoulder dx skew               float64
#  598   right_shoulder left_shoulder dx quantile 25        float64
#  599   right_shoulder left_shoulder dx quantile 75        float64
#  600   right_shoulder left_shoulder dx RMS                float64
#  601   right_shoulder left_shoulder dx MAV                float64
#  602   right_shoulder left_shoulder dy mean_ft            float64
#  603   right_shoulder left_shoulder dy std_ft             float64
#  604   right_shoulder left_shoulder dy max_ft             float64
#  605   right_shoulder left_shoulder dy min_ft             float64
#  606   right_shoulder left_shoulder dy var_ft             float64
#  607   right_shoulder left_shoulder dy med_ft             float64
#  608   right_shoulder left_shoulder dy sum_ft             float64
#  609   right_shoulder left_shoulder dy std                float64
#  610   right_shoulder left_shoulder dy kurtosis           float64
#  611   right_shoulder left_shoulder dy skew               float64
#  612   right_shoulder left_shoulder dy quantile 25        float64
#  613   right_shoulder left_shoulder dy quantile 75        float64
#  614   right_shoulder left_shoulder dy RMS                float64
#  615   right_shoulder left_shoulder dy MAV                float64
#  616   right_shoulder left_elbow dx mean_ft               float64
#  617   right_shoulder left_elbow dx std_ft                float64
#  618   right_shoulder left_elbow dx max_ft                float64
#  619   right_shoulder left_elbow dx min_ft                float64
#  620   right_shoulder left_elbow dx var_ft                float64
#  621   right_shoulder left_elbow dx med_ft                float64
#  622   right_shoulder left_elbow dx sum_ft                float64
#  623   right_shoulder left_elbow dx std                   float64
#  624   right_shoulder left_elbow dx kurtosis              float64
#  625   right_shoulder left_elbow dx skew                  float64
#  626   right_shoulder left_elbow dx quantile 25           float64
#  627   right_shoulder left_elbow dx quantile 75           float64
#  628   right_shoulder left_elbow dx RMS                   float64
#  629   right_shoulder left_elbow dx MAV                   float64
#  630   right_shoulder left_elbow dy mean_ft               float64
#  631   right_shoulder left_elbow dy std_ft                float64
#  632   right_shoulder left_elbow dy max_ft                float64
#  633   right_shoulder left_elbow dy min_ft                float64
#  634   right_shoulder left_elbow dy var_ft                float64
#  635   right_shoulder left_elbow dy med_ft                float64
#  636   right_shoulder left_elbow dy sum_ft                float64
#  637   right_shoulder left_elbow dy std                   float64
#  638   right_shoulder left_elbow dy kurtosis              float64
#  639   right_shoulder left_elbow dy skew                  float64
#  640   right_shoulder left_elbow dy quantile 25           float64
#  641   right_shoulder left_elbow dy quantile 75           float64
#  642   right_shoulder left_elbow dy RMS                   float64
#  643   right_shoulder left_elbow dy MAV                   float64
#  644   right_shoulder right_elbow dx mean_ft              float64
#  645   right_shoulder right_elbow dx std_ft               float64
#  646   right_shoulder right_elbow dx max_ft               float64
#  647   right_shoulder right_elbow dx min_ft               float64
#  648   right_shoulder right_elbow dx var_ft               float64
#  649   right_shoulder right_elbow dx med_ft               float64
#  650   right_shoulder right_elbow dx sum_ft               float64
#  651   right_shoulder right_elbow dx std                  float64
#  652   right_shoulder right_elbow dx kurtosis             float64
#  653   right_shoulder right_elbow dx skew                 float64
#  654   right_shoulder right_elbow dx quantile 25          float64
#  655   right_shoulder right_elbow dx quantile 75          float64
#  656   right_shoulder right_elbow dx RMS                  float64
#  657   right_shoulder right_elbow dx MAV                  float64
#  658   right_shoulder right_elbow dy mean_ft              float64
#  659   right_shoulder right_elbow dy std_ft               float64
#  660   right_shoulder right_elbow dy max_ft               float64
#  661   right_shoulder right_elbow dy min_ft               float64
#  662   right_shoulder right_elbow dy var_ft               float64
#  663   right_shoulder right_elbow dy med_ft               float64
#  664   right_shoulder right_elbow dy sum_ft               float64
#  665   right_shoulder right_elbow dy std                  float64
#  666   right_shoulder right_elbow dy kurtosis             float64
#  667   right_shoulder right_elbow dy skew                 float64
#  668   right_shoulder right_elbow dy quantile 25          float64
#  669   right_shoulder right_elbow dy quantile 75          float64
#  670   right_shoulder right_elbow dy RMS                  float64
#  671   right_shoulder right_elbow dy MAV                  float64
#  672   right_shoulder left_wrist dx mean_ft               float64
#  673   right_shoulder left_wrist dx std_ft                float64
#  674   right_shoulder left_wrist dx max_ft                float64
#  675   right_shoulder left_wrist dx min_ft                float64
#  676   right_shoulder left_wrist dx var_ft                float64
#  677   right_shoulder left_wrist dx med_ft                float64
#  678   right_shoulder left_wrist dx sum_ft                float64
#  679   right_shoulder left_wrist dx std                   float64
#  680   right_shoulder left_wrist dx kurtosis              float64
#  681   right_shoulder left_wrist dx skew                  float64
#  682   right_shoulder left_wrist dx quantile 25           float64
#  683   right_shoulder left_wrist dx quantile 75           float64
#  684   right_shoulder left_wrist dx RMS                   float64
#  685   right_shoulder left_wrist dx MAV                   float64
#  686   right_shoulder left_wrist dy mean_ft               float64
#  687   right_shoulder left_wrist dy std_ft                float64
#  688   right_shoulder left_wrist dy max_ft                float64
#  689   right_shoulder left_wrist dy min_ft                float64
#  690   right_shoulder left_wrist dy var_ft                float64
#  691   right_shoulder left_wrist dy med_ft                float64
#  692   right_shoulder left_wrist dy sum_ft                float64
#  693   right_shoulder left_wrist dy std                   float64
#  694   right_shoulder left_wrist dy kurtosis              float64
#  695   right_shoulder left_wrist dy skew                  float64
#  696   right_shoulder left_wrist dy quantile 25           float64
#  697   right_shoulder left_wrist dy quantile 75           float64
#  698   right_shoulder left_wrist dy RMS                   float64
#  699   right_shoulder left_wrist dy MAV                   float64
#  700   right_shoulder right_wrist dx mean_ft              float64
#  701   right_shoulder right_wrist dx std_ft               float64
#  702   right_shoulder right_wrist dx max_ft               float64
#  703   right_shoulder right_wrist dx min_ft               float64
#  704   right_shoulder right_wrist dx var_ft               float64
#  705   right_shoulder right_wrist dx med_ft               float64
#  706   right_shoulder right_wrist dx sum_ft               float64
#  707   right_shoulder right_wrist dx std                  float64
#  708   right_shoulder right_wrist dx kurtosis             float64
#  709   right_shoulder right_wrist dx skew                 float64
#  710   right_shoulder right_wrist dx quantile 25          float64
#  711   right_shoulder right_wrist dx quantile 75          float64
#  712   right_shoulder right_wrist dx RMS                  float64
#  713   right_shoulder right_wrist dx MAV                  float64
#  714   right_shoulder right_wrist dy mean_ft              float64
#  715   right_shoulder right_wrist dy std_ft               float64
#  716   right_shoulder right_wrist dy max_ft               float64
#  717   right_shoulder right_wrist dy min_ft               float64
#  718   right_shoulder right_wrist dy var_ft               float64
#  719   right_shoulder right_wrist dy med_ft               float64
#  720   right_shoulder right_wrist dy sum_ft               float64
#  721   right_shoulder right_wrist dy std                  float64
#  722   right_shoulder right_wrist dy kurtosis             float64
# ...
#  2758  movingright_shoulder right_ear dy mean_ft          float64
#  2759  movingright_shoulder right_ear dy std_ft           float64
#  2760  movingright_shoulder right_ear dy max_ft           float64
#  2761  movingright_shoulder right_ear dy min_ft           float64
#  2762  movingright_shoulder right_ear dy var_ft           float64
#  2763  movingright_shoulder right_ear dy med_ft           float64
#  2764  movingright_shoulder right_ear dy sum_ft           float64
#  2765  movingright_shoulder right_ear dy std              float64
#  2766  movingright_shoulder right_ear dy kurtosis         float64
#  2767  movingright_shoulder right_ear dy skew             float64
#  2768  movingright_shoulder right_ear dy quantile 25      float64
#  2769  movingright_shoulder right_ear dy quantile 75      float64
#  2770  movingright_shoulder right_ear dy RMS              float64
#  2771  movingright_shoulder right_ear dy MAV              float64
#  2772  movingright_shoulder left_shoulder dx mean_ft      float64
#  2773  movingright_shoulder left_shoulder dx std_ft       float64
#  2774  movingright_shoulder left_shoulder dx max_ft       float64
#  2775  movingright_shoulder left_shoulder dx min_ft       float64
#  2776  movingright_shoulder left_shoulder dx var_ft       float64
#  2777  movingright_shoulder left_shoulder dx med_ft       float64
#  2778  movingright_shoulder left_shoulder dx sum_ft       float64
#  2779  movingright_shoulder left_shoulder dx std          float64
#  2780  movingright_shoulder left_shoulder dx kurtosis     float64
#  2781  movingright_shoulder left_shoulder dx skew         float64
#  2782  movingright_shoulder left_shoulder dx quantile 25  float64
#  2783  movingright_shoulder left_shoulder dx quantile 75  float64
#  2784  movingright_shoulder left_shoulder dx RMS          float64
#  2785  movingright_shoulder left_shoulder dx MAV          float64
#  2786  movingright_shoulder left_shoulder dy mean_ft      float64
#  2787  movingright_shoulder left_shoulder dy std_ft       float64
#  2788  movingright_shoulder left_shoulder dy max_ft       float64
#  2789  movingright_shoulder left_shoulder dy min_ft       float64
#  2790  movingright_shoulder left_shoulder dy var_ft       float64
#  2791  movingright_shoulder left_shoulder dy med_ft       float64
#  2792  movingright_shoulder left_shoulder dy sum_ft       float64
#  2793  movingright_shoulder left_shoulder dy std          float64
#  2794  movingright_shoulder left_shoulder dy kurtosis     float64
#  2795  movingright_shoulder left_shoulder dy skew         float64
#  2796  movingright_shoulder left_shoulder dy quantile 25  float64
#  2797  movingright_shoulder left_shoulder dy quantile 75  float64
#  2798  movingright_shoulder left_shoulder dy RMS          float64
#  2799  movingright_shoulder left_shoulder dy MAV          float64
#  2800  movingright_shoulder left_elbow dx mean_ft         float64
#  2801  movingright_shoulder left_elbow dx std_ft          float64
#  2802  movingright_shoulder left_elbow dx max_ft          float64
#  2803  movingright_shoulder left_elbow dx min_ft          float64
#  2804  movingright_shoulder left_elbow dx var_ft          float64
#  2805  movingright_shoulder left_elbow dx med_ft          float64
#  2806  movingright_shoulder left_elbow dx sum_ft          float64
#  2807  movingright_shoulder left_elbow dx std             float64
#  2808  movingright_shoulder left_elbow dx kurtosis        float64
#  2809  movingright_shoulder left_elbow dx skew            float64
#  2810  movingright_shoulder left_elbow dx quantile 25     float64
#  2811  movingright_shoulder left_elbow dx quantile 75     float64
#  2812  movingright_shoulder left_elbow dx RMS             float64
#  2813  movingright_shoulder left_elbow dx MAV             float64
#  2814  movingright_shoulder left_elbow dy mean_ft         float64
#  2815  movingright_shoulder left_elbow dy std_ft          float64
#  2816  movingright_shoulder left_elbow dy max_ft          float64
#  2817  movingright_shoulder left_elbow dy min_ft          float64
#  2818  movingright_shoulder left_elbow dy var_ft          float64
#  2819  movingright_shoulder left_elbow dy med_ft          float64
#  2820  movingright_shoulder left_elbow dy sum_ft          float64
#  2821  movingright_shoulder left_elbow dy std             float64
#  2822  movingright_shoulder left_elbow dy kurtosis        float64
#  2823  movingright_shoulder left_elbow dy skew            float64
#  2824  movingright_shoulder left_elbow dy quantile 25     float64
#  2825  movingright_shoulder left_elbow dy quantile 75     float64
#  2826  movingright_shoulder left_elbow dy RMS             float64
#  2827  movingright_shoulder left_elbow dy MAV             float64
#  2828  movingright_shoulder right_elbow dx mean_ft        float64
#  2829  movingright_shoulder right_elbow dx std_ft         float64
#  2830  movingright_shoulder right_elbow dx max_ft         float64
#  2831  movingright_shoulder right_elbow dx min_ft         float64
#  2832  movingright_shoulder right_elbow dx var_ft         float64
#  2833  movingright_shoulder right_elbow dx med_ft         float64
#  2834  movingright_shoulder right_elbow dx sum_ft         float64
#  2835  movingright_shoulder right_elbow dx std            float64
#  2836  movingright_shoulder right_elbow dx kurtosis       float64
#  2837  movingright_shoulder right_elbow dx skew           float64
#  2838  movingright_shoulder right_elbow dx quantile 25    float64
#  2839  movingright_shoulder right_elbow dx quantile 75    float64
#  2840  movingright_shoulder right_elbow dx RMS            float64
#  2841  movingright_shoulder right_elbow dx MAV            float64
#  2842  movingright_shoulder right_elbow dy mean_ft        float64
#  2843  movingright_shoulder right_elbow dy std_ft         float64
#  2844  movingright_shoulder right_elbow dy max_ft         float64
#  2845  movingright_shoulder right_elbow dy min_ft         float64
#  2846  movingright_shoulder right_elbow dy var_ft         float64
#  2847  movingright_shoulder right_elbow dy med_ft         float64
#  2848  movingright_shoulder right_elbow dy sum_ft         float64
#  2849  movingright_shoulder right_elbow dy std            float64
#  2850  movingright_shoulder right_elbow dy kurtosis       float64
#  2851  movingright_shoulder right_elbow dy skew           float64
#  2852  movingright_shoulder right_elbow dy quantile 25    float64
#  2853  movingright_shoulder right_elbow dy quantile 75    float64
#  2854  movingright_shoulder right_elbow dy RMS            float64
#  2855  movingright_shoulder right_elbow dy MAV            float64
#  2856  movingright_shoulder left_wrist dx mean_ft         float64
#  2857  movingright_shoulder left_wrist dx std_ft          float64
#  2858  movingright_shoulder left_wrist dx max_ft          float64
#  2859  movingright_shoulder left_wrist dx min_ft          float64
#  2860  movingright_shoulder left_wrist dx var_ft          float64
#  2861  movingright_shoulder left_wrist dx med_ft          float64
#  2862  movingright_shoulder left_wrist dx sum_ft          float64
#  2863  movingright_shoulder left_wrist dx std             float64
#  2864  movingright_shoulder left_wrist dx kurtosis        float64
#  2865  movingright_shoulder left_wrist dx skew            float64
#  2866  movingright_shoulder left_wrist dx quantile 25     float64
#  2867  movingright_shoulder left_wrist dx quantile 75     float64
#  2868  movingright_shoulder left_wrist dx RMS             float64
#  2869  movingright_shoulder left_wrist dx MAV             float64
#  2870  movingright_shoulder left_wrist dy mean_ft         float64
#  2871  movingright_shoulder left_wrist dy std_ft          float64
#  2872  movingright_shoulder left_wrist dy max_ft          float64
#  2873  movingright_shoulder left_wrist dy min_ft          float64
#  2874  movingright_shoulder left_wrist dy var_ft          float64
#  2875  movingright_shoulder left_wrist dy med_ft          float64
#  2876  movingright_shoulder left_wrist dy sum_ft          float64
#  2877  movingright_shoulder left_wrist dy std             float64
#  2878  movingright_shoulder left_wrist dy kurtosis        float64
#  2879  movingright_shoulder left_wrist dy skew            float64
#  2880  movingright_shoulder left_wrist dy quantile 25     float64
#  2881  movingright_shoulder left_wrist dy quantile 75     float64
#  2882  movingright_shoulder left_wrist dy RMS             float64
#  2883  movingright_shoulder left_wrist dy MAV             float64
#  2884  movingright_shoulder right_wrist dx mean_ft        float64
#  2885  movingright_shoulder right_wrist dx std_ft         float64
#  2886  movingright_shoulder right_wrist dx max_ft         float64
#  2887  movingright_shoulder right_wrist dx min_ft         float64
#  2888  movingright_shoulder right_wrist dx var_ft         float64
#  2889  movingright_shoulder right_wrist dx med_ft         float64
#  2890  movingright_shoulder right_wrist dx sum_ft         float64
#  2891  movingright_shoulder right_wrist dx std            float64
#  2892  movingright_shoulder right_wrist dx kurtosis       float64
#  2893  movingright_shoulder right_wrist dx skew           float64
#  2894  movingright_shoulder right_wrist dx quantile 25    float64
#  2895  movingright_shoulder right_wrist dx quantile 75    float64
#  2896  movingright_shoulder right_wrist dx RMS            float64
#  2897  movingright_shoulder right_wrist dx MAV            float64
#  2898  movingright_shoulder right_wrist dy mean_ft        float64
#  2899  movingright_shoulder right_wrist dy std_ft         float64
#  2900  movingright_shoulder right_wrist dy max_ft         float64
#  2901  movingright_shoulder right_wrist dy min_ft         float64
#  2902  movingright_shoulder right_wrist dy var_ft         float64
#  2903  movingright_shoulder right_wrist dy med_ft         float64
#  2904  movingright_shoulder right_wrist dy sum_ft         float64
#  2905  movingright_shoulder right_wrist dy std            float64
#  2906  movingright_shoulder right_wrist dy kurtosis       float64
#  2907  movingright_shoulder right_wrist dy skew           float64
#  2908  movingright_shoulder right_wrist dy quantile 25    float64
#  2909  movingright_shoulder right_wrist dy quantile 75    float64
#  2910  movingright_shoulder right_wrist dy RMS            float64
#  2911  movingright_shoulder right_wrist dy MAV            float64
#  2912  movingright_shoulder left_hip dx mean_ft           float64
#  2913  movingright_shoulder left_hip dx std_ft            float64
#  2914  movingright_shoulder left_hip dx max_ft            float64
#  2915  movingright_shoulder left_hip dx min_ft            float64
#  2916  movingright_shoulder left_hip dx var_ft            float64
#  2917  movingright_shoulder left_hip dx med_ft            float64
#  2918  movingright_shoulder left_hip dx sum_ft            float64
#  2919  movingright_shoulder left_hip dx std               float64
#  2920  movingright_shoulder left_hip dx kurtosis          float64
#  2921  movingright_shoulder left_hip dx skew              float64
#  2922  movingright_shoulder left_hip dx quantile 25       float64
#  2923  movingright_shoulder left_hip dx quantile 75       float64
#  2924  movingright_shoulder left_hip dx RMS               float64
#  2925  movingright_shoulder left_hip dx MAV               float64
#  2926  movingright_shoulder left_hip dy mean_ft           float64
#  2927  movingright_shoulder left_hip dy std_ft            float64
#  2928  movingright_shoulder left_hip dy max_ft            float64
#  2929  movingright_shoulder left_hip dy min_ft            float64
#  2930  movingright_shoulder left_hip dy var_ft            float64
#  2931  movingright_shoulder left_hip dy med_ft            float64
#  2932  movingright_shoulder left_hip dy sum_ft            float64
#  2933  movingright_shoulder left_hip dy std               float64
#  2934  movingright_shoulder left_hip dy kurtosis          float64
#  2935  movingright_shoulder left_hip dy skew              float64
#  2936  movingright_shoulder left_hip dy quantile 25       float64
#  2937  movingright_shoulder left_hip dy quantile 75       float64
#  2938  movingright_shoulder left_hip dy RMS               float64
#  2939  movingright_shoulder left_hip dy MAV               float64
#  2940  movingright_shoulder right_hip dx mean_ft          float64
#  2941  movingright_shoulder right_hip dx std_ft           float64
#  2942  movingright_shoulder right_hip dx max_ft           float64
#  2943  movingright_shoulder right_hip dx min_ft           float64
#  2944  movingright_shoulder right_hip dx var_ft           float64
#  2945  movingright_shoulder right_hip dx med_ft           float64
#  2946  movingright_shoulder right_hip dx sum_ft           float64
#  2947  movingright_shoulder right_hip dx std              float64
#  2948  movingright_shoulder right_hip dx kurtosis         float64
#  2949  movingright_shoulder right_hip dx skew             float64
#  2950  movingright_shoulder right_hip dx quantile 25      float64
#  2951  movingright_shoulder right_hip dx quantile 75      float64
#  2952  movingright_shoulder right_hip dx RMS              float64
#  2953  movingright_shoulder right_hip dx MAV              float64
#  2954  movingright_shoulder right_hip dy mean_ft          float64
#  2955  movingright_shoulder right_hip dy std_ft           float64
#  2956  movingright_shoulder right_hip dy max_ft           float64
#  2957  movingright_shoulder right_hip dy min_ft           float64
#  2958  movingright_shoulder right_hip dy var_ft           float64
#  2959  movingright_shoulder right_hip dy med_ft           float64
#  2960  movingright_shoulder right_hip dy sum_ft           float64
#  2961  movingright_shoulder right_hip dy std              float64
#  2962  movingright_shoulder right_hip dy kurtosis         float64
#  2963  movingright_shoulder right_hip dy skew             float64
#  2964  movingright_shoulder right_hip dy quantile 25      float64
#  2965  movingright_shoulder right_hip dy quantile 75      float64
#  2966  movingright_shoulder right_hip dy RMS              float64
#  2967  movingright_shoulder right_hip dy MAV              float64
#  2968  movingcenter_x mean_ft                             float64
#  2969  movingcenter_x std_ft                              float64
#  2970  movingcenter_x max_ft                              float64
#  2971  movingcenter_x min_ft                              float64
#  2972  movingcenter_x var_ft                              float64
#  2973  movingcenter_x med_ft                              float64
#  2974  movingcenter_x sum_ft                              float64
#  2975  movingcenter_x std                                 float64
#  2976  movingcenter_x kurtosis                            float64
#  2977  movingcenter_x skew                                float64
#  2978  movingcenter_x quantile 25                         float64
#  2979  movingcenter_x quantile 75                         float64
#  2980  movingcenter_x RMS                                 float64
#  2981  movingcenter_x MAV                                 float64
#  2982  movingcenter_y mean_ft                             float64
#  2983  movingcenter_y std_ft                              float64
#  2984  movingcenter_y max_ft                              float64
#  2985  movingcenter_y min_ft                              float64
#  2986  movingcenter_y var_ft                              float64
#  2987  movingcenter_y med_ft                              float64
#  2988  movingcenter_y sum_ft                              float64
#  2989  movingcenter_y std                                 float64
#  2990  movingcenter_y kurtosis                            float64
#  2991  movingcenter_y skew                                float64
#  2992  movingcenter_y quantile 25                         float64
#  2993  movingcenter_y quantile 75                         float64
#  2994  movingcenter_y RMS                                 float64
#  2995  movingcenter_y MAV                                 float64
#  2996  previous_label                                     int64
#  2997  label                                              float64
#  2998  after1                                             int64
# dtypes: float64(2997), int64(2)
# memory usage: 89.0 MB

# %%
sns.histplot(df["label"])
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='label', ylabel='Count'>

# %%
X=df.drop(["label","previous_label",'after1'],axis=1)
y=df['label']

# %%
X.shape
# Out:
# (3883, 2996)

# %%
y.shape
# Out:
# (3883,)

# %%
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='logloss', random_state=10)
# xgbcl.fit(X_train,y_train)
# # filename = './xgb_model.sav'
# # xgbcl=joblib.load(filename)
# pred=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.ensemble import RandomForestClassifier #Random Forest
# rf=RandomForestClassifier(random_state=10)
# rf.fit(X_train,y_train)
# pred=rf.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# import joblib
# filename = './xgb_model.sav'
# joblib.dump(xgbcl, filename)

# %%
# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(X_train,y_train)
# pred=svc.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
# knn = RadiusNeighborsClassifier(radius=175)
# knn.fit(X_train,y_train)
# pred=knn.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.linear_model import SGDClassifier
## sgd=SGDClassifier()loss='epsilon_insensitive'
# sgd.fit(X_train,y_train)
# pred=sgd.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
from sklearn.feature_selection import SelectKBest,f_regression
# Applying SelectKBest class to extract top 15 best features
fs = SelectKBest(score_func=f_regression,k=15)
# Applying feature selection
fit = fs.fit(X,y)
features_score = pd.DataFrame(fit.scores_)
features = pd.DataFrame(X.columns)
feature_score = pd.concat([features,features_score],axis=1)
# Assigning column names
feature_score.columns = ["Input_Features","F_Score"]
print(feature_score.nlargest(300,columns="F_Score"))
# dfi.export(feature_score.nlargest(16,columns="F_Score"),'./image/fulltest/f_test.png')
# feature_score.nlargest(300,columns="F_Score")['Input_Features'].values
# Out:
#                                        Input_Features      F_Score
# 2888       movingright_shoulder right_wrist dx var_ft  2632.680748
# 2902       movingright_shoulder right_wrist dy var_ft  2610.709781
# 2895  movingright_shoulder right_wrist dx quantile 75  2546.894295
# 2832       movingright_shoulder right_elbow dx var_ft  2519.698044
# 2552                       movingright_wrist_x var_ft  2514.425636
# ...                                               ...          ...
# 2392                            movingright_ear_x RMS   526.377746
# 771                right_shoulder right_hip dy std_ft   512.393256
# 777                   right_shoulder right_hip dy std   512.393256
# 1845                     accright_wrist_y quantile 75   507.778460
# 2384                         movingright_ear_x var_ft   504.628080
#
# [300 rows x 2 columns]

# %%
X_train=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train=y
X_test=test.drop(["label","previous_label"],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test=test['label']

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier #Random Forest
# try:
# oversampling the train dataset using SMOTE

sm = SMOTE()
all_feature_smote, all_label_smote = sm.fit_resample(X_train,y_train)
# rf=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf.fit(all_feature_smote, all_label_smote)
# # filename = './model/smote_rf_model.sav'
# # rf=joblib.load(filename)
# pred_rf=rf.predict(X_test)

# print(metrics.classification_report(pred_rf,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model/smote_rf_model2.sav'
# joblib.dump(rf, filename)

# %%
a=[e for e in X_train if e not in X_test]
a
# Out:
# []

# %%
from xgboost import XGBClassifier#XGBcalssifier
from xgboost import callback
early_stop = callback.EarlyStopping(
    rounds=4, metric_name='mlogloss', save_best=True
)
try:
    filename = './model_win6/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    pred_xgb=xgbcl.predict(X_test)
except:
    xgbcl=XGBClassifier( eval_metric='mlogloss', random_state=10,callbacks=[early_stop])
    xgbcl.fit(all_feature_smote, all_label_smote,eval_set=[(X_test, y_test)])
    pred_xgb=xgbcl.predict(X_test)

from sklearn import metrics #accuracy measure
print(metrics.classification_report(pred_xgb,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_xgb,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81        74
#            1       1.00      0.25      0.40         4
#            2       0.75      0.75      0.75        20
#            3       0.33      0.67      0.44         3
#            4       0.60      0.76      0.68        34
#            5       0.50      0.33      0.40         6
#            6       0.57      1.00      0.73         4
#            7       0.76      0.72      0.74        36
#            8       0.83      1.00      0.91         5
#
#     accuracy                           0.74       186
#    macro avg       0.69      0.69      0.65       186
# weighted avg       0.76      0.74      0.74       186
# <Axes: >

# %%
# X_train_with_predictions.shape

# %%
# X_train_with_predictions=df.drop(["label"],axis=1)
# y_train_with_predictions=df['label']
# X_test["previous_label"]=pred_xgb
# all_feature_smote_with_predictions, all_label_smote_with_predictions = sm.fit_resample(X_train_with_predictions,y_train_with_predictions)
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='aucs‌', random_state=10)
# xgbcl.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_xgb_with_predictions=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_xgb_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_xgb_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# rf_with_predictions=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf_with_predictions.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_rf_with_predictions=rf_with_predictions.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_rf_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_win6/smote_xgb_model2.sav'
joblib.dump(xgbcl, filename)
# Out:
# ['./model_win6/smote_xgb_model2.sav']

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
HGBC=HistGradientBoostingClassifier(random_state=10)
# HGBC.fit(X_train,y_train)
try:
    filename = './model_win6/smote_HGBC_model2.sav'
    HGBC=joblib.load(filename)
    pred=HGBC.predict(X_test)
except:
    HGBC.fit(all_feature_smote, all_label_smote )
    pred=HGBC.predict(X_test)


print(metrics.classification_report(pred,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.71      0.78        79
#          1.0       1.00      0.50      0.67         2
#          2.0       0.70      0.93      0.80        15
#          3.0       0.00      0.00      0.00         0
#          4.0       0.53      0.70      0.61        33
#          5.0       0.50      0.67      0.57         3
#          6.0       0.29      1.00      0.44         2
#          7.0       0.91      0.66      0.77        47
#          8.0       0.83      1.00      0.91         5
#
#     accuracy                           0.72       186
#    macro avg       0.63      0.69      0.62       186
# weighted avg       0.79      0.72      0.74       186
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <Axes: >

# %%
filename = './model_win6/smote_HGBC_model2.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_win6/smote_HGBC_model2.sav']

# %%
# def predict0_4(df):
# #     print(df['label_pred'])
# #     print(df['label_pred'] in [1,2,3,5,6,7,8])
#     if df['previous_label'] in [1,2,3,5,6,7,8]:
#         return df['previous_label']
#     else:
# #         print(np.array(df.drop(["label","previous_label",'label_pred'])))
# # xgb_class0_4
#         return xgbcl.predict(np.array(df.drop(["label",'previous_label'
#                                     ])).reshape(1,-1)).view().item()

# %%
# from sklearn.ensemble import AdaBoostClassifier
# test['previous_label']=pred_xgb
# # test['previous_label']=list(pred_xgb).insert(0,0)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label",'previous_label'],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4=np.array(X_train_class0_4)
# y_train_class0_4=np.array(y_train_class0_4)
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# xgb_class0_4=RandomForestClassifier(random_state=10,n_estimators=30,criterion='gini')#XGBClassifier( eval_metric='logloss', random_state=10)
# try:
#     print('sm')
# #     xgb_class0_4.fit(X_train_class0_4sm, y_train_class0_4sm)
# except:
#     print('no sm')
# #     xgb_class0_4.fit(X_train_class0_4, y_train_class0_4)
# test['label_pred']=test.apply(lambda x:predict0_4(x),axis=1)

# # test_class0_4=test[(test['label_pred'].isin([0,4]))&(test['label'].isin([0,4]))]
# # X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# # y_test_class0_4=test_class0_4.label
# # # X_test_class0_4=np.array(X_test_class0_4)
# # # y_test_class0_4=np.array(y_test_class0_4)

# # pred_class0_4=xgb_class0_4.predict(X_test_class0_4)
# print(metrics.classification_report(test['label'],test['label_pred']))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(test['label'],test['label_pred'], normalize='true')
# sns.heatmap(conf,annot=True)

# %%
test['label1']=pred
# turn2
test['previous_label']=test['label1']
test['second_turn']=test['previous_label'].diff()
test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
turn=list(test['second_turn'])
turn_2=[]

if (test['label'][0].item()>0): 
    count=2
else: 
    count=1
for i in range(len(turn)):

    if turn[i]<-3:
        count-=1
    if count<=0:
        turn_2.append(1) 
    else:
        turn_2.append(0) 
test['turn']=turn
test['second_turn']=turn_2
            
print(list(test['label'])[0])
def fturn():
    if list(test['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0
after0=fturn()
sturn=True
after1=[]
for i in range(len(test['label'])):

    if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
        after0-=1
    if (list(test['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after1.append(1) 
    else:
        after1.append(0) 
test['after1']=after1
test=test.drop(['second_turn','turn'],axis=1)
# Out:
# 8

# %%
X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test_a=test['label']

X=df.drop(["label","previous_label"],axis=1)
y=df['label']
X_train_a=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train_a=y

all_feature_smote_a, all_label_smote_a = sm.fit_resample(X_train_a,y_train_a)

# %%
try:
    filename = './model_win6/smote_HGBC_model_after.sav'
    HGBC=joblib.load(filename)
    pred_a=HGBC.predict(X_test_a)
except:
    print('learning')
    HGBC=HistGradientBoostingClassifier(random_state=10)
    HGBC.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=HGBC.predict(X_test_a)


print(metrics.classification_report(pred_a,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_a,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.73      0.79        75
#          1.0       1.00      0.50      0.67         2
#          2.0       0.70      1.00      0.82        14
#          3.0       0.00      0.00      0.00         1
#          4.0       0.58      0.68      0.63        37
#          5.0       0.50      0.67      0.57         3
#          6.0       0.43      1.00      0.60         3
#          7.0       0.91      0.67      0.78        46
#          8.0       0.83      1.00      0.91         5
#
#     accuracy                           0.73       186
#    macro avg       0.64      0.69      0.64       186
# weighted avg       0.78      0.73      0.75       186
# <Axes: >

# %%
# XGB=RandomForestClassifier(random_state=10)
# XGB.fit(all_feature_smote_a, all_label_smote_a)

# pred_b=XGB.predict(X_test_a)

# print(metrics.classification_report(pred_b,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_b,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_win6/smote_HGBC_model_after.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_win6/smote_HGBC_model_after.sav']

# %%
# from sklearn.ensemble import AdaBoostClassifier
# ada=AdaBoostClassifier(random_state=10)
# ada.fit(X_train,y_train)
# pred=ada.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from catboost import CatBoostClassifier
# # catboost=CatBoostClassifier()
# # catboost.fit(X_train,y_train)
# filename = './catboost_model.sav'
# catboost=joblib.load(filename)
# pred=catboost.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './catboost_model.sav'
# joblib.dump(catboost, filename)

# %%
# from keras.layers import TimeDistributed
# # # trainX=np.array(X_train)
# # testX=np.array(X_test)
# # # trainY=np.array(y_train)
# # testY=np.array(y_test)
# # trainX=np.array(all_feature_smote)
# # trainY=np.array(all_label_smote)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label","previous_label"],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# trainX=np.array(X_train_class0_4sm)
# trainY=np.array(y_train_class0_4sm)

# test_class0_4=test[test['label'].isin([0,4])]
# X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# y_test_class0_4=test_class0_4.label
# testX=np.array(X_test_class0_4)
# testY=np.array(y_test_class0_4)

# # # testY = tf.keras.utils.to_categorical(testY)
# # # trainY = tf.keras.utils.to_categorical(trainY)
# # trainX = np.expand_dims(trainX, 2)
# # testX = np.expand_dims(testX, 2)

# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# from tensorflow.keras import models
# model = models.Sequential()
# model.add(layers.Input(shape=(len(trainX[1]), 1)))
# model.add(layers.Conv1D(64,64, activation='relu'))
# # model.add(LSTM(units=3, return_sequences=True))
# # model.add(LSTM(units=64, return_sequences=True))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Conv1D(32, 32, activation='relu'))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Conv1D(16, 16, activation='relu'))
# model.add(LSTM(units=64, return_sequences=True))
# # model.add(LSTM(units=32, return_sequences=True))
# model.add(LSTM(units=16, return_sequences=True))
# model.add(Dropout(0.5))

# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(32, activation='relu'))
# model.add(layers.Dense(9,activation='softmax'))
# mcp_save = ModelCheckpoint('DL_model.hdf5', save_best_only=True, monitor='val_loss', mode='min')
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# history = model.fit(trainX,trainY, epochs=100, 
#                     validation_data=(testX,testY), 
#                     callbacks=[early_stopping,mcp_save])

# %%
# plt.clf()
# plt.plot(history.history['loss'], label='loss')
# plt.plot(history.history['val_loss'], label = 'val_loss')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')

# plt.legend(loc='lower right')

# %%
# pred=model.predict(testX)
# pred=np.argmax(pred,axis=1)
# print(metrics.classification_report(pred,testY))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,testY, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# model_rnn = Sequential()
# model_rnn.add(LSTM(units=64, return_sequences=True, input_shape=(len(trainX[1]), 1)))
# model_rnn.add(Conv1D(128, 6))
# model_rnn.add(LSTM(units = 64, return_sequences = True))
# model_rnn.add(Dropout(0.2))
# model_rnn.add(Conv1D(128, 3))
# model_rnn.add(LSTM(units = 64, return_sequences = True))

# model_rnn.add(Dropout(0.2))
# model_rnn.add(LSTM(units = 64))

# model_rnn.add(Dense(units = 128))
# model_rnn.add(Dense(units = 64))

# model_rnn.add(Dense(units = 9, activation="softmax")) #4 as the output classes

# # Define the BRNN model with LSTM layers
# model_brnn = keras.Sequential([
#     layers.Bidirectional(layers.LSTM(64, activation='relu', return_sequences=True), 
#                          input_shape=(len(trainX[1]), 1)),
# #     layers.Bidirectional(layers.LSTM(64, activation='relu')),
# #     layers.Bidirectional(layers.LSTM(32, activation='relu')),
#     layers.Bidirectional(layers.LSTM(16, activation='relu')),
    
#     layers.Dense(9, activation='softmax')
# ])

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# # Compile the RNN model
# model_rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Compile the BRNN model
# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Define early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Train the RNN model with early stopping

# ## model_rnn.fit(all_feature, all_label, epochs=100, batch_size=500, validation_data=(X_vad, y_vad), callbacks=[early_stopping])

# # Train the BRNN model with early stopping

# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# # history_brnn=model_brnn.fit(trainX,trainY, epochs=10, batch_size=500,
# #                             validation_data=(testX,testY), callbacks=[early_stopping])
# # , callbacks=[early_stopping]

# %%
# history_rnn=model_rnn.fit(trainX,trainY, epochs=20,
#                             validation_data=(testX,testY), callbacks=[early_stopping])

# %%
len(all_label_smote)

# %%
def output_xgb(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_win6/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_win6/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_win6/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(pred,y_test,average='weighted')
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(pred,y_test, normalize='true',labels=[i for i in range(9)])
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
    plt.savefig(f"./image/xgb_gan_win6/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s])

# %%
test_set=os.listdir('./test_set_df_acc_win6')
out_xgb=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_xgb(ID,out_xgb)
out_df_xgb=pd.DataFrame(out_xgb,columns=['ID','accuracy','weighted avg F1-score'])
out_df_xgb
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#        ID  accuracy  weighted avg F1-score
# 0   S08T1  0.731183               0.745301
# 1   S08T2  0.668394               0.690092
# 2   N11T1  0.808696               0.828634
# 3   N11T2  0.831858               0.848449
# 4   N06T1  0.604651               0.616208
# 5   S02T2  0.713376               0.743573
# 6   N06T2  0.711864               0.738960
# 7   S02T1  0.682796               0.700358
# 8   N02T2  0.638158               0.649434
# 9   N02T1  0.797468               0.811918
# 10  S03T1  0.739274               0.750276
# 11  S03T2  0.748252               0.772986

# %%
test_set=os.listdir('./test_set_df')
test_set

# %%
def output_rf(ID,out):
    test=pd.read_csv(f'./test_set_df_acc_win6/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_win6/smote_HGBC_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_win6/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(pred,y_test,average='weighted')
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(pred,y_test,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
    plt.savefig(f"./image/rf_gan_win6/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s])

# %%
test_set=os.listdir('./test_set_df_acc_win6')
out_rf=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_rf)
out_df=pd.DataFrame(out_rf,columns=['ID','accuracy','weighted avg F1-score'])
out_df.describe()
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#         accuracy  weighted avg F1-score
# count  12.000000              12.000000
# mean    0.722997               0.741349
# std     0.068575               0.069800
# min     0.604651               0.616208
# 25%     0.679195               0.697792
# 50%     0.722279               0.744437
# 75%     0.760556               0.782719
# max     0.831858               0.848449

# %%
out_df.describe()#HGBC not rf model :(
# Out:
#         accuracy  weighted avg F1-score
# count  12.000000              12.000000
# mean    0.722997               0.741349
# std     0.068575               0.069800
# min     0.604651               0.616208
# 25%     0.679195               0.697792
# 50%     0.722279               0.744437
# 75%     0.760556               0.782719
# max     0.831858               0.848449

# %%
out_df_xgb.describe()
# Out:
#         accuracy  weighted avg F1-score
# count  12.000000              12.000000
# mean    0.722997               0.741349
# std     0.068575               0.069800
# min     0.604651               0.616208
# 25%     0.679195               0.697792
# 50%     0.722279               0.744437
# 75%     0.760556               0.782719
# max     0.831858               0.848449
