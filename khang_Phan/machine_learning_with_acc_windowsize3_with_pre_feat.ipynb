# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd # data processing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D,Dropout,LSTM, Bidirectional
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.layers import BatchNormalization, Dropout
from keras.layers import Dense, Activation
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import torch
from torch.nn import Transformer
from sklearn.preprocessing import StandardScaler #good
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
from sklearn import metrics #accuracy measure
import joblib
import warnings

# %%
def second_turn(label,dif):
    if label>0:
        return 0
    if label==0:
        return dif
def fturn(df):
    if list(df['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0
def fturn_test():
    if list(df['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0

# %%
training_set=os.listdir("./training_set_df_acc_windowsize3_with_pre_feat/")
# training_set=['./gan_win6.csv','./gan_win6.csv']
df=None
for data in training_set:
    if data.endswith('.csv'):
        file=f"./training_set_df_acc_windowsize3_with_pre_feat/{data}"
        if df is None:
            df=pd.read_csv(file)
            df=df.astype(float)
            print(df.shape)
            df['previous_label']=df['label']
            
            df['label']=df['label'].astype("category")
            df['previous_label']=df['label']
            df['previous_label']=df['previous_label'].astype(int)
            df['second_turn']=df['previous_label'].diff()
            df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
            turn=list(df['second_turn'])
            turn_2=[]
            
            if (df['label'][0].item()>0): 
                count=2
            else: 
                count=1
            for i in range(len(turn)):

                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            df['turn']=turn
            df['second_turn']=turn_2
            after1=[]
            
# print(list(df['label'])[0])

            after0=fturn(df)
            sturn=True
            for i in range(len(df.label)):

                if (list(df['label'])[i]==1)|(list(df['label'])[i]==2)|(list(df['label'])[i]==3):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(df)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after1.append(1) 
                else:
                    after1.append(0) 
            df['after1']=after1
            after4=[]
            after0=fturn(df)
            sturn=True
            for i in range(len(df['label'])):
                if (list(df['label'])[i]==4)|(list(df['label'])[i]==5)|(list(df['label'])[i]==6):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(df)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after4.append(1) 
                else:
                    after4.append(0) 

            df['after4']=after4
            
        else:
            d=pd.read_csv(file)
            d['previous_label']=d['label']
            d['previous_label']=d['previous_label'].astype(int)
            d['label']=d['label'].astype("category")
            d['second_turn']=d['previous_label'].diff()
            d['second_turn']=d.apply(lambda d:second_turn(d['label'],d['second_turn']),axis=1)
            turn=list(d['second_turn'])
            turn_2=[]
            if (d['label'][0].item()>0): 
                count=2
            else: count=1
            for i in range(len(turn)):
                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            d['second_turn']=turn_2
            d['turn']=turn
            after1=[]
            
# print(list(df['label'])[0])

            after0=fturn(d)
            sturn=True
            for i in range(len(d.label)):

                if (list(d['label'])[i]==1)|(list(d['label'])[i]==2)|(list(d['label'])[i]==3):
                    after0-=1
                if (list(d['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(d)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after1.append(1) 
                else:
                    after1.append(0) 
            d['after1']=after1
            after4=[]
            after0=fturn(d)
            sturn=True
            for i in range(len(d['label'])):
                if (list(d['label'])[i]==4)|(list(d['label'])[i]==5)|(list(d['label'])[i]==6):
                    after0-=1
                if (list(df['second_turn'])[i]>0) and sturn==True:
                    after0=fturn(d)
                    sturn=False
                if after0<=0:
            #         print(after0)
                    after4.append(1) 
                else:
                    after4.append(0) 

            d['after4']=after4
            df=pd.concat([df,d])
# # turn2
# df['previous_label']=df['label']
# df['second_turn']=df['previous_label'].diff()
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
# turn=list(df['second_turn'])
# turn_2=[]

# if (df['label'][0].item()>0): 
#     count=2
# else: 
#     count=1
# for i in range(len(turn)):

#     if turn[i]<-3:
#         count-=1
#     if count<=0:
#         turn_2.append(1) 
#     else:
#         turn_2.append(0) 
# df['turn']=turn
# df['second_turn']=turn_2
# Out:
# (211, 8682)

# %%
df[['label','second_turn','turn','after1']].to_csv('./check/check.csv')

# %%
df=df.drop(['second_turn','turn'],axis=1)

# %%
# df=df.astype(float)
# df['previous_label']=df['label']
# df['label']=df['label'].astype(int)
# df['label']=df['label'].astype("category")
# df['second_turn']=df['previous_label'].diff
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['dif']))
# turn=list(df['second_turn'])

# %%
# is_2=False
# turn_2=[]
# for i in len(turn):
#     if turn[i]>2:
#         is_2=True
#     if !is_2:
#         return 0
#     return 1
# df['second_turn']=turn_2

# %%
test=pd.read_csv('./test_set_df_acc_windowsize3_with_pre_feat/S08T2.csv')
df=df.fillna(0)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3883 entries, 0 to 171
# Data columns (total 8684 columns):
#  #     Column                                                           Dtype
# ---    ------                                                           -----
#  0     left_elbow_shoulder_hip mean_ft                                  float64
#  1     left_elbow_shoulder_hip std_ft                                   float64
#  2     left_elbow_shoulder_hip max_ft                                   float64
#  3     left_elbow_shoulder_hip min_ft                                   float64
#  4     left_elbow_shoulder_hip var_ft                                   float64
#  5     left_elbow_shoulder_hip med_ft                                   float64
#  6     left_elbow_shoulder_hip sum_ft                                   float64
#  7     left_elbow_shoulder_hip kurtosis                                 float64
#  8     left_elbow_shoulder_hip skew                                     float64
#  9     left_elbow_shoulder_hip quantile 25                              float64
#  10    left_elbow_shoulder_hip quantile 75                              float64
#  11    left_elbow_shoulder_hip RMS                                      float64
#  12    left_elbow_shoulder_hip MAV                                      float64
#  13    left_elbow_shoulder_hip rmse                                     float64
#  14    left_elbow_shoulder_hip mae                                      float64
#  15    left_elbow_shoulder_hip maxerror                                 float64
#  16    left_elbow_shoulder_hip minerror                                 float64
#  17    left_elbow_shoulder_hip stderror                                 float64
#  18    left_elbow_shoulder_hip quantile25e                              float64
#  19    left_elbow_shoulder_hip quantile75e                              float64
#  20    right_elbow_shoulder_hip mean_ft                                 float64
#  21    right_elbow_shoulder_hip std_ft                                  float64
#  22    right_elbow_shoulder_hip max_ft                                  float64
#  23    right_elbow_shoulder_hip min_ft                                  float64
#  24    right_elbow_shoulder_hip var_ft                                  float64
#  25    right_elbow_shoulder_hip med_ft                                  float64
#  26    right_elbow_shoulder_hip sum_ft                                  float64
#  27    right_elbow_shoulder_hip kurtosis                                float64
#  28    right_elbow_shoulder_hip skew                                    float64
#  29    right_elbow_shoulder_hip quantile 25                             float64
#  30    right_elbow_shoulder_hip quantile 75                             float64
#  31    right_elbow_shoulder_hip RMS                                     float64
#  32    right_elbow_shoulder_hip MAV                                     float64
#  33    right_elbow_shoulder_hip rmse                                    float64
#  34    right_elbow_shoulder_hip mae                                     float64
#  35    right_elbow_shoulder_hip maxerror                                float64
#  36    right_elbow_shoulder_hip minerror                                float64
#  37    right_elbow_shoulder_hip stderror                                float64
#  38    right_elbow_shoulder_hip quantile25e                             float64
#  39    right_elbow_shoulder_hip quantile75e                             float64
#  40    left_wrist_elbow_shoulder mean_ft                                float64
#  41    left_wrist_elbow_shoulder std_ft                                 float64
#  42    left_wrist_elbow_shoulder max_ft                                 float64
#  43    left_wrist_elbow_shoulder min_ft                                 float64
#  44    left_wrist_elbow_shoulder var_ft                                 float64
#  45    left_wrist_elbow_shoulder med_ft                                 float64
#  46    left_wrist_elbow_shoulder sum_ft                                 float64
#  47    left_wrist_elbow_shoulder kurtosis                               float64
#  48    left_wrist_elbow_shoulder skew                                   float64
#  49    left_wrist_elbow_shoulder quantile 25                            float64
#  50    left_wrist_elbow_shoulder quantile 75                            float64
#  51    left_wrist_elbow_shoulder RMS                                    float64
#  52    left_wrist_elbow_shoulder MAV                                    float64
#  53    left_wrist_elbow_shoulder rmse                                   float64
#  54    left_wrist_elbow_shoulder mae                                    float64
#  55    left_wrist_elbow_shoulder maxerror                               float64
#  56    left_wrist_elbow_shoulder minerror                               float64
#  57    left_wrist_elbow_shoulder stderror                               float64
#  58    left_wrist_elbow_shoulder quantile25e                            float64
#  59    left_wrist_elbow_shoulder quantile75e                            float64
#  60    right_wrist_elbow_shoulder mean_ft                               float64
#  61    right_wrist_elbow_shoulder std_ft                                float64
#  62    right_wrist_elbow_shoulder max_ft                                float64
#  63    right_wrist_elbow_shoulder min_ft                                float64
#  64    right_wrist_elbow_shoulder var_ft                                float64
#  65    right_wrist_elbow_shoulder med_ft                                float64
#  66    right_wrist_elbow_shoulder sum_ft                                float64
#  67    right_wrist_elbow_shoulder kurtosis                              float64
#  68    right_wrist_elbow_shoulder skew                                  float64
#  69    right_wrist_elbow_shoulder quantile 25                           float64
#  70    right_wrist_elbow_shoulder quantile 75                           float64
#  71    right_wrist_elbow_shoulder RMS                                   float64
#  72    right_wrist_elbow_shoulder MAV                                   float64
#  73    right_wrist_elbow_shoulder rmse                                  float64
#  74    right_wrist_elbow_shoulder mae                                   float64
#  75    right_wrist_elbow_shoulder maxerror                              float64
#  76    right_wrist_elbow_shoulder minerror                              float64
#  77    right_wrist_elbow_shoulder stderror                              float64
#  78    right_wrist_elbow_shoulder quantile25e                           float64
#  79    right_wrist_elbow_shoulder quantile75e                           float64
#  80     right_elbow_shoulder mean_ft                                    float64
#  81     right_elbow_shoulder std_ft                                     float64
#  82     right_elbow_shoulder max_ft                                     float64
#  83     right_elbow_shoulder min_ft                                     float64
#  84     right_elbow_shoulder var_ft                                     float64
#  85     right_elbow_shoulder med_ft                                     float64
#  86     right_elbow_shoulder sum_ft                                     float64
#  87     right_elbow_shoulder kurtosis                                   float64
#  88     right_elbow_shoulder skew                                       float64
#  89     right_elbow_shoulder quantile 25                                float64
#  90     right_elbow_shoulder quantile 75                                float64
#  91     right_elbow_shoulder RMS                                        float64
#  92     right_elbow_shoulder MAV                                        float64
#  93     right_elbow_shoulder rmse                                       float64
#  94     right_elbow_shoulder mae                                        float64
#  95     right_elbow_shoulder maxerror                                   float64
#  96     right_elbow_shoulder minerror                                   float64
#  97     right_elbow_shoulder stderror                                   float64
#  98     right_elbow_shoulder quantile25e                                float64
#  99     right_elbow_shoulder quantile75e                                float64
#  100   left_elbow_shoulder mean_ft                                      float64
#  101   left_elbow_shoulder std_ft                                       float64
#  102   left_elbow_shoulder max_ft                                       float64
#  103   left_elbow_shoulder min_ft                                       float64
#  104   left_elbow_shoulder var_ft                                       float64
#  105   left_elbow_shoulder med_ft                                       float64
#  106   left_elbow_shoulder sum_ft                                       float64
#  107   left_elbow_shoulder kurtosis                                     float64
#  108   left_elbow_shoulder skew                                         float64
#  109   left_elbow_shoulder quantile 25                                  float64
#  110   left_elbow_shoulder quantile 75                                  float64
#  111   left_elbow_shoulder RMS                                          float64
#  112   left_elbow_shoulder MAV                                          float64
#  113   left_elbow_shoulder rmse                                         float64
#  114   left_elbow_shoulder mae                                          float64
#  115   left_elbow_shoulder maxerror                                     float64
#  116   left_elbow_shoulder minerror                                     float64
#  117   left_elbow_shoulder stderror                                     float64
#  118   left_elbow_shoulder quantile25e                                  float64
#  119   left_elbow_shoulder quantile75e                                  float64
#  120   elbow_center_elbow mean_ft                                       float64
#  121   elbow_center_elbow std_ft                                        float64
#  122   elbow_center_elbow max_ft                                        float64
#  123   elbow_center_elbow min_ft                                        float64
#  124   elbow_center_elbow var_ft                                        float64
#  125   elbow_center_elbow med_ft                                        float64
#  126   elbow_center_elbow sum_ft                                        float64
#  127   elbow_center_elbow kurtosis                                      float64
#  128   elbow_center_elbow skew                                          float64
#  129   elbow_center_elbow quantile 25                                   float64
#  130   elbow_center_elbow quantile 75                                   float64
#  131   elbow_center_elbow RMS                                           float64
#  132   elbow_center_elbow MAV                                           float64
#  133   elbow_center_elbow rmse                                          float64
#  134   elbow_center_elbow mae                                           float64
#  135   elbow_center_elbow maxerror                                      float64
#  136   elbow_center_elbow minerror                                      float64
#  137   elbow_center_elbow stderror                                      float64
#  138   elbow_center_elbow quantile25e                                   float64
#  139   elbow_center_elbow quantile75e                                   float64
#  140   shoulder_center_shoulder mean_ft                                 float64
#  141   shoulder_center_shoulder std_ft                                  float64
#  142   shoulder_center_shoulder max_ft                                  float64
#  143   shoulder_center_shoulder min_ft                                  float64
#  144   shoulder_center_shoulder var_ft                                  float64
#  145   shoulder_center_shoulder med_ft                                  float64
#  146   shoulder_center_shoulder sum_ft                                  float64
#  147   shoulder_center_shoulder kurtosis                                float64
#  148   shoulder_center_shoulder skew                                    float64
#  149   shoulder_center_shoulder quantile 25                             float64
#  150   shoulder_center_shoulder quantile 75                             float64
#  151   shoulder_center_shoulder RMS                                     float64
#  152   shoulder_center_shoulder MAV                                     float64
#  153   shoulder_center_shoulder rmse                                    float64
#  154   shoulder_center_shoulder mae                                     float64
#  155   shoulder_center_shoulder maxerror                                float64
#  156   shoulder_center_shoulder minerror                                float64
#  157   shoulder_center_shoulder stderror                                float64
#  158   shoulder_center_shoulder quantile25e                             float64
#  159   shoulder_center_shoulder quantile75e                             float64
#  160   wrist_center_wrist mean_ft                                       float64
#  161   wrist_center_wrist std_ft                                        float64
#  162   wrist_center_wrist max_ft                                        float64
#  163   wrist_center_wrist min_ft                                        float64
#  164   wrist_center_wrist var_ft                                        float64
#  165   wrist_center_wrist med_ft                                        float64
#  166   wrist_center_wrist sum_ft                                        float64
#  167   wrist_center_wrist kurtosis                                      float64
#  168   wrist_center_wrist skew                                          float64
#  169   wrist_center_wrist quantile 25                                   float64
#  170   wrist_center_wrist quantile 75                                   float64
#  171   wrist_center_wrist RMS                                           float64
#  172   wrist_center_wrist MAV                                           float64
#  173   wrist_center_wrist rmse                                          float64
#  174   wrist_center_wrist mae                                           float64
#  175   wrist_center_wrist maxerror                                      float64
#  176   wrist_center_wrist minerror                                      float64
#  177   wrist_center_wrist stderror                                      float64
#  178   wrist_center_wrist quantile25e                                   float64
#  179   wrist_center_wrist quantile75e                                   float64
#  180   nose_x mean_ft                                                   float64
#  181   nose_x std_ft                                                    float64
#  182   nose_x max_ft                                                    float64
#  183   nose_x min_ft                                                    float64
#  184   nose_x var_ft                                                    float64
#  185   nose_x med_ft                                                    float64
#  186   nose_x sum_ft                                                    float64
#  187   nose_x kurtosis                                                  float64
#  188   nose_x skew                                                      float64
#  189   nose_x quantile 25                                               float64
#  190   nose_x quantile 75                                               float64
#  191   nose_x RMS                                                       float64
#  192   nose_x MAV                                                       float64
#  193   nose_x rmse                                                      float64
#  194   nose_x mae                                                       float64
#  195   nose_x maxerror                                                  float64
#  196   nose_x minerror                                                  float64
#  197   nose_x stderror                                                  float64
#  198   nose_x quantile25e                                               float64
#  199   nose_x quantile75e                                               float64
#  200   nose_y mean_ft                                                   float64
#  201   nose_y std_ft                                                    float64
#  202   nose_y max_ft                                                    float64
#  203   nose_y min_ft                                                    float64
#  204   nose_y var_ft                                                    float64
#  205   nose_y med_ft                                                    float64
#  206   nose_y sum_ft                                                    float64
#  207   nose_y kurtosis                                                  float64
#  208   nose_y skew                                                      float64
#  209   nose_y quantile 25                                               float64
#  210   nose_y quantile 75                                               float64
#  211   nose_y RMS                                                       float64
#  212   nose_y MAV                                                       float64
#  213   nose_y rmse                                                      float64
#  214   nose_y mae                                                       float64
#  215   nose_y maxerror                                                  float64
#  216   nose_y minerror                                                  float64
#  217   nose_y stderror                                                  float64
#  218   nose_y quantile25e                                               float64
#  219   nose_y quantile75e                                               float64
#  220   left_eye_x mean_ft                                               float64
#  221   left_eye_x std_ft                                                float64
#  222   left_eye_x max_ft                                                float64
#  223   left_eye_x min_ft                                                float64
#  224   left_eye_x var_ft                                                float64
#  225   left_eye_x med_ft                                                float64
#  226   left_eye_x sum_ft                                                float64
#  227   left_eye_x kurtosis                                              float64
#  228   left_eye_x skew                                                  float64
#  229   left_eye_x quantile 25                                           float64
#  230   left_eye_x quantile 75                                           float64
#  231   left_eye_x RMS                                                   float64
#  232   left_eye_x MAV                                                   float64
#  233   left_eye_x rmse                                                  float64
#  234   left_eye_x mae                                                   float64
#  235   left_eye_x maxerror                                              float64
#  236   left_eye_x minerror                                              float64
#  237   left_eye_x stderror                                              float64
#  238   left_eye_x quantile25e                                           float64
#  239   left_eye_x quantile75e                                           float64
#  240   left_eye_y mean_ft                                               float64
#  241   left_eye_y std_ft                                                float64
#  242   left_eye_y max_ft                                                float64
#  243   left_eye_y min_ft                                                float64
#  244   left_eye_y var_ft                                                float64
#  245   left_eye_y med_ft                                                float64
#  246   left_eye_y sum_ft                                                float64
#  247   left_eye_y kurtosis                                              float64
#  248   left_eye_y skew                                                  float64
#  249   left_eye_y quantile 25                                           float64
#  250   left_eye_y quantile 75                                           float64
#  251   left_eye_y RMS                                                   float64
#  252   left_eye_y MAV                                                   float64
#  253   left_eye_y rmse                                                  float64
#  254   left_eye_y mae                                                   float64
#  255   left_eye_y maxerror                                              float64
#  256   left_eye_y minerror                                              float64
#  257   left_eye_y stderror                                              float64
#  258   left_eye_y quantile25e                                           float64
#  259   left_eye_y quantile75e                                           float64
#  260   right_eye_x mean_ft                                              float64
#  261   right_eye_x std_ft                                               float64
#  262   right_eye_x max_ft                                               float64
#  263   right_eye_x min_ft                                               float64
#  264   right_eye_x var_ft                                               float64
#  265   right_eye_x med_ft                                               float64
#  266   right_eye_x sum_ft                                               float64
#  267   right_eye_x kurtosis                                             float64
#  268   right_eye_x skew                                                 float64
#  269   right_eye_x quantile 25                                          float64
#  270   right_eye_x quantile 75                                          float64
#  271   right_eye_x RMS                                                  float64
#  272   right_eye_x MAV                                                  float64
#  273   right_eye_x rmse                                                 float64
#  274   right_eye_x mae                                                  float64
#  275   right_eye_x maxerror                                             float64
#  276   right_eye_x minerror                                             float64
#  277   right_eye_x stderror                                             float64
#  278   right_eye_x quantile25e                                          float64
#  279   right_eye_x quantile75e                                          float64
#  280   right_eye_y mean_ft                                              float64
#  281   right_eye_y std_ft                                               float64
#  282   right_eye_y max_ft                                               float64
#  283   right_eye_y min_ft                                               float64
#  284   right_eye_y var_ft                                               float64
#  285   right_eye_y med_ft                                               float64
#  286   right_eye_y sum_ft                                               float64
#  287   right_eye_y kurtosis                                             float64
#  288   right_eye_y skew                                                 float64
#  289   right_eye_y quantile 25                                          float64
#  290   right_eye_y quantile 75                                          float64
#  291   right_eye_y RMS                                                  float64
#  292   right_eye_y MAV                                                  float64
#  293   right_eye_y rmse                                                 float64
#  294   right_eye_y mae                                                  float64
#  295   right_eye_y maxerror                                             float64
#  296   right_eye_y minerror                                             float64
#  297   right_eye_y stderror                                             float64
#  298   right_eye_y quantile25e                                          float64
#  299   right_eye_y quantile75e                                          float64
#  300   left_ear_x mean_ft                                               float64
#  301   left_ear_x std_ft                                                float64
#  302   left_ear_x max_ft                                                float64
#  303   left_ear_x min_ft                                                float64
#  304   left_ear_x var_ft                                                float64
#  305   left_ear_x med_ft                                                float64
#  306   left_ear_x sum_ft                                                float64
#  307   left_ear_x kurtosis                                              float64
#  308   left_ear_x skew                                                  float64
#  309   left_ear_x quantile 25                                           float64
#  310   left_ear_x quantile 75                                           float64
#  311   left_ear_x RMS                                                   float64
#  312   left_ear_x MAV                                                   float64
#  313   left_ear_x rmse                                                  float64
#  314   left_ear_x mae                                                   float64
#  315   left_ear_x maxerror                                              float64
#  316   left_ear_x minerror                                              float64
#  317   left_ear_x stderror                                              float64
#  318   left_ear_x quantile25e                                           float64
#  319   left_ear_x quantile75e                                           float64
#  320   left_ear_y mean_ft                                               float64
#  321   left_ear_y std_ft                                                float64
#  322   left_ear_y max_ft                                                float64
#  323   left_ear_y min_ft                                                float64
#  324   left_ear_y var_ft                                                float64
#  325   left_ear_y med_ft                                                float64
#  326   left_ear_y sum_ft                                                float64
#  327   left_ear_y kurtosis                                              float64
#  328   left_ear_y skew                                                  float64
#  329   left_ear_y quantile 25                                           float64
#  330   left_ear_y quantile 75                                           float64
#  331   left_ear_y RMS                                                   float64
#  332   left_ear_y MAV                                                   float64
#  333   left_ear_y rmse                                                  float64
#  334   left_ear_y mae                                                   float64
#  335   left_ear_y maxerror                                              float64
#  336   left_ear_y minerror                                              float64
#  337   left_ear_y stderror                                              float64
#  338   left_ear_y quantile25e                                           float64
#  339   left_ear_y quantile75e                                           float64
#  340   right_ear_x mean_ft                                              float64
#  341   right_ear_x std_ft                                               float64
#  342   right_ear_x max_ft                                               float64
#  343   right_ear_x min_ft                                               float64
#  344   right_ear_x var_ft                                               float64
#  345   right_ear_x med_ft                                               float64
#  346   right_ear_x sum_ft                                               float64
#  347   right_ear_x kurtosis                                             float64
#  348   right_ear_x skew                                                 float64
#  349   right_ear_x quantile 25                                          float64
#  350   right_ear_x quantile 75                                          float64
#  351   right_ear_x RMS                                                  float64
#  352   right_ear_x MAV                                                  float64
#  353   right_ear_x rmse                                                 float64
#  354   right_ear_x mae                                                  float64
#  355   right_ear_x maxerror                                             float64
#  356   right_ear_x minerror                                             float64
#  357   right_ear_x stderror                                             float64
#  358   right_ear_x quantile25e                                          float64
#  359   right_ear_x quantile75e                                          float64
#  360   right_ear_y mean_ft                                              float64
#  361   right_ear_y std_ft                                               float64
#  362   right_ear_y max_ft                                               float64
#  363   right_ear_y min_ft                                               float64
#  364   right_ear_y var_ft                                               float64
#  365   right_ear_y med_ft                                               float64
#  366   right_ear_y sum_ft                                               float64
#  367   right_ear_y kurtosis                                             float64
#  368   right_ear_y skew                                                 float64
#  369   right_ear_y quantile 25                                          float64
#  370   right_ear_y quantile 75                                          float64
#  371   right_ear_y RMS                                                  float64
#  372   right_ear_y MAV                                                  float64
#  373   right_ear_y rmse                                                 float64
#  374   right_ear_y mae                                                  float64
#  375   right_ear_y maxerror                                             float64
#  376   right_ear_y minerror                                             float64
#  377   right_ear_y stderror                                             float64
#  378   right_ear_y quantile25e                                          float64
#  379   right_ear_y quantile75e                                          float64
#  380   left_shoulder_x mean_ft                                          float64
#  381   left_shoulder_x std_ft                                           float64
#  382   left_shoulder_x max_ft                                           float64
#  383   left_shoulder_x min_ft                                           float64
#  384   left_shoulder_x var_ft                                           float64
#  385   left_shoulder_x med_ft                                           float64
#  386   left_shoulder_x sum_ft                                           float64
#  387   left_shoulder_x kurtosis                                         float64
#  388   left_shoulder_x skew                                             float64
#  389   left_shoulder_x quantile 25                                      float64
#  390   left_shoulder_x quantile 75                                      float64
#  391   left_shoulder_x RMS                                              float64
#  392   left_shoulder_x MAV                                              float64
#  393   left_shoulder_x rmse                                             float64
#  394   left_shoulder_x mae                                              float64
#  395   left_shoulder_x maxerror                                         float64
#  396   left_shoulder_x minerror                                         float64
#  397   left_shoulder_x stderror                                         float64
#  398   left_shoulder_x quantile25e                                      float64
#  399   left_shoulder_x quantile75e                                      float64
#  400   left_shoulder_y mean_ft                                          float64
#  401   left_shoulder_y std_ft                                           float64
#  402   left_shoulder_y max_ft                                           float64
#  403   left_shoulder_y min_ft                                           float64
#  404   left_shoulder_y var_ft                                           float64
#  405   left_shoulder_y med_ft                                           float64
#  406   left_shoulder_y sum_ft                                           float64
#  407   left_shoulder_y kurtosis                                         float64
#  408   left_shoulder_y skew                                             float64
#  409   left_shoulder_y quantile 25                                      float64
#  410   left_shoulder_y quantile 75                                      float64
#  411   left_shoulder_y RMS                                              float64
#  412   left_shoulder_y MAV                                              float64
#  413   left_shoulder_y rmse                                             float64
#  414   left_shoulder_y mae                                              float64
#  415   left_shoulder_y maxerror                                         float64
#  416   left_shoulder_y minerror                                         float64
#  417   left_shoulder_y stderror                                         float64
#  418   left_shoulder_y quantile25e                                      float64
#  419   left_shoulder_y quantile75e                                      float64
#  420   right_shoulder_x mean_ft                                         float64
#  421   right_shoulder_x std_ft                                          float64
#  422   right_shoulder_x max_ft                                          float64
#  423   right_shoulder_x min_ft                                          float64
#  424   right_shoulder_x var_ft                                          float64
#  425   right_shoulder_x med_ft                                          float64
#  426   right_shoulder_x sum_ft                                          float64
#  427   right_shoulder_x kurtosis                                        float64
#  428   right_shoulder_x skew                                            float64
#  429   right_shoulder_x quantile 25                                     float64
#  430   right_shoulder_x quantile 75                                     float64
#  431   right_shoulder_x RMS                                             float64
#  432   right_shoulder_x MAV                                             float64
#  433   right_shoulder_x rmse                                            float64
#  434   right_shoulder_x mae                                             float64
#  435   right_shoulder_x maxerror                                        float64
#  436   right_shoulder_x minerror                                        float64
#  437   right_shoulder_x stderror                                        float64
#  438   right_shoulder_x quantile25e                                     float64
#  439   right_shoulder_x quantile75e                                     float64
#  440   right_shoulder_y mean_ft                                         float64
#  441   right_shoulder_y std_ft                                          float64
#  442   right_shoulder_y max_ft                                          float64
#  443   right_shoulder_y min_ft                                          float64
#  444   right_shoulder_y var_ft                                          float64
#  445   right_shoulder_y med_ft                                          float64
#  446   right_shoulder_y sum_ft                                          float64
#  447   right_shoulder_y kurtosis                                        float64
#  448   right_shoulder_y skew                                            float64
#  449   right_shoulder_y quantile 25                                     float64
#  450   right_shoulder_y quantile 75                                     float64
#  451   right_shoulder_y RMS                                             float64
#  452   right_shoulder_y MAV                                             float64
#  453   right_shoulder_y rmse                                            float64
#  454   right_shoulder_y mae                                             float64
#  455   right_shoulder_y maxerror                                        float64
#  456   right_shoulder_y minerror                                        float64
#  457   right_shoulder_y stderror                                        float64
#  458   right_shoulder_y quantile25e                                     float64
#  459   right_shoulder_y quantile75e                                     float64
#  460   left_elbow_x mean_ft                                             float64
#  461   left_elbow_x std_ft                                              float64
#  462   left_elbow_x max_ft                                              float64
#  463   left_elbow_x min_ft                                              float64
#  464   left_elbow_x var_ft                                              float64
#  465   left_elbow_x med_ft                                              float64
#  466   left_elbow_x sum_ft                                              float64
#  467   left_elbow_x kurtosis                                            float64
#  468   left_elbow_x skew                                                float64
#  469   left_elbow_x quantile 25                                         float64
#  470   left_elbow_x quantile 75                                         float64
#  471   left_elbow_x RMS                                                 float64
#  472   left_elbow_x MAV                                                 float64
#  473   left_elbow_x rmse                                                float64
#  474   left_elbow_x mae                                                 float64
#  475   left_elbow_x maxerror                                            float64
#  476   left_elbow_x minerror                                            float64
#  477   left_elbow_x stderror                                            float64
#  478   left_elbow_x quantile25e                                         float64
#  479   left_elbow_x quantile75e                                         float64
#  480   left_elbow_y mean_ft                                             float64
#  481   left_elbow_y std_ft                                              float64
#  482   left_elbow_y max_ft                                              float64
#  483   left_elbow_y min_ft                                              float64
#  484   left_elbow_y var_ft                                              float64
#  485   left_elbow_y med_ft                                              float64
#  486   left_elbow_y sum_ft                                              float64
#  487   left_elbow_y kurtosis                                            float64
#  488   left_elbow_y skew                                                float64
#  489   left_elbow_y quantile 25                                         float64
#  490   left_elbow_y quantile 75                                         float64
#  491   left_elbow_y RMS                                                 float64
#  492   left_elbow_y MAV                                                 float64
#  493   left_elbow_y rmse                                                float64
#  494   left_elbow_y mae                                                 float64
#  495   left_elbow_y maxerror                                            float64
#  496   left_elbow_y minerror                                            float64
#  497   left_elbow_y stderror                                            float64
#  498   left_elbow_y quantile25e                                         float64
#  499   left_elbow_y quantile75e                                         float64
#  500   right_elbow_x mean_ft                                            float64
#  501   right_elbow_x std_ft                                             float64
#  502   right_elbow_x max_ft                                             float64
#  503   right_elbow_x min_ft                                             float64
#  504   right_elbow_x var_ft                                             float64
#  505   right_elbow_x med_ft                                             float64
#  506   right_elbow_x sum_ft                                             float64
#  507   right_elbow_x kurtosis                                           float64
#  508   right_elbow_x skew                                               float64
#  509   right_elbow_x quantile 25                                        float64
#  510   right_elbow_x quantile 75                                        float64
#  511   right_elbow_x RMS                                                float64
#  512   right_elbow_x MAV                                                float64
#  513   right_elbow_x rmse                                               float64
#  514   right_elbow_x mae                                                float64
#  515   right_elbow_x maxerror                                           float64
#  516   right_elbow_x minerror                                           float64
#  517   right_elbow_x stderror                                           float64
#  518   right_elbow_x quantile25e                                        float64
#  519   right_elbow_x quantile75e                                        float64
#  520   right_elbow_y mean_ft                                            float64
#  521   right_elbow_y std_ft                                             float64
#  522   right_elbow_y max_ft                                             float64
#  523   right_elbow_y min_ft                                             float64
#  524   right_elbow_y var_ft                                             float64
#  525   right_elbow_y med_ft                                             float64
#  526   right_elbow_y sum_ft                                             float64
#  527   right_elbow_y kurtosis                                           float64
#  528   right_elbow_y skew                                               float64
#  529   right_elbow_y quantile 25                                        float64
#  530   right_elbow_y quantile 75                                        float64
#  531   right_elbow_y RMS                                                float64
#  532   right_elbow_y MAV                                                float64
#  533   right_elbow_y rmse                                               float64
#  534   right_elbow_y mae                                                float64
#  535   right_elbow_y maxerror                                           float64
#  536   right_elbow_y minerror                                           float64
#  537   right_elbow_y stderror                                           float64
#  538   right_elbow_y quantile25e                                        float64
#  539   right_elbow_y quantile75e                                        float64
#  540   left_wrist_x mean_ft                                             float64
#  541   left_wrist_x std_ft                                              float64
#  542   left_wrist_x max_ft                                              float64
#  543   left_wrist_x min_ft                                              float64
#  544   left_wrist_x var_ft                                              float64
#  545   left_wrist_x med_ft                                              float64
#  546   left_wrist_x sum_ft                                              float64
#  547   left_wrist_x kurtosis                                            float64
#  548   left_wrist_x skew                                                float64
#  549   left_wrist_x quantile 25                                         float64
#  550   left_wrist_x quantile 75                                         float64
#  551   left_wrist_x RMS                                                 float64
#  552   left_wrist_x MAV                                                 float64
#  553   left_wrist_x rmse                                                float64
#  554   left_wrist_x mae                                                 float64
#  555   left_wrist_x maxerror                                            float64
#  556   left_wrist_x minerror                                            float64
#  557   left_wrist_x stderror                                            float64
#  558   left_wrist_x quantile25e                                         float64
#  559   left_wrist_x quantile75e                                         float64
#  560   left_wrist_y mean_ft                                             float64
#  561   left_wrist_y std_ft                                              float64
#  562   left_wrist_y max_ft                                              float64
#  563   left_wrist_y min_ft                                              float64
#  564   left_wrist_y var_ft                                              float64
#  565   left_wrist_y med_ft                                              float64
#  566   left_wrist_y sum_ft                                              float64
#  567   left_wrist_y kurtosis                                            float64
#  568   left_wrist_y skew                                                float64
#  569   left_wrist_y quantile 25                                         float64
#  570   left_wrist_y quantile 75                                         float64
#  571   left_wrist_y RMS                                                 float64
#  572   left_wrist_y MAV                                                 float64
#  573   left_wrist_y rmse                                                float64
#  574   left_wrist_y mae                                                 float64
#  575   left_wrist_y maxerror                                            float64
#  576   left_wrist_y minerror                                            float64
#  577   left_wrist_y stderror                                            float64
#  578   left_wrist_y quantile25e                                         float64
#  579   left_wrist_y quantile75e                                         float64
#  580   right_wrist_x mean_ft                                            float64
#  581   right_wrist_x std_ft                                             float64
#  582   right_wrist_x max_ft                                             float64
#  583   right_wrist_x min_ft                                             float64
#  584   right_wrist_x var_ft                                             float64
#  585   right_wrist_x med_ft                                             float64
#  586   right_wrist_x sum_ft                                             float64
#  587   right_wrist_x kurtosis                                           float64
#  588   right_wrist_x skew                                               float64
#  589   right_wrist_x quantile 25                                        float64
#  590   right_wrist_x quantile 75                                        float64
#  591   right_wrist_x RMS                                                float64
#  592   right_wrist_x MAV                                                float64
#  593   right_wrist_x rmse                                               float64
#  594   right_wrist_x mae                                                float64
#  595   right_wrist_x maxerror                                           float64
# ...
#  8485  movingright_shoulder left_wrist dx med_ft previous 12 s          float64
#  8486  movingright_shoulder left_wrist dx sum_ft previous 12 s          float64
#  8487  movingright_shoulder left_wrist dx kurtosis previous 12 s        float64
#  8488  movingright_shoulder left_wrist dx skew previous 12 s            float64
#  8489  movingright_shoulder left_wrist dx quantile 25 previous 12 s     float64
#  8490  movingright_shoulder left_wrist dx quantile 75 previous 12 s     float64
#  8491  movingright_shoulder left_wrist dx RMS previous 12 s             float64
#  8492  movingright_shoulder left_wrist dx MAV previous 12 s             float64
#  8493  movingright_shoulder left_wrist dx rmse previous 12 s            float64
#  8494  movingright_shoulder left_wrist dx mae previous 12 s             float64
#  8495  movingright_shoulder left_wrist dx maxerror previous 12 s        float64
#  8496  movingright_shoulder left_wrist dx minerror previous 12 s        float64
#  8497  movingright_shoulder left_wrist dx stderror previous 12 s        float64
#  8498  movingright_shoulder left_wrist dx quantile25e previous 12 s     float64
#  8499  movingright_shoulder left_wrist dx quantile75e previous 12 s     float64
#  8500  movingright_shoulder left_wrist dy mean_ft previous 12 s         float64
#  8501  movingright_shoulder left_wrist dy std_ft previous 12 s          float64
#  8502  movingright_shoulder left_wrist dy max_ft previous 12 s          float64
#  8503  movingright_shoulder left_wrist dy min_ft previous 12 s          float64
#  8504  movingright_shoulder left_wrist dy var_ft previous 12 s          float64
#  8505  movingright_shoulder left_wrist dy med_ft previous 12 s          float64
#  8506  movingright_shoulder left_wrist dy sum_ft previous 12 s          float64
#  8507  movingright_shoulder left_wrist dy kurtosis previous 12 s        float64
#  8508  movingright_shoulder left_wrist dy skew previous 12 s            float64
#  8509  movingright_shoulder left_wrist dy quantile 25 previous 12 s     float64
#  8510  movingright_shoulder left_wrist dy quantile 75 previous 12 s     float64
#  8511  movingright_shoulder left_wrist dy RMS previous 12 s             float64
#  8512  movingright_shoulder left_wrist dy MAV previous 12 s             float64
#  8513  movingright_shoulder left_wrist dy rmse previous 12 s            float64
#  8514  movingright_shoulder left_wrist dy mae previous 12 s             float64
#  8515  movingright_shoulder left_wrist dy maxerror previous 12 s        float64
#  8516  movingright_shoulder left_wrist dy minerror previous 12 s        float64
#  8517  movingright_shoulder left_wrist dy stderror previous 12 s        float64
#  8518  movingright_shoulder left_wrist dy quantile25e previous 12 s     float64
#  8519  movingright_shoulder left_wrist dy quantile75e previous 12 s     float64
#  8520  movingright_shoulder right_wrist dx mean_ft previous 12 s        float64
#  8521  movingright_shoulder right_wrist dx std_ft previous 12 s         float64
#  8522  movingright_shoulder right_wrist dx max_ft previous 12 s         float64
#  8523  movingright_shoulder right_wrist dx min_ft previous 12 s         float64
#  8524  movingright_shoulder right_wrist dx var_ft previous 12 s         float64
#  8525  movingright_shoulder right_wrist dx med_ft previous 12 s         float64
#  8526  movingright_shoulder right_wrist dx sum_ft previous 12 s         float64
#  8527  movingright_shoulder right_wrist dx kurtosis previous 12 s       float64
#  8528  movingright_shoulder right_wrist dx skew previous 12 s           float64
#  8529  movingright_shoulder right_wrist dx quantile 25 previous 12 s    float64
#  8530  movingright_shoulder right_wrist dx quantile 75 previous 12 s    float64
#  8531  movingright_shoulder right_wrist dx RMS previous 12 s            float64
#  8532  movingright_shoulder right_wrist dx MAV previous 12 s            float64
#  8533  movingright_shoulder right_wrist dx rmse previous 12 s           float64
#  8534  movingright_shoulder right_wrist dx mae previous 12 s            float64
#  8535  movingright_shoulder right_wrist dx maxerror previous 12 s       float64
#  8536  movingright_shoulder right_wrist dx minerror previous 12 s       float64
#  8537  movingright_shoulder right_wrist dx stderror previous 12 s       float64
#  8538  movingright_shoulder right_wrist dx quantile25e previous 12 s    float64
#  8539  movingright_shoulder right_wrist dx quantile75e previous 12 s    float64
#  8540  movingright_shoulder right_wrist dy mean_ft previous 12 s        float64
#  8541  movingright_shoulder right_wrist dy std_ft previous 12 s         float64
#  8542  movingright_shoulder right_wrist dy max_ft previous 12 s         float64
#  8543  movingright_shoulder right_wrist dy min_ft previous 12 s         float64
#  8544  movingright_shoulder right_wrist dy var_ft previous 12 s         float64
#  8545  movingright_shoulder right_wrist dy med_ft previous 12 s         float64
#  8546  movingright_shoulder right_wrist dy sum_ft previous 12 s         float64
#  8547  movingright_shoulder right_wrist dy kurtosis previous 12 s       float64
#  8548  movingright_shoulder right_wrist dy skew previous 12 s           float64
#  8549  movingright_shoulder right_wrist dy quantile 25 previous 12 s    float64
#  8550  movingright_shoulder right_wrist dy quantile 75 previous 12 s    float64
#  8551  movingright_shoulder right_wrist dy RMS previous 12 s            float64
#  8552  movingright_shoulder right_wrist dy MAV previous 12 s            float64
#  8553  movingright_shoulder right_wrist dy rmse previous 12 s           float64
#  8554  movingright_shoulder right_wrist dy mae previous 12 s            float64
#  8555  movingright_shoulder right_wrist dy maxerror previous 12 s       float64
#  8556  movingright_shoulder right_wrist dy minerror previous 12 s       float64
#  8557  movingright_shoulder right_wrist dy stderror previous 12 s       float64
#  8558  movingright_shoulder right_wrist dy quantile25e previous 12 s    float64
#  8559  movingright_shoulder right_wrist dy quantile75e previous 12 s    float64
#  8560  movingright_shoulder left_hip dx mean_ft previous 12 s           float64
#  8561  movingright_shoulder left_hip dx std_ft previous 12 s            float64
#  8562  movingright_shoulder left_hip dx max_ft previous 12 s            float64
#  8563  movingright_shoulder left_hip dx min_ft previous 12 s            float64
#  8564  movingright_shoulder left_hip dx var_ft previous 12 s            float64
#  8565  movingright_shoulder left_hip dx med_ft previous 12 s            float64
#  8566  movingright_shoulder left_hip dx sum_ft previous 12 s            float64
#  8567  movingright_shoulder left_hip dx kurtosis previous 12 s          float64
#  8568  movingright_shoulder left_hip dx skew previous 12 s              float64
#  8569  movingright_shoulder left_hip dx quantile 25 previous 12 s       float64
#  8570  movingright_shoulder left_hip dx quantile 75 previous 12 s       float64
#  8571  movingright_shoulder left_hip dx RMS previous 12 s               float64
#  8572  movingright_shoulder left_hip dx MAV previous 12 s               float64
#  8573  movingright_shoulder left_hip dx rmse previous 12 s              float64
#  8574  movingright_shoulder left_hip dx mae previous 12 s               float64
#  8575  movingright_shoulder left_hip dx maxerror previous 12 s          float64
#  8576  movingright_shoulder left_hip dx minerror previous 12 s          float64
#  8577  movingright_shoulder left_hip dx stderror previous 12 s          float64
#  8578  movingright_shoulder left_hip dx quantile25e previous 12 s       float64
#  8579  movingright_shoulder left_hip dx quantile75e previous 12 s       float64
#  8580  movingright_shoulder left_hip dy mean_ft previous 12 s           float64
#  8581  movingright_shoulder left_hip dy std_ft previous 12 s            float64
#  8582  movingright_shoulder left_hip dy max_ft previous 12 s            float64
#  8583  movingright_shoulder left_hip dy min_ft previous 12 s            float64
#  8584  movingright_shoulder left_hip dy var_ft previous 12 s            float64
#  8585  movingright_shoulder left_hip dy med_ft previous 12 s            float64
#  8586  movingright_shoulder left_hip dy sum_ft previous 12 s            float64
#  8587  movingright_shoulder left_hip dy kurtosis previous 12 s          float64
#  8588  movingright_shoulder left_hip dy skew previous 12 s              float64
#  8589  movingright_shoulder left_hip dy quantile 25 previous 12 s       float64
#  8590  movingright_shoulder left_hip dy quantile 75 previous 12 s       float64
#  8591  movingright_shoulder left_hip dy RMS previous 12 s               float64
#  8592  movingright_shoulder left_hip dy MAV previous 12 s               float64
#  8593  movingright_shoulder left_hip dy rmse previous 12 s              float64
#  8594  movingright_shoulder left_hip dy mae previous 12 s               float64
#  8595  movingright_shoulder left_hip dy maxerror previous 12 s          float64
#  8596  movingright_shoulder left_hip dy minerror previous 12 s          float64
#  8597  movingright_shoulder left_hip dy stderror previous 12 s          float64
#  8598  movingright_shoulder left_hip dy quantile25e previous 12 s       float64
#  8599  movingright_shoulder left_hip dy quantile75e previous 12 s       float64
#  8600  movingright_shoulder right_hip dx mean_ft previous 12 s          float64
#  8601  movingright_shoulder right_hip dx std_ft previous 12 s           float64
#  8602  movingright_shoulder right_hip dx max_ft previous 12 s           float64
#  8603  movingright_shoulder right_hip dx min_ft previous 12 s           float64
#  8604  movingright_shoulder right_hip dx var_ft previous 12 s           float64
#  8605  movingright_shoulder right_hip dx med_ft previous 12 s           float64
#  8606  movingright_shoulder right_hip dx sum_ft previous 12 s           float64
#  8607  movingright_shoulder right_hip dx kurtosis previous 12 s         float64
#  8608  movingright_shoulder right_hip dx skew previous 12 s             float64
#  8609  movingright_shoulder right_hip dx quantile 25 previous 12 s      float64
#  8610  movingright_shoulder right_hip dx quantile 75 previous 12 s      float64
#  8611  movingright_shoulder right_hip dx RMS previous 12 s              float64
#  8612  movingright_shoulder right_hip dx MAV previous 12 s              float64
#  8613  movingright_shoulder right_hip dx rmse previous 12 s             float64
#  8614  movingright_shoulder right_hip dx mae previous 12 s              float64
#  8615  movingright_shoulder right_hip dx maxerror previous 12 s         float64
#  8616  movingright_shoulder right_hip dx minerror previous 12 s         float64
#  8617  movingright_shoulder right_hip dx stderror previous 12 s         float64
#  8618  movingright_shoulder right_hip dx quantile25e previous 12 s      float64
#  8619  movingright_shoulder right_hip dx quantile75e previous 12 s      float64
#  8620  movingright_shoulder right_hip dy mean_ft previous 12 s          float64
#  8621  movingright_shoulder right_hip dy std_ft previous 12 s           float64
#  8622  movingright_shoulder right_hip dy max_ft previous 12 s           float64
#  8623  movingright_shoulder right_hip dy min_ft previous 12 s           float64
#  8624  movingright_shoulder right_hip dy var_ft previous 12 s           float64
#  8625  movingright_shoulder right_hip dy med_ft previous 12 s           float64
#  8626  movingright_shoulder right_hip dy sum_ft previous 12 s           float64
#  8627  movingright_shoulder right_hip dy kurtosis previous 12 s         float64
#  8628  movingright_shoulder right_hip dy skew previous 12 s             float64
#  8629  movingright_shoulder right_hip dy quantile 25 previous 12 s      float64
#  8630  movingright_shoulder right_hip dy quantile 75 previous 12 s      float64
#  8631  movingright_shoulder right_hip dy RMS previous 12 s              float64
#  8632  movingright_shoulder right_hip dy MAV previous 12 s              float64
#  8633  movingright_shoulder right_hip dy rmse previous 12 s             float64
#  8634  movingright_shoulder right_hip dy mae previous 12 s              float64
#  8635  movingright_shoulder right_hip dy maxerror previous 12 s         float64
#  8636  movingright_shoulder right_hip dy minerror previous 12 s         float64
#  8637  movingright_shoulder right_hip dy stderror previous 12 s         float64
#  8638  movingright_shoulder right_hip dy quantile25e previous 12 s      float64
#  8639  movingright_shoulder right_hip dy quantile75e previous 12 s      float64
#  8640  movingcenter_x mean_ft previous 12 s                             float64
#  8641  movingcenter_x std_ft previous 12 s                              float64
#  8642  movingcenter_x max_ft previous 12 s                              float64
#  8643  movingcenter_x min_ft previous 12 s                              float64
#  8644  movingcenter_x var_ft previous 12 s                              float64
#  8645  movingcenter_x med_ft previous 12 s                              float64
#  8646  movingcenter_x sum_ft previous 12 s                              float64
#  8647  movingcenter_x kurtosis previous 12 s                            float64
#  8648  movingcenter_x skew previous 12 s                                float64
#  8649  movingcenter_x quantile 25 previous 12 s                         float64
#  8650  movingcenter_x quantile 75 previous 12 s                         float64
#  8651  movingcenter_x RMS previous 12 s                                 float64
#  8652  movingcenter_x MAV previous 12 s                                 float64
#  8653  movingcenter_x rmse previous 12 s                                float64
#  8654  movingcenter_x mae previous 12 s                                 float64
#  8655  movingcenter_x maxerror previous 12 s                            float64
#  8656  movingcenter_x minerror previous 12 s                            float64
#  8657  movingcenter_x stderror previous 12 s                            float64
#  8658  movingcenter_x quantile25e previous 12 s                         float64
#  8659  movingcenter_x quantile75e previous 12 s                         float64
#  8660  movingcenter_y mean_ft previous 12 s                             float64
#  8661  movingcenter_y std_ft previous 12 s                              float64
#  8662  movingcenter_y max_ft previous 12 s                              float64
#  8663  movingcenter_y min_ft previous 12 s                              float64
#  8664  movingcenter_y var_ft previous 12 s                              float64
#  8665  movingcenter_y med_ft previous 12 s                              float64
#  8666  movingcenter_y sum_ft previous 12 s                              float64
#  8667  movingcenter_y kurtosis previous 12 s                            float64
#  8668  movingcenter_y skew previous 12 s                                float64
#  8669  movingcenter_y quantile 25 previous 12 s                         float64
#  8670  movingcenter_y quantile 75 previous 12 s                         float64
#  8671  movingcenter_y RMS previous 12 s                                 float64
#  8672  movingcenter_y MAV previous 12 s                                 float64
#  8673  movingcenter_y rmse previous 12 s                                float64
#  8674  movingcenter_y mae previous 12 s                                 float64
#  8675  movingcenter_y maxerror previous 12 s                            float64
#  8676  movingcenter_y minerror previous 12 s                            float64
#  8677  movingcenter_y stderror previous 12 s                            float64
#  8678  movingcenter_y quantile25e previous 12 s                         float64
#  8679  movingcenter_y quantile75e previous 12 s                         float64
#  8680  previous_label                                                   int64
#  8681  label                                                            float64
#  8682  after1                                                           int64
#  8683  after4                                                           int64
# dtypes: float64(8681), int64(3)
# memory usage: 257.3 MB

# %%
sns.histplot(df["label"])
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='label', ylabel='Count'>

# %%
X=df.drop(["label","previous_label",'after1','after4'],axis=1)
y=df['label']

# %%
X.shape
# Out:
# (3883, 8680)

# %%
y.shape
# Out:
# (3883,)

# %%
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='logloss', random_state=10)
# xgbcl.fit(X_train,y_train)
# # filename = './xgb_model.sav'
# # xgbcl=joblib.load(filename)
# pred=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.ensemble import RandomForestClassifier #Random Forest
# rf=RandomForestClassifier(random_state=10)
# rf.fit(X_train,y_train)
# pred=rf.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# import joblib
# filename = './xgb_model.sav'
# joblib.dump(xgbcl, filename)

# %%
# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(X_train,y_train)
# pred=svc.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
# knn = RadiusNeighborsClassifier(radius=175)
# knn.fit(X_train,y_train)
# pred=knn.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.linear_model import SGDClassifier
## sgd=SGDClassifier()loss='epsilon_insensitive'
# sgd.fit(X_train,y_train)
# pred=sgd.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.feature_selection import SelectKBest,f_regression
# # Applying SelectKBest class to extract top 15 best features
# fs = SelectKBest(score_func=f_regression,k=15)
# # Applying feature selection
# fit = fs.fit(X,y)
# features_score = pd.DataFrame(fit.scores_)
# features = pd.DataFrame(X.columns)
# feature_score = pd.concat([features,features_score],axis=1)
# # Assigning column names
# feature_score.columns = ["Input_Features","F_Score"]
# print(feature_score.nlargest(300,columns="F_Score"))
# # dfi.export(feature_score.nlargest(16,columns="F_Score"),'./image/fulltest/f_test.png')
# # feature_score.nlargest(300,columns="F_Score")['Input_Features'].values

# %%
X_train=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train=y
X_test=test.drop(["label","previous_label"],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test=test['label']

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier #Random Forest
# try:
# oversampling the train dataset using SMOTE

sm = SMOTE()
all_feature_smote, all_label_smote = sm.fit_resample(X_train,y_train)
# rf=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf.fit(all_feature_smote, all_label_smote)
# # filename = './model/smote_rf_model.sav'
# # rf=joblib.load(filename)
# pred_rf=rf.predict(X_test)

# print(metrics.classification_report(pred_rf,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model/smote_rf_model2.sav'
# joblib.dump(rf, filename)

# %%
a=[e for e in X_train if e not in X_test]
a
# Out:
# []

# %%
from xgboost import XGBClassifier#XGBcalssifier
from xgboost import callback
early_stop = callback.EarlyStopping(
    rounds=4, metric_name='mlogloss', save_best=True
)
try:
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    pred_xgb=xgbcl.predict(X_test)
except:
    xgbcl=XGBClassifier( eval_metric='mlogloss', random_state=10,callbacks=[early_stop])
    xgbcl.fit(all_feature_smote, all_label_smote,eval_set=[(X_test, y_test)])
    pred_xgb=xgbcl.predict(X_test)

from sklearn import metrics #accuracy measure
print(metrics.classification_report(pred_xgb,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_xgb,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# [0]	validation_0-mlogloss:1.90566
# [1]	validation_0-mlogloss:1.76696
# [2]	validation_0-mlogloss:1.65673
# [3]	validation_0-mlogloss:1.54552
# [4]	validation_0-mlogloss:1.45589
# [5]	validation_0-mlogloss:1.37610
# [6]	validation_0-mlogloss:1.30844
# [7]	validation_0-mlogloss:1.24335
# [8]	validation_0-mlogloss:1.19531
# [9]	validation_0-mlogloss:1.14377
# [10]	validation_0-mlogloss:1.10845
# [11]	validation_0-mlogloss:1.08873
# [12]	validation_0-mlogloss:1.09178
# [13]	validation_0-mlogloss:1.06829
# [14]	validation_0-mlogloss:1.06416
# [15]	validation_0-mlogloss:1.03468
# [16]	validation_0-mlogloss:1.03076
# [17]	validation_0-mlogloss:1.02201
# [18]	validation_0-mlogloss:1.02486
# [19]	validation_0-mlogloss:1.00415
# [20]	validation_0-mlogloss:0.99804
# [21]	validation_0-mlogloss:0.98949
# [22]	validation_0-mlogloss:0.98168
# [23]	validation_0-mlogloss:0.97305
# [24]	validation_0-mlogloss:0.96142
# [25]	validation_0-mlogloss:0.96059
# [26]	validation_0-mlogloss:0.96225
# [27]	validation_0-mlogloss:0.95093
# [28]	validation_0-mlogloss:0.93742
# [29]	validation_0-mlogloss:0.94003
# [30]	validation_0-mlogloss:0.93354
# [31]	validation_0-mlogloss:0.92293
# [32]	validation_0-mlogloss:0.92459
# [33]	validation_0-mlogloss:0.92039
# [34]	validation_0-mlogloss:0.92640
# [35]	validation_0-mlogloss:0.91759
# [36]	validation_0-mlogloss:0.92216
# [37]	validation_0-mlogloss:0.91140
# [38]	validation_0-mlogloss:0.90603
# [39]	validation_0-mlogloss:0.90395
# [40]	validation_0-mlogloss:0.91012
# [41]	validation_0-mlogloss:0.90915
# [42]	validation_0-mlogloss:0.90539
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72        72
#            1       1.00      0.43      0.60         7
#            2       1.00      0.58      0.73        31
#            3       1.00      1.00      1.00         3
#            4       0.58      0.68      0.63        38
#            5       0.40      0.40      0.40         5
#            6       0.40      0.67      0.50         3
#            7       0.56      0.77      0.65        30
#            8       0.27      0.75      0.40         4
#
#     accuracy                           0.66       193
#    macro avg       0.67      0.66      0.63       193
# weighted avg       0.72      0.66      0.67       193
# <Axes: >

# %%
# X_train_with_predictions.shape

# %%
# X_train_with_predictions=df.drop(["label"],axis=1)
# y_train_with_predictions=df['label']
# X_test["previous_label"]=pred_xgb
# all_feature_smote_with_predictions, all_label_smote_with_predictions = sm.fit_resample(X_train_with_predictions,y_train_with_predictions)
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='aucs‌', random_state=10)
# xgbcl.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_xgb_with_predictions=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_xgb_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_xgb_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# rf_with_predictions=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf_with_predictions.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_rf_with_predictions=rf_with_predictions.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_rf_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_windowsize3_with_pre_feat/smote_xgb_model2.sav'
joblib.dump(xgbcl, filename)
# Out:
# ['./model_windowsize3_with_pre_feat/smote_xgb_model2.sav']

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
HGBC=HistGradientBoostingClassifier(random_state=10,class_weight='balanced')
# HGBC.fit(X_train,y_train)
try:
    filename = './model_windowsize3_with_pre_feat/smote_HGBC_model2.sav'
    HGBC=joblib.load(filename)
    pred=HGBC.predict(X_test)
except:
    HGBC.fit(all_feature_smote, all_label_smote )
    pred=HGBC.predict(X_test)


print(metrics.classification_report(pred,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.69      0.74        71
#          1.0       1.00      0.75      0.86         4
#          2.0       1.00      0.58      0.73        31
#          3.0       0.33      1.00      0.50         1
#          4.0       0.62      0.64      0.63        44
#          5.0       0.20      0.50      0.29         2
#          6.0       0.40      0.67      0.50         3
#          7.0       0.63      0.81      0.71        32
#          8.0       0.27      0.60      0.37         5
#
#     accuracy                           0.68       193
#    macro avg       0.58      0.69      0.59       193
# weighted avg       0.74      0.68      0.69       193
# <Axes: >

# %%
filename = './model_windowsize3_with_pre_feat/smote_HGBC_model2.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_windowsize3_with_pre_feat/smote_HGBC_model2.sav']

# %%
# def predict0_4(df):
# #     print(df['label_pred'])
# #     print(df['label_pred'] in [1,2,3,5,6,7,8])
#     if df['previous_label'] in [1,2,3,5,6,7,8]:
#         return df['previous_label']
#     else:
# #         print(np.array(df.drop(["label","previous_label",'label_pred'])))
# # xgb_class0_4
#         return xgbcl.predict(np.array(df.drop(["label",'previous_label'
#                                     ])).reshape(1,-1)).view().item()

# %%
# from sklearn.ensemble import AdaBoostClassifier
# test['previous_label']=pred_xgb
# # test['previous_label']=list(pred_xgb).insert(0,0)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label",'previous_label'],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4=np.array(X_train_class0_4)
# y_train_class0_4=np.array(y_train_class0_4)
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# xgb_class0_4=RandomForestClassifier(random_state=10,n_estimators=30,criterion='gini')#XGBClassifier( eval_metric='logloss', random_state=10)
# try:
#     print('sm')
# #     xgb_class0_4.fit(X_train_class0_4sm, y_train_class0_4sm)
# except:
#     print('no sm')
# #     xgb_class0_4.fit(X_train_class0_4, y_train_class0_4)
# test['label_pred']=test.apply(lambda x:predict0_4(x),axis=1)

# # test_class0_4=test[(test['label_pred'].isin([0,4]))&(test['label'].isin([0,4]))]
# # X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# # y_test_class0_4=test_class0_4.label
# # # X_test_class0_4=np.array(X_test_class0_4)
# # # y_test_class0_4=np.array(y_test_class0_4)

# # pred_class0_4=xgb_class0_4.predict(X_test_class0_4)
# print(metrics.classification_report(test['label'],test['label_pred']))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(test['label'],test['label_pred'], normalize='true')
# sns.heatmap(conf,annot=True)

# %%
test['label1']=pred
# turn2
test['previous_label']=test['label1']
test['second_turn']=test['previous_label'].diff()
test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
turn=list(test['second_turn'])
turn_2=[]

if (test['label'][0].item()>0): 
    count=2
else: 
    count=1
for i in range(len(turn)):

    if turn[i]<-3:
        count-=1
    if count<=0:
        turn_2.append(1) 
    else:
        turn_2.append(0) 
test['turn']=turn
test['second_turn']=turn_2
            
print(list(test['label'])[0])
def fturn_test():
    if list(test['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0
after0=fturn_test()
sturn=True
after1=[]
after4=[]
for i in range(len(test['label'])):

    if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
        after0-=1
    if (list(test['second_turn'])[i]>0) and sturn==True:
        after0=fturn_test()
        sturn=False
    if after0<=0:
#         print(after0)
        after1.append(1) 
    else:
        after1.append(0) 
after0=fturn_test()
sturn=True
for i in range(len(test['label'])):
    if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
        after0-=1
    if (list(test['second_turn'])[i]>0) and sturn==True:
        after0=fturn_test()
        sturn=False
    if after0<=0:
#         print(after0)
        after4.append(1) 
    else:
        after4.append(0) 


test['after1']=after1
test['after4']=after4
test=test.drop(['second_turn','turn'],axis=1)
# Out:
# 8

# %%
X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test_a=test['label']

X=df.drop(["label","previous_label"],axis=1)
y=df['label']
X_train_a=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train_a=y

all_feature_smote_a, all_label_smote_a = sm.fit_resample(X_train_a,y_train_a)

# %%
try:
    filename = './model_windowsize3_with_pre_feat/smote_HGBC_model_after.sav'
    HGBC=joblib.load(filename)
    pred_a=HGBC.predict(X_test_a)
except:
    print('learning')
    HGBC=HistGradientBoostingClassifier(random_state=10,class_weight='balanced')
    HGBC.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=HGBC.predict(X_test_a)


print(metrics.classification_report(pred_a,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_a,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# learning
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.81      0.59        36
#          1.0       0.33      1.00      0.50         1
#          2.0       0.56      1.00      0.71        10
#          3.0       0.33      1.00      0.50         1
#          4.0       0.91      0.61      0.73        67
#          5.0       0.40      0.25      0.31         8
#          6.0       0.40      0.67      0.50         3
#          7.0       0.95      0.62      0.75        63
#          8.0       0.27      0.75      0.40         4
#
#     accuracy                           0.66       193
#    macro avg       0.51      0.74      0.56       193
# weighted avg       0.77      0.66      0.68       193
# <Axes: >

# %%
# XGB=RandomForestClassifier(random_state=10)
# XGB.fit(all_feature_smote_a, all_label_smote_a)

# pred_b=XGB.predict(X_test_a)

# print(metrics.classification_report(pred_b,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_b,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_windowsize3_with_pre_feat/smote_HGBC_model_after.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_windowsize3_with_pre_feat/smote_HGBC_model_after.sav']

# %%
# import six
# import sys
# sys.modules['sklearn.externals.six'] = six
# from seqlearn.perceptron import StructuredPerceptron

try:
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model_after.sav'
    xgbafter=joblib.load(filename)
    pred_a=xgbafter.predict(X_test_a)
except:
    print('learning')
    xgbafter=XGBClassifier( eval_metric='mlogloss', random_state=10)
    xgbafter.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=xgbafter.predict(X_test_a)
    
print(metrics.classification_report(pred_a,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_a,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# learning
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 8
#       7 filename = './model_windowsize3_with_pre_feat/smote_xgb_model_after.sav'
# ----> 8 xgbafter=joblib.load(filename)
#       9 pred_a=xgbafter.predict(X_test_a)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#
# FileNotFoundError: [Errno 2] No such file or directory: './model_windowsize3_with_pre_feat/smote_xgb_model_after.sav'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 13
#      11     print('learning')
#      12     xgbafter=XGBClassifier( eval_metric='mlogloss', random_state=10)
# ---> 13     xgbafter.fit(all_feature_smote_a, all_label_smote_a )
#      14     pred_a=xgbafter.predict(X_test_a)
#      16 print(metrics.classification_report(pred_a,y_test))
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1490, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1462 (
#    1463     model,
#    1464     metric,
#    (...)
#    1469     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1470 )
#    1471 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1472     missing=self.missing,
#    1473     X=X,
#    (...)
#    1487     feature_types=self.feature_types,
#    1488 )
# -> 1490 self._Booster = train(
#    1491     params,
#    1492     train_dmatrix,
#    1493     self.get_num_boosting_rounds(),
#    1494     evals=evals,
#    1495     early_stopping_rounds=early_stopping_rounds,
#    1496     evals_result=evals_result,
#    1497     obj=obj,
#    1498     custom_metric=metric,
#    1499     verbose_eval=verbose,
#    1500     xgb_model=model,
#    1501     callbacks=callbacks,
#    1502 )
#    1504 if not callable(self.objective):
#    1505     self.objective = params["objective"]
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
filename = './model_windowsize3_with_pre_feat/smote_xgb_model_after.sav'
joblib.dump(xgbafter, filename)

# %%
# from sklearn.ensemble import GradientBoostingClassifier
# # import six
# # import sys
# # sys.modules['sklearn.externals.six'] = six
# # from seqlearn.perceptron import StructuredPerceptron

# try:
#     filename = './model_windowsize3_with_pre_feat/smote_ada_model_after.sav'
#     ada=joblib.load(filename)
#     pred_a=ada.predict(X_test_a)
# except:
    
#     print('learning')
#     ada=GradientBoostingClassifier(n_estimators=200,max_features=9)
#     ada.fit(all_feature_smote_a, all_label_smote_a )
#     pred_a=ada.predict(X_test_a)    
# print(metrics.classification_report(y_test,pred_a))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(y_test,pred_a, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model_windowsize3_with_pre_feat/smote_ada_model_after.sav'
# joblib.dump(ada, filename)

# %%
# from sklearn.model_selection import GridSearchCV
# filename = './model_windowsize3_with_pre_feat/smote_grid_model_after.sav'
# try:
#     clf=joblib.load(filename)
#     pred_a=clf.predict(X_test_a)  
# except:

#     parameters = {
#         "loss":[ 'log_loss'],
#         "learning_rate": [ 0.1, 0.5, 0.2,0.05,0.01],#0.01, 0.025, 0.05, 0.075,
# #         "min_samples_split": np.linspace(0.1, 0.5, 12),
# #         "min_samples_leaf": np.linspace(0.1, 0.5, 12),
#         "max_depth":[8,50],
#         "max_features":["log2","sqrt"],
#         "criterion": ["friedman_mse",  'squared_error']
# #         "subsample":[0.5, 0.618, 0.8, 0.85, 0.9, 0.95, 1.0],
# #         "n_estimators":[10]
#         }
#     clf = GridSearchCV(GradientBoostingClassifier(), parameters, cv=4, n_jobs=-1)
#     print('learning')
#     # ada=GradientBoostingClassifier(n_estimators=200,max_features=9)
#     clf.fit(all_feature_smote_a, all_label_smote_a )
#     pred_a=clf.predict(X_test_a)    
# print(metrics.classification_report(y_test,pred_a))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(y_test,pred_a, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model_windowsize3_with_pre_feat/smote_grid_model_after.sav'
# joblib.dump(ada, filename)

# %%
# from sklearn.ensemble import VotingClassifier,StackingClassifier,BaggingClassifier,RandomTreesEmbedding,ExtraTreesClassifier,RandomForestClassifier
# VC=VotingClassifier(estimators=[('HGBC',HGBC),
#                                  ('XGB',xgbafter),
#                                ('RTE',ExtraTreesClassifier()),
#                                ('RF',RandomForestClassifier()),
#                                ('BG',BaggingClassifier())],
#                     weights=[7,7,5,5,5],
#                     voting='soft'
#                    )
# filename = './model_windowsize3_with_pre_feat/smote_VC2_model_after.sav'
# try:
#     VC=joblib.load(filename)
#     pred_a=VC.predict(X_test_a)  
# except:

#     print('learning')
#     # ada=GradientBoostingClassifier(n_estimators=200,max_features=9)
#     VC.fit(all_feature_smote_a, all_label_smote_a )
#     pred_a=VC.predict(X_test_a)    
# print(metrics.classification_report(y_test,pred_a))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(y_test,pred_a, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model_windowsize3_with_pre_feat/smote_VC2_model_after.sav'
# joblib.dump(VC, filename)

# %%
# from sklearn.ensemble import VotingClassifier,StackingClassifier,RandomTreesEmbedding,ExtraTreesClassifier
# RTE=ExtraTreesClassifier()

# filename = './model_windowsize3_with_pre_feat/smote_RTE_model_after.sav'
# try:
#     RTE=joblib.load(filename)
#     pred_a=RTE.predict(X_test_a)  
# except:

#     print('learning')
#     # ada=GradientBoostingClassifier(n_estimators=200,max_features=9)
#     RTE.fit(all_feature_smote_a, all_label_smote_a )
#     pred_a=RTE.predict(X_test_a)    
# print(metrics.classification_report(y_test,pred_a))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(y_test,pred_a, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model_windowsize3_with_pre_feat/smote_RTE_model_after.sav'
# joblib.dump(RTE, filename)

# %%
# from sklearn.ensemble import AdaBoostClassifier
# ada=AdaBoostClassifier(random_state=10)
# ada.fit(X_train,y_train)
# pred=ada.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from catboost import CatBoostClassifier
# # catboost=CatBoostClassifier()
# # catboost.fit(X_train,y_train)
# filename = './catboost_model.sav'
# catboost=joblib.load(filename)
# pred=catboost.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './catboost_model.sav'
# joblib.dump(catboost, filename)

# %%
# from keras.layers import TimeDistributed
# # # trainX=np.array(X_train)
# # testX=np.array(X_test)
# # # trainY=np.array(y_train)
# # testY=np.array(y_test)
# # trainX=np.array(all_feature_smote)
# # trainY=np.array(all_label_smote)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label","previous_label"],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# trainX=np.array(X_train_class0_4sm)
# trainY=np.array(y_train_class0_4sm)

# test_class0_4=test[test['label'].isin([0,4])]
# X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# y_test_class0_4=test_class0_4.label
# testX=np.array(X_test_class0_4)
# testY=np.array(y_test_class0_4)

# # # testY = tf.keras.utils.to_categorical(testY)
# # # trainY = tf.keras.utils.to_categorical(trainY)
# # trainX = np.expand_dims(trainX, 2)
# # testX = np.expand_dims(testX, 2)

# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# from tensorflow.keras import models
# model = models.Sequential()
# model.add(layers.Input(shape=(len(trainX[1]), 1)))
# model.add(layers.Conv1D(64,64, activation='relu'))
# # model.add(LSTM(units=3, return_sequences=True))
# # model.add(LSTM(units=64, return_sequences=True))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Conv1D(32, 32, activation='relu'))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Conv1D(16, 16, activation='relu'))
# model.add(LSTM(units=64, return_sequences=True))
# # model.add(LSTM(units=32, return_sequences=True))
# model.add(LSTM(units=16, return_sequences=True))
# model.add(Dropout(0.5))

# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(32, activation='relu'))
# model.add(layers.Dense(9,activation='softmax'))
# mcp_save = ModelCheckpoint('DL_model.hdf5', save_best_only=True, monitor='val_loss', mode='min')
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# history = model.fit(trainX,trainY, epochs=100, 
#                     validation_data=(testX,testY), 
#                     callbacks=[early_stopping,mcp_save])

# %%
# plt.clf()
# plt.plot(history.history['loss'], label='loss')
# plt.plot(history.history['val_loss'], label = 'val_loss')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')

# plt.legend(loc='lower right')

# %%
# pred=model.predict(testX)
# pred=np.argmax(pred,axis=1)
# print(metrics.classification_report(pred,testY))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,testY, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# model_rnn = Sequential()
# model_rnn.add(LSTM(units=64, return_sequences=True, input_shape=(len(trainX[1]), 1)))
# model_rnn.add(Conv1D(128, 6))
# model_rnn.add(LSTM(units = 64, return_sequences = True))
# model_rnn.add(Dropout(0.2))
# model_rnn.add(Conv1D(128, 3))
# model_rnn.add(LSTM(units = 64, return_sequences = True))

# model_rnn.add(Dropout(0.2))
# model_rnn.add(LSTM(units = 64))

# model_rnn.add(Dense(units = 128))
# model_rnn.add(Dense(units = 64))

# model_rnn.add(Dense(units = 9, activation="softmax")) #4 as the output classes

# # Define the BRNN model with LSTM layers
# model_brnn = keras.Sequential([
#     layers.Bidirectional(layers.LSTM(64, activation='relu', return_sequences=True), 
#                          input_shape=(len(trainX[1]), 1)),
# #     layers.Bidirectional(layers.LSTM(64, activation='relu')),
# #     layers.Bidirectional(layers.LSTM(32, activation='relu')),
#     layers.Bidirectional(layers.LSTM(16, activation='relu')),
    
#     layers.Dense(9, activation='softmax')
# ])

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# # Compile the RNN model
# model_rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Compile the BRNN model
# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Define early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Train the RNN model with early stopping

# ## model_rnn.fit(all_feature, all_label, epochs=100, batch_size=500, validation_data=(X_vad, y_vad), callbacks=[early_stopping])

# # Train the BRNN model with early stopping

# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# # history_brnn=model_brnn.fit(trainX,trainY, epochs=10, batch_size=500,
# #                             validation_data=(testX,testY), callbacks=[early_stopping])
# # , callbacks=[early_stopping]

# %%
# history_rnn=model_rnn.fit(trainX,trainY, epochs=20,
#                             validation_data=(testX,testY), callbacks=[early_stopping])

# %%
len(all_label_smote)

# %%
# import scipy
# pred_aa=pd.Series(pred_a)
# pred_aa=pred_aa.rolling(3, min_periods=1).apply(scipy.stats.mode)
# pred_aa=pred_aa.apply(np.ceil)
# pred_aa=np.array(pred_aa)
# print(metrics.classification_report(pred_aa,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_aa,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
def output_xgb(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_windowsize3_with_pre_feat/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn_test():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn_test()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn_test()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_windowsize3_with_pre_feat')
out_xgb=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_xgb(ID,out_xgb)
out_df_xgb=pd.DataFrame(out_xgb,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])

out_df_xgb
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#        ID  accuracy  weighted avg F1-score  F1_score class 0  \
# 0   S08T1  0.693548               0.686820          0.686869
# 1   S08T2  0.663212               0.646041          0.591837
# 2   N11T1  0.800000               0.794056          0.690909
# 3   N11T2  0.796460               0.792147          0.653061
# 4   N06T1  0.616279               0.621479          0.622951
# 5   S02T2  0.694268               0.684205          0.683544
# 6   N06T2  0.898305               0.885537          1.000000
# 7   S02T1  0.854839               0.831636          0.925620
# 8   N02T2  0.763158               0.735947          0.646154
# 9   N02T1  0.765823               0.756673          0.638889
# 10  S03T1  0.752475               0.744867          0.736196
# 11  S03T2  0.776224               0.762585          0.728682
#
#     F1_score class 1  F1_score class 2  F1_score class 3  F1_score class 4  \
# 0           1.000000          0.600000          0.500000          0.740741
# 1           0.500000          0.714286          0.500000          0.732143
# 2           0.666667          0.857143               NaN          0.615385
# 3           0.666667          1.000000               NaN          0.636364
# 4                NaN          0.454545               NaN          0.536082
# 5                NaN          0.625000          0.571429          0.657534
# 6           0.666667          0.774194          0.333333          0.937500
# 7           1.000000          0.864865          0.454545          0.956522
# 8                NaN          0.631579               NaN          0.716049
# 9                NaN          0.625000               NaN          0.674157
# 10          0.500000          0.666667          0.500000          0.692810
# 11          0.400000          0.666667          0.666667          0.756757
#
#     F1_score class 5  F1_score class 6  F1_score class 7  F1_score class 8
# 0           0.461538          0.500000          0.719101          0.909091
# 1           0.307692          0.500000          0.750000          0.400000
# 2                NaN          1.000000          0.987952          1.000000
# 3                NaN          1.000000          0.967033          0.933333
# 4           0.500000          0.615385          0.640000          0.883721
# 5           0.714286          0.285714          0.786517          0.714286
# 6                NaN          0.800000          0.909091          0.875000
# 7           0.666667          0.800000          0.876404          0.421053
# 8           0.750000          1.000000          0.914894          0.956522
# 9           0.800000          1.000000          0.905263          0.965517
# 10          0.428571          0.400000          0.857143          0.916667
# 11          0.333333          0.500000          0.883978          0.904762

# %%
test_set=os.listdir('./test_set_df')
test_set
# Out:
# ['.DS_Store',
#  'S08T1.csv',
#  'S08T2.csv',
#  'N11T1.csv',
#  'N11T2.csv',
#  'N06T1.csv',
#  'S02T2.csv',
#  'N06T2.csv',
#  'S02T1.csv',
#  'N02T2.csv',
#  'N02T1.csv',
#  'S03T1.csv',
#  'S03T2.csv']

# %%
def output_rf(ID,out):
    test=pd.read_csv(f'./test_set_df_acc_windowsize3_with_pre_feat/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_HGBC_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn_test():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn_test()
    sturn=True
    after1=[]
    after4=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after0=fturn_test()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     plt.savefig(f"./image/rf_gan_window3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_windowsize3_with_pre_feat')
out_rf=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_rf)
out_df=pd.DataFrame(out_rf,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])

out_df.describe()
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          8.000000
# mean    0.801584               0.790206          0.800171          0.654167
# std     0.088141               0.089470          0.161886          0.231584
# min     0.663212               0.646041          0.591837          0.400000
# 25%     0.760487               0.742637          0.674197          0.500000
# 50%     0.777647               0.773222          0.732439          0.583333
# 75%     0.865705               0.845112          0.977861          0.750000
# max     0.946903               0.931491          1.000000          1.000000
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          7.000000         12.000000          9.000000
# mean           0.762373          0.562152          0.767921          0.613818
# std            0.127499          0.183956          0.123361          0.204572
# min            0.625000          0.333333          0.615385          0.307692
# 25%            0.657895          0.477273          0.675033          0.428571
# 50%            0.744240          0.500000          0.724096          0.666667
# 75%            0.859073          0.619048          0.870739          0.750000
# max            1.000000          0.909091          0.956522          0.857143
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         12.000000         12.000000         12.000000
# mean           0.700092          0.869665          0.823329
# std            0.264368          0.085198          0.205207
# min            0.285714          0.711111          0.400000
# 25%            0.500000          0.839486          0.834821
# 50%            0.707692          0.880191          0.906926
# 75%            1.000000          0.910542          0.939130
# max            1.000000          0.988764          1.000000

# %%
def output_xgb_2(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_windowsize3_with_pre_feat/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn_test():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn_test()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn_test()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_windowsize3_with_pre_feat')
out_xgb2=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_xgb2)
out_df2=pd.DataFrame(out_xgb2,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])

# %%
def output_ada(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_windowsize3_with_pre_feat/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn_test():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn_test()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn_test()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn_test()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_windowsize3_with_pre_feat/smote_VC2_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
# test_set=os.listdir('./test_set_df_acc_windowsize3_with_pre_feat')
# out_ada=[]
# for ID in test_set:
#     if ID.endswith(".csv"):
#         output_ada(ID,out_ada)
# out_ada=pd.DataFrame(out_ada,columns=['ID','accuracy','weighted avg F1-score',
#                                        'F1_score class 0',
#                                       'F1_score class 1',
#                                       'F1_score class 2',
#                                       'F1_score class 3',
#                                       'F1_score class 4',
#                                       'F1_score class 5',
#                                       'F1_score class 6',
#                                       'F1_score class 7',
#                                       'F1_score class 8'])

# %%
out_df.describe()#HGBC not rf model :(  HGBC HGBC
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          8.000000
# mean    0.801584               0.790206          0.800171          0.654167
# std     0.088141               0.089470          0.161886          0.231584
# min     0.663212               0.646041          0.591837          0.400000
# 25%     0.760487               0.742637          0.674197          0.500000
# 50%     0.777647               0.773222          0.732439          0.583333
# 75%     0.865705               0.845112          0.977861          0.750000
# max     0.946903               0.931491          1.000000          1.000000
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          7.000000         12.000000          9.000000
# mean           0.762373          0.562152          0.767921          0.613818
# std            0.127499          0.183956          0.123361          0.204572
# min            0.625000          0.333333          0.615385          0.307692
# 25%            0.657895          0.477273          0.675033          0.428571
# 50%            0.744240          0.500000          0.724096          0.666667
# 75%            0.859073          0.619048          0.870739          0.750000
# max            1.000000          0.909091          0.956522          0.857143
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         12.000000         12.000000         12.000000
# mean           0.700092          0.869665          0.823329
# std            0.264368          0.085198          0.205207
# min            0.285714          0.711111          0.400000
# 25%            0.500000          0.839486          0.834821
# 50%            0.707692          0.880191          0.906926
# 75%            1.000000          0.910542          0.939130
# max            1.000000          0.988764          1.000000

# %%
out_df_xgb.describe()#XGB HGBC
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          8.000000
# mean    0.756216               0.745166          0.717059          0.675000
# std     0.079775               0.076601          0.123046          0.223074
# min     0.616279               0.621479          0.591837          0.400000
# 25%     0.694088               0.686166          0.644338          0.500000
# 50%     0.764490               0.750770          0.685206          0.666667
# 75%     0.797345               0.792624          0.730561          0.750000
# max     0.898305               0.885537          1.000000          1.000000
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          7.000000         12.000000          9.000000
# mean           0.706662          0.503711          0.721004          0.551343
# std            0.146304          0.102166          0.121987          0.185004
# min            0.454545          0.333333          0.536082          0.307692
# 25%            0.625000          0.477273          0.652242          0.428571
# 50%            0.666667          0.500000          0.704430          0.500000
# 75%            0.794931          0.535714          0.744745          0.714286
# max            1.000000          0.666667          0.956522          0.800000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         12.000000         12.000000         12.000000
# mean           0.700092          0.849781          0.823329
# std            0.264368          0.104730          0.205207
# min            0.285714          0.640000          0.400000
# 25%            0.500000          0.777388          0.834821
# 50%            0.707692          0.880191          0.906926
# 75%            1.000000          0.910542          0.939130
# max            1.000000          0.987952          1.000000

# %%
out_df2.describe()#XGB XGB

# %%
# out_ada.describe()

# %%
all_feature_smote_a.iloc[50,:]
# Out:
# left_elbow_shoulder_hip mean_ft            710.611015
# left_elbow_shoulder_hip std_ft              18.288626
# left_elbow_shoulder_hip max_ft             739.000000
# left_elbow_shoulder_hip min_ft             676.659483
# left_elbow_shoulder_hip var_ft             334.473849
#                                               ...
# movingcenter_y stderror previous 3 s         0.454744
# movingcenter_y quantile25e previous 3 s     -0.707865
# movingcenter_y quantile75e previous 3 s      0.292135
# after1                                       1.000000
# after4                                       1.000000
# Name: 50, Length: 8682, dtype: float64
