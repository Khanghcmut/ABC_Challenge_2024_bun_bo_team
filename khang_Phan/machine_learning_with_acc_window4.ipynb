# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd # data processing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D,Dropout,LSTM, Bidirectional
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.layers import BatchNormalization, Dropout
from keras.layers import Dense, Activation
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import torch
from torch.nn import Transformer
from sklearn.preprocessing import StandardScaler #good
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
from sklearn import metrics #accuracy measure
import joblib
import warnings

# %%
def second_turn(label,dif):
    if label>0:
        return 0
    if label==0:
        return dif

# %%
training_set=os.listdir("./training_set_df_acc_window4/")
df=None
for data in training_set:
    if data.endswith('.csv'):
        file=f"./training_set_df_acc_window4/{data}"
        if df is None:
            df=pd.read_csv(file)
            df=df.astype(float)
            print(df.shape)
            df['previous_label']=df['label']
            
            df['label']=df['label'].astype("category")
            df['previous_label']=df['label']
            df['previous_label']=df['previous_label'].astype(int)
            df['second_turn']=df['previous_label'].diff()
            df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
            turn=list(df['second_turn'])
            turn_2=[]
            
            if (df['label'][0].item()>0): 
                count=2
            else: 
                count=1
            for i in range(len(turn)):

                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            df['turn']=turn
            df['second_turn']=turn_2
            
        else:
            d=pd.read_csv(file)
            d['previous_label']=d['label']
            d['previous_label']=d['previous_label'].astype(int)
            d['label']=d['label'].astype("category")
            d['second_turn']=d['previous_label'].diff()
            d['second_turn']=d.apply(lambda d:second_turn(d['label'],d['second_turn']),axis=1)
            turn=list(d['second_turn'])
            turn_2=[]
            if (d['label'][0].item()>0): 
                count=2
            else: count=1
            for i in range(len(turn)):
                if turn[i]<-3:
                    count-=1
                if count<=0:
                    turn_2.append(1) 
                else:
                    turn_2.append(0) 
            d['second_turn']=turn_2
            d['turn']=turn
            df=pd.concat([df,d])
# # turn2
# df['previous_label']=df['label']
# df['second_turn']=df['previous_label'].diff()
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['second_turn']),axis=1)
# turn=list(df['second_turn'])
# turn_2=[]

# if (df['label'][0].item()>0): 
#     count=2
# else: 
#     count=1
# for i in range(len(turn)):

#     if turn[i]<-3:
#         count-=1
#     if count<=0:
#         turn_2.append(1) 
#     else:
#         turn_2.append(0) 
# df['turn']=turn
# df['second_turn']=turn_2

after1=[]
            
# print(list(df['label'])[0])
def fturn():
    if list((df['label'])[0]>0): 
        after0=1
    else: after0=1
    return after0
after0=fturn()
sturn=True
for i in range(len(df.label)):

    if (list(df['label'])[i]==1)|(list(df['label'])[i]==2)|(list(df['label'])[i]==3):
        after0-=1
    if (list(df['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after1.append(1) 
    else:
        after1.append(0) 
df['after1']=after1
after4=[]
after0=fturn()
sturn=True
for i in range(len(df['label'])):
    if (list(df['label'])[i]==4)|(list(df['label'])[i]==5)|(list(df['label'])[i]==6):
        after0-=1
    if (list(df['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after4.append(1) 
    else:
        after4.append(0) 

df['after4']=after4
# Out:
# (154, 4496)

# %%
df[['label','second_turn','turn','after1']].to_csv('./check/check.csv')

# %%
df=df.drop(['second_turn','turn'],axis=1)

# %%
# df=df.astype(float)
# df['previous_label']=df['label']
# df['label']=df['label'].astype(int)
# df['label']=df['label'].astype("category")
# df['second_turn']=df['previous_label'].diff
# df['second_turn']=df.apply(lambda df:second_turn(df['label'],df['dif']))
# turn=list(df['second_turn'])

# %%
# is_2=False
# turn_2=[]
# for i in len(turn):
#     if turn[i]>2:
#         is_2=True
#     if !is_2:
#         return 0
#     return 1
# df['second_turn']=turn_2

# %%
test=pd.read_csv('./test_set_df_acc_window4/S08T1.csv')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2817 entries, 0 to 124
# Data columns (total 4498 columns):
#  #     Column                                             Dtype
# ---    ------                                             -----
#  0     left_elbow_shoulder_hip mean_ft                    float64
#  1     left_elbow_shoulder_hip std_ft                     float64
#  2     left_elbow_shoulder_hip max_ft                     float64
#  3     left_elbow_shoulder_hip min_ft                     float64
#  4     left_elbow_shoulder_hip var_ft                     float64
#  5     left_elbow_shoulder_hip med_ft                     float64
#  6     left_elbow_shoulder_hip sum_ft                     float64
#  7     left_elbow_shoulder_hip std                        float64
#  8     left_elbow_shoulder_hip kurtosis                   float64
#  9     left_elbow_shoulder_hip skew                       float64
#  10    left_elbow_shoulder_hip quantile 25                float64
#  11    left_elbow_shoulder_hip quantile 75                float64
#  12    left_elbow_shoulder_hip RMS                        float64
#  13    left_elbow_shoulder_hip MAV                        float64
#  14    left_elbow_shoulder_hip rmse                       float64
#  15    left_elbow_shoulder_hip mae                        float64
#  16    left_elbow_shoulder_hip maxerror                   float64
#  17    left_elbow_shoulder_hip minerror                   float64
#  18    left_elbow_shoulder_hip stderror                   float64
#  19    left_elbow_shoulder_hip quantile25e                float64
#  20    left_elbow_shoulder_hip quantile75e                float64
#  21    right_elbow_shoulder_hip mean_ft                   float64
#  22    right_elbow_shoulder_hip std_ft                    float64
#  23    right_elbow_shoulder_hip max_ft                    float64
#  24    right_elbow_shoulder_hip min_ft                    float64
#  25    right_elbow_shoulder_hip var_ft                    float64
#  26    right_elbow_shoulder_hip med_ft                    float64
#  27    right_elbow_shoulder_hip sum_ft                    float64
#  28    right_elbow_shoulder_hip std                       float64
#  29    right_elbow_shoulder_hip kurtosis                  float64
#  30    right_elbow_shoulder_hip skew                      float64
#  31    right_elbow_shoulder_hip quantile 25               float64
#  32    right_elbow_shoulder_hip quantile 75               float64
#  33    right_elbow_shoulder_hip RMS                       float64
#  34    right_elbow_shoulder_hip MAV                       float64
#  35    right_elbow_shoulder_hip rmse                      float64
#  36    right_elbow_shoulder_hip mae                       float64
#  37    right_elbow_shoulder_hip maxerror                  float64
#  38    right_elbow_shoulder_hip minerror                  float64
#  39    right_elbow_shoulder_hip stderror                  float64
#  40    right_elbow_shoulder_hip quantile25e               float64
#  41    right_elbow_shoulder_hip quantile75e               float64
#  42    left_wrist_elbow_shoulder mean_ft                  float64
#  43    left_wrist_elbow_shoulder std_ft                   float64
#  44    left_wrist_elbow_shoulder max_ft                   float64
#  45    left_wrist_elbow_shoulder min_ft                   float64
#  46    left_wrist_elbow_shoulder var_ft                   float64
#  47    left_wrist_elbow_shoulder med_ft                   float64
#  48    left_wrist_elbow_shoulder sum_ft                   float64
#  49    left_wrist_elbow_shoulder std                      float64
#  50    left_wrist_elbow_shoulder kurtosis                 float64
#  51    left_wrist_elbow_shoulder skew                     float64
#  52    left_wrist_elbow_shoulder quantile 25              float64
#  53    left_wrist_elbow_shoulder quantile 75              float64
#  54    left_wrist_elbow_shoulder RMS                      float64
#  55    left_wrist_elbow_shoulder MAV                      float64
#  56    left_wrist_elbow_shoulder rmse                     float64
#  57    left_wrist_elbow_shoulder mae                      float64
#  58    left_wrist_elbow_shoulder maxerror                 float64
#  59    left_wrist_elbow_shoulder minerror                 float64
#  60    left_wrist_elbow_shoulder stderror                 float64
#  61    left_wrist_elbow_shoulder quantile25e              float64
#  62    left_wrist_elbow_shoulder quantile75e              float64
#  63    right_wrist_elbow_shoulder mean_ft                 float64
#  64    right_wrist_elbow_shoulder std_ft                  float64
#  65    right_wrist_elbow_shoulder max_ft                  float64
#  66    right_wrist_elbow_shoulder min_ft                  float64
#  67    right_wrist_elbow_shoulder var_ft                  float64
#  68    right_wrist_elbow_shoulder med_ft                  float64
#  69    right_wrist_elbow_shoulder sum_ft                  float64
#  70    right_wrist_elbow_shoulder std                     float64
#  71    right_wrist_elbow_shoulder kurtosis                float64
#  72    right_wrist_elbow_shoulder skew                    float64
#  73    right_wrist_elbow_shoulder quantile 25             float64
#  74    right_wrist_elbow_shoulder quantile 75             float64
#  75    right_wrist_elbow_shoulder RMS                     float64
#  76    right_wrist_elbow_shoulder MAV                     float64
#  77    right_wrist_elbow_shoulder rmse                    float64
#  78    right_wrist_elbow_shoulder mae                     float64
#  79    right_wrist_elbow_shoulder maxerror                float64
#  80    right_wrist_elbow_shoulder minerror                float64
#  81    right_wrist_elbow_shoulder stderror                float64
#  82    right_wrist_elbow_shoulder quantile25e             float64
#  83    right_wrist_elbow_shoulder quantile75e             float64
#  84     right_elbow_shoulder mean_ft                      float64
#  85     right_elbow_shoulder std_ft                       float64
#  86     right_elbow_shoulder max_ft                       float64
#  87     right_elbow_shoulder min_ft                       float64
#  88     right_elbow_shoulder var_ft                       float64
#  89     right_elbow_shoulder med_ft                       float64
#  90     right_elbow_shoulder sum_ft                       float64
#  91     right_elbow_shoulder std                          float64
#  92     right_elbow_shoulder kurtosis                     float64
#  93     right_elbow_shoulder skew                         float64
#  94     right_elbow_shoulder quantile 25                  float64
#  95     right_elbow_shoulder quantile 75                  float64
#  96     right_elbow_shoulder RMS                          float64
#  97     right_elbow_shoulder MAV                          float64
#  98     right_elbow_shoulder rmse                         float64
#  99     right_elbow_shoulder mae                          float64
#  100    right_elbow_shoulder maxerror                     float64
#  101    right_elbow_shoulder minerror                     float64
#  102    right_elbow_shoulder stderror                     float64
#  103    right_elbow_shoulder quantile25e                  float64
#  104    right_elbow_shoulder quantile75e                  float64
#  105   left_elbow_shoulder mean_ft                        float64
#  106   left_elbow_shoulder std_ft                         float64
#  107   left_elbow_shoulder max_ft                         float64
#  108   left_elbow_shoulder min_ft                         float64
#  109   left_elbow_shoulder var_ft                         float64
#  110   left_elbow_shoulder med_ft                         float64
#  111   left_elbow_shoulder sum_ft                         float64
#  112   left_elbow_shoulder std                            float64
#  113   left_elbow_shoulder kurtosis                       float64
#  114   left_elbow_shoulder skew                           float64
#  115   left_elbow_shoulder quantile 25                    float64
#  116   left_elbow_shoulder quantile 75                    float64
#  117   left_elbow_shoulder RMS                            float64
#  118   left_elbow_shoulder MAV                            float64
#  119   left_elbow_shoulder rmse                           float64
#  120   left_elbow_shoulder mae                            float64
#  121   left_elbow_shoulder maxerror                       float64
#  122   left_elbow_shoulder minerror                       float64
#  123   left_elbow_shoulder stderror                       float64
#  124   left_elbow_shoulder quantile25e                    float64
#  125   left_elbow_shoulder quantile75e                    float64
#  126   nose_x mean_ft                                     float64
#  127   nose_x std_ft                                      float64
#  128   nose_x max_ft                                      float64
#  129   nose_x min_ft                                      float64
#  130   nose_x var_ft                                      float64
#  131   nose_x med_ft                                      float64
#  132   nose_x sum_ft                                      float64
#  133   nose_x std                                         float64
#  134   nose_x kurtosis                                    float64
#  135   nose_x skew                                        float64
#  136   nose_x quantile 25                                 float64
#  137   nose_x quantile 75                                 float64
#  138   nose_x RMS                                         float64
#  139   nose_x MAV                                         float64
#  140   nose_x rmse                                        float64
#  141   nose_x mae                                         float64
#  142   nose_x maxerror                                    float64
#  143   nose_x minerror                                    float64
#  144   nose_x stderror                                    float64
#  145   nose_x quantile25e                                 float64
#  146   nose_x quantile75e                                 float64
#  147   nose_y mean_ft                                     float64
#  148   nose_y std_ft                                      float64
#  149   nose_y max_ft                                      float64
#  150   nose_y min_ft                                      float64
#  151   nose_y var_ft                                      float64
#  152   nose_y med_ft                                      float64
#  153   nose_y sum_ft                                      float64
#  154   nose_y std                                         float64
#  155   nose_y kurtosis                                    float64
#  156   nose_y skew                                        float64
#  157   nose_y quantile 25                                 float64
#  158   nose_y quantile 75                                 float64
#  159   nose_y RMS                                         float64
#  160   nose_y MAV                                         float64
#  161   nose_y rmse                                        float64
#  162   nose_y mae                                         float64
#  163   nose_y maxerror                                    float64
#  164   nose_y minerror                                    float64
#  165   nose_y stderror                                    float64
#  166   nose_y quantile25e                                 float64
#  167   nose_y quantile75e                                 float64
#  168   left_eye_x mean_ft                                 float64
#  169   left_eye_x std_ft                                  float64
#  170   left_eye_x max_ft                                  float64
#  171   left_eye_x min_ft                                  float64
#  172   left_eye_x var_ft                                  float64
#  173   left_eye_x med_ft                                  float64
#  174   left_eye_x sum_ft                                  float64
#  175   left_eye_x std                                     float64
#  176   left_eye_x kurtosis                                float64
#  177   left_eye_x skew                                    float64
#  178   left_eye_x quantile 25                             float64
#  179   left_eye_x quantile 75                             float64
#  180   left_eye_x RMS                                     float64
#  181   left_eye_x MAV                                     float64
#  182   left_eye_x rmse                                    float64
#  183   left_eye_x mae                                     float64
#  184   left_eye_x maxerror                                float64
#  185   left_eye_x minerror                                float64
#  186   left_eye_x stderror                                float64
#  187   left_eye_x quantile25e                             float64
#  188   left_eye_x quantile75e                             float64
#  189   left_eye_y mean_ft                                 float64
#  190   left_eye_y std_ft                                  float64
#  191   left_eye_y max_ft                                  float64
#  192   left_eye_y min_ft                                  float64
#  193   left_eye_y var_ft                                  float64
#  194   left_eye_y med_ft                                  float64
#  195   left_eye_y sum_ft                                  float64
#  196   left_eye_y std                                     float64
#  197   left_eye_y kurtosis                                float64
#  198   left_eye_y skew                                    float64
#  199   left_eye_y quantile 25                             float64
#  200   left_eye_y quantile 75                             float64
#  201   left_eye_y RMS                                     float64
#  202   left_eye_y MAV                                     float64
#  203   left_eye_y rmse                                    float64
#  204   left_eye_y mae                                     float64
#  205   left_eye_y maxerror                                float64
#  206   left_eye_y minerror                                float64
#  207   left_eye_y stderror                                float64
#  208   left_eye_y quantile25e                             float64
#  209   left_eye_y quantile75e                             float64
#  210   right_eye_x mean_ft                                float64
#  211   right_eye_x std_ft                                 float64
#  212   right_eye_x max_ft                                 float64
#  213   right_eye_x min_ft                                 float64
#  214   right_eye_x var_ft                                 float64
#  215   right_eye_x med_ft                                 float64
#  216   right_eye_x sum_ft                                 float64
#  217   right_eye_x std                                    float64
#  218   right_eye_x kurtosis                               float64
#  219   right_eye_x skew                                   float64
#  220   right_eye_x quantile 25                            float64
#  221   right_eye_x quantile 75                            float64
#  222   right_eye_x RMS                                    float64
#  223   right_eye_x MAV                                    float64
#  224   right_eye_x rmse                                   float64
#  225   right_eye_x mae                                    float64
#  226   right_eye_x maxerror                               float64
#  227   right_eye_x minerror                               float64
#  228   right_eye_x stderror                               float64
#  229   right_eye_x quantile25e                            float64
#  230   right_eye_x quantile75e                            float64
#  231   right_eye_y mean_ft                                float64
#  232   right_eye_y std_ft                                 float64
#  233   right_eye_y max_ft                                 float64
#  234   right_eye_y min_ft                                 float64
#  235   right_eye_y var_ft                                 float64
#  236   right_eye_y med_ft                                 float64
#  237   right_eye_y sum_ft                                 float64
#  238   right_eye_y std                                    float64
#  239   right_eye_y kurtosis                               float64
#  240   right_eye_y skew                                   float64
#  241   right_eye_y quantile 25                            float64
#  242   right_eye_y quantile 75                            float64
#  243   right_eye_y RMS                                    float64
#  244   right_eye_y MAV                                    float64
#  245   right_eye_y rmse                                   float64
#  246   right_eye_y mae                                    float64
#  247   right_eye_y maxerror                               float64
#  248   right_eye_y minerror                               float64
#  249   right_eye_y stderror                               float64
#  250   right_eye_y quantile25e                            float64
#  251   right_eye_y quantile75e                            float64
#  252   left_ear_x mean_ft                                 float64
#  253   left_ear_x std_ft                                  float64
#  254   left_ear_x max_ft                                  float64
#  255   left_ear_x min_ft                                  float64
#  256   left_ear_x var_ft                                  float64
#  257   left_ear_x med_ft                                  float64
#  258   left_ear_x sum_ft                                  float64
#  259   left_ear_x std                                     float64
#  260   left_ear_x kurtosis                                float64
#  261   left_ear_x skew                                    float64
#  262   left_ear_x quantile 25                             float64
#  263   left_ear_x quantile 75                             float64
#  264   left_ear_x RMS                                     float64
#  265   left_ear_x MAV                                     float64
#  266   left_ear_x rmse                                    float64
#  267   left_ear_x mae                                     float64
#  268   left_ear_x maxerror                                float64
#  269   left_ear_x minerror                                float64
#  270   left_ear_x stderror                                float64
#  271   left_ear_x quantile25e                             float64
#  272   left_ear_x quantile75e                             float64
#  273   left_ear_y mean_ft                                 float64
#  274   left_ear_y std_ft                                  float64
#  275   left_ear_y max_ft                                  float64
#  276   left_ear_y min_ft                                  float64
#  277   left_ear_y var_ft                                  float64
#  278   left_ear_y med_ft                                  float64
#  279   left_ear_y sum_ft                                  float64
#  280   left_ear_y std                                     float64
#  281   left_ear_y kurtosis                                float64
#  282   left_ear_y skew                                    float64
#  283   left_ear_y quantile 25                             float64
#  284   left_ear_y quantile 75                             float64
#  285   left_ear_y RMS                                     float64
#  286   left_ear_y MAV                                     float64
#  287   left_ear_y rmse                                    float64
#  288   left_ear_y mae                                     float64
#  289   left_ear_y maxerror                                float64
#  290   left_ear_y minerror                                float64
#  291   left_ear_y stderror                                float64
#  292   left_ear_y quantile25e                             float64
#  293   left_ear_y quantile75e                             float64
#  294   right_ear_x mean_ft                                float64
#  295   right_ear_x std_ft                                 float64
#  296   right_ear_x max_ft                                 float64
#  297   right_ear_x min_ft                                 float64
#  298   right_ear_x var_ft                                 float64
#  299   right_ear_x med_ft                                 float64
#  300   right_ear_x sum_ft                                 float64
#  301   right_ear_x std                                    float64
#  302   right_ear_x kurtosis                               float64
#  303   right_ear_x skew                                   float64
#  304   right_ear_x quantile 25                            float64
#  305   right_ear_x quantile 75                            float64
#  306   right_ear_x RMS                                    float64
#  307   right_ear_x MAV                                    float64
#  308   right_ear_x rmse                                   float64
#  309   right_ear_x mae                                    float64
#  310   right_ear_x maxerror                               float64
#  311   right_ear_x minerror                               float64
#  312   right_ear_x stderror                               float64
#  313   right_ear_x quantile25e                            float64
#  314   right_ear_x quantile75e                            float64
#  315   right_ear_y mean_ft                                float64
#  316   right_ear_y std_ft                                 float64
#  317   right_ear_y max_ft                                 float64
#  318   right_ear_y min_ft                                 float64
#  319   right_ear_y var_ft                                 float64
#  320   right_ear_y med_ft                                 float64
#  321   right_ear_y sum_ft                                 float64
#  322   right_ear_y std                                    float64
#  323   right_ear_y kurtosis                               float64
#  324   right_ear_y skew                                   float64
#  325   right_ear_y quantile 25                            float64
#  326   right_ear_y quantile 75                            float64
#  327   right_ear_y RMS                                    float64
#  328   right_ear_y MAV                                    float64
#  329   right_ear_y rmse                                   float64
#  330   right_ear_y mae                                    float64
#  331   right_ear_y maxerror                               float64
#  332   right_ear_y minerror                               float64
#  333   right_ear_y stderror                               float64
#  334   right_ear_y quantile25e                            float64
#  335   right_ear_y quantile75e                            float64
#  336   left_shoulder_x mean_ft                            float64
#  337   left_shoulder_x std_ft                             float64
#  338   left_shoulder_x max_ft                             float64
#  339   left_shoulder_x min_ft                             float64
#  340   left_shoulder_x var_ft                             float64
#  341   left_shoulder_x med_ft                             float64
#  342   left_shoulder_x sum_ft                             float64
#  343   left_shoulder_x std                                float64
#  344   left_shoulder_x kurtosis                           float64
#  345   left_shoulder_x skew                               float64
#  346   left_shoulder_x quantile 25                        float64
#  347   left_shoulder_x quantile 75                        float64
#  348   left_shoulder_x RMS                                float64
#  349   left_shoulder_x MAV                                float64
#  350   left_shoulder_x rmse                               float64
#  351   left_shoulder_x mae                                float64
#  352   left_shoulder_x maxerror                           float64
#  353   left_shoulder_x minerror                           float64
#  354   left_shoulder_x stderror                           float64
#  355   left_shoulder_x quantile25e                        float64
#  356   left_shoulder_x quantile75e                        float64
#  357   left_shoulder_y mean_ft                            float64
#  358   left_shoulder_y std_ft                             float64
#  359   left_shoulder_y max_ft                             float64
#  360   left_shoulder_y min_ft                             float64
#  361   left_shoulder_y var_ft                             float64
#  362   left_shoulder_y med_ft                             float64
#  363   left_shoulder_y sum_ft                             float64
#  364   left_shoulder_y std                                float64
#  365   left_shoulder_y kurtosis                           float64
#  366   left_shoulder_y skew                               float64
#  367   left_shoulder_y quantile 25                        float64
#  368   left_shoulder_y quantile 75                        float64
#  369   left_shoulder_y RMS                                float64
#  370   left_shoulder_y MAV                                float64
#  371   left_shoulder_y rmse                               float64
#  372   left_shoulder_y mae                                float64
#  373   left_shoulder_y maxerror                           float64
#  374   left_shoulder_y minerror                           float64
#  375   left_shoulder_y stderror                           float64
#  376   left_shoulder_y quantile25e                        float64
#  377   left_shoulder_y quantile75e                        float64
#  378   right_shoulder_x mean_ft                           float64
#  379   right_shoulder_x std_ft                            float64
#  380   right_shoulder_x max_ft                            float64
#  381   right_shoulder_x min_ft                            float64
#  382   right_shoulder_x var_ft                            float64
#  383   right_shoulder_x med_ft                            float64
#  384   right_shoulder_x sum_ft                            float64
#  385   right_shoulder_x std                               float64
#  386   right_shoulder_x kurtosis                          float64
#  387   right_shoulder_x skew                              float64
#  388   right_shoulder_x quantile 25                       float64
#  389   right_shoulder_x quantile 75                       float64
#  390   right_shoulder_x RMS                               float64
#  391   right_shoulder_x MAV                               float64
#  392   right_shoulder_x rmse                              float64
#  393   right_shoulder_x mae                               float64
#  394   right_shoulder_x maxerror                          float64
#  395   right_shoulder_x minerror                          float64
#  396   right_shoulder_x stderror                          float64
#  397   right_shoulder_x quantile25e                       float64
#  398   right_shoulder_x quantile75e                       float64
#  399   right_shoulder_y mean_ft                           float64
#  400   right_shoulder_y std_ft                            float64
#  401   right_shoulder_y max_ft                            float64
#  402   right_shoulder_y min_ft                            float64
#  403   right_shoulder_y var_ft                            float64
#  404   right_shoulder_y med_ft                            float64
#  405   right_shoulder_y sum_ft                            float64
#  406   right_shoulder_y std                               float64
#  407   right_shoulder_y kurtosis                          float64
#  408   right_shoulder_y skew                              float64
#  409   right_shoulder_y quantile 25                       float64
#  410   right_shoulder_y quantile 75                       float64
#  411   right_shoulder_y RMS                               float64
#  412   right_shoulder_y MAV                               float64
#  413   right_shoulder_y rmse                              float64
#  414   right_shoulder_y mae                               float64
#  415   right_shoulder_y maxerror                          float64
#  416   right_shoulder_y minerror                          float64
#  417   right_shoulder_y stderror                          float64
#  418   right_shoulder_y quantile25e                       float64
#  419   right_shoulder_y quantile75e                       float64
#  420   left_elbow_x mean_ft                               float64
#  421   left_elbow_x std_ft                                float64
#  422   left_elbow_x max_ft                                float64
#  423   left_elbow_x min_ft                                float64
#  424   left_elbow_x var_ft                                float64
#  425   left_elbow_x med_ft                                float64
#  426   left_elbow_x sum_ft                                float64
#  427   left_elbow_x std                                   float64
#  428   left_elbow_x kurtosis                              float64
#  429   left_elbow_x skew                                  float64
#  430   left_elbow_x quantile 25                           float64
#  431   left_elbow_x quantile 75                           float64
#  432   left_elbow_x RMS                                   float64
#  433   left_elbow_x MAV                                   float64
#  434   left_elbow_x rmse                                  float64
#  435   left_elbow_x mae                                   float64
#  436   left_elbow_x maxerror                              float64
#  437   left_elbow_x minerror                              float64
#  438   left_elbow_x stderror                              float64
#  439   left_elbow_x quantile25e                           float64
#  440   left_elbow_x quantile75e                           float64
#  441   left_elbow_y mean_ft                               float64
#  442   left_elbow_y std_ft                                float64
#  443   left_elbow_y max_ft                                float64
#  444   left_elbow_y min_ft                                float64
#  445   left_elbow_y var_ft                                float64
#  446   left_elbow_y med_ft                                float64
#  447   left_elbow_y sum_ft                                float64
#  448   left_elbow_y std                                   float64
#  449   left_elbow_y kurtosis                              float64
#  450   left_elbow_y skew                                  float64
#  451   left_elbow_y quantile 25                           float64
#  452   left_elbow_y quantile 75                           float64
#  453   left_elbow_y RMS                                   float64
#  454   left_elbow_y MAV                                   float64
#  455   left_elbow_y rmse                                  float64
#  456   left_elbow_y mae                                   float64
#  457   left_elbow_y maxerror                              float64
#  458   left_elbow_y minerror                              float64
#  459   left_elbow_y stderror                              float64
#  460   left_elbow_y quantile25e                           float64
#  461   left_elbow_y quantile75e                           float64
#  462   right_elbow_x mean_ft                              float64
#  463   right_elbow_x std_ft                               float64
#  464   right_elbow_x max_ft                               float64
#  465   right_elbow_x min_ft                               float64
#  466   right_elbow_x var_ft                               float64
#  467   right_elbow_x med_ft                               float64
#  468   right_elbow_x sum_ft                               float64
#  469   right_elbow_x std                                  float64
#  470   right_elbow_x kurtosis                             float64
#  471   right_elbow_x skew                                 float64
#  472   right_elbow_x quantile 25                          float64
#  473   right_elbow_x quantile 75                          float64
#  474   right_elbow_x RMS                                  float64
#  475   right_elbow_x MAV                                  float64
#  476   right_elbow_x rmse                                 float64
#  477   right_elbow_x mae                                  float64
#  478   right_elbow_x maxerror                             float64
#  479   right_elbow_x minerror                             float64
#  480   right_elbow_x stderror                             float64
#  481   right_elbow_x quantile25e                          float64
#  482   right_elbow_x quantile75e                          float64
#  483   right_elbow_y mean_ft                              float64
#  484   right_elbow_y std_ft                               float64
#  485   right_elbow_y max_ft                               float64
#  486   right_elbow_y min_ft                               float64
#  487   right_elbow_y var_ft                               float64
#  488   right_elbow_y med_ft                               float64
#  489   right_elbow_y sum_ft                               float64
#  490   right_elbow_y std                                  float64
#  491   right_elbow_y kurtosis                             float64
#  492   right_elbow_y skew                                 float64
#  493   right_elbow_y quantile 25                          float64
#  494   right_elbow_y quantile 75                          float64
#  495   right_elbow_y RMS                                  float64
#  496   right_elbow_y MAV                                  float64
#  497   right_elbow_y rmse                                 float64
#  498   right_elbow_y mae                                  float64
#  499   right_elbow_y maxerror                             float64
#  500   right_elbow_y minerror                             float64
#  501   right_elbow_y stderror                             float64
#  502   right_elbow_y quantile25e                          float64
#  503   right_elbow_y quantile75e                          float64
#  504   left_wrist_x mean_ft                               float64
#  505   left_wrist_x std_ft                                float64
#  506   left_wrist_x max_ft                                float64
#  507   left_wrist_x min_ft                                float64
#  508   left_wrist_x var_ft                                float64
#  509   left_wrist_x med_ft                                float64
#  510   left_wrist_x sum_ft                                float64
#  511   left_wrist_x std                                   float64
#  512   left_wrist_x kurtosis                              float64
#  513   left_wrist_x skew                                  float64
#  514   left_wrist_x quantile 25                           float64
#  515   left_wrist_x quantile 75                           float64
#  516   left_wrist_x RMS                                   float64
#  517   left_wrist_x MAV                                   float64
#  518   left_wrist_x rmse                                  float64
#  519   left_wrist_x mae                                   float64
#  520   left_wrist_x maxerror                              float64
#  521   left_wrist_x minerror                              float64
#  522   left_wrist_x stderror                              float64
#  523   left_wrist_x quantile25e                           float64
#  524   left_wrist_x quantile75e                           float64
#  525   left_wrist_y mean_ft                               float64
#  526   left_wrist_y std_ft                                float64
#  527   left_wrist_y max_ft                                float64
#  528   left_wrist_y min_ft                                float64
#  529   left_wrist_y var_ft                                float64
#  530   left_wrist_y med_ft                                float64
#  531   left_wrist_y sum_ft                                float64
#  532   left_wrist_y std                                   float64
#  533   left_wrist_y kurtosis                              float64
#  534   left_wrist_y skew                                  float64
#  535   left_wrist_y quantile 25                           float64
#  536   left_wrist_y quantile 75                           float64
#  537   left_wrist_y RMS                                   float64
#  538   left_wrist_y MAV                                   float64
#  539   left_wrist_y rmse                                  float64
#  540   left_wrist_y mae                                   float64
#  541   left_wrist_y maxerror                              float64
#  542   left_wrist_y minerror                              float64
#  543   left_wrist_y stderror                              float64
#  544   left_wrist_y quantile25e                           float64
#  545   left_wrist_y quantile75e                           float64
#  546   right_wrist_x mean_ft                              float64
#  547   right_wrist_x std_ft                               float64
#  548   right_wrist_x max_ft                               float64
#  549   right_wrist_x min_ft                               float64
#  550   right_wrist_x var_ft                               float64
#  551   right_wrist_x med_ft                               float64
#  552   right_wrist_x sum_ft                               float64
#  553   right_wrist_x std                                  float64
#  554   right_wrist_x kurtosis                             float64
#  555   right_wrist_x skew                                 float64
#  556   right_wrist_x quantile 25                          float64
#  557   right_wrist_x quantile 75                          float64
#  558   right_wrist_x RMS                                  float64
#  559   right_wrist_x MAV                                  float64
#  560   right_wrist_x rmse                                 float64
#  561   right_wrist_x mae                                  float64
#  562   right_wrist_x maxerror                             float64
#  563   right_wrist_x minerror                             float64
#  564   right_wrist_x stderror                             float64
#  565   right_wrist_x quantile25e                          float64
#  566   right_wrist_x quantile75e                          float64
#  567   right_wrist_y mean_ft                              float64
#  568   right_wrist_y std_ft                               float64
#  569   right_wrist_y max_ft                               float64
#  570   right_wrist_y min_ft                               float64
#  571   right_wrist_y var_ft                               float64
#  572   right_wrist_y med_ft                               float64
#  573   right_wrist_y sum_ft                               float64
#  574   right_wrist_y std                                  float64
#  575   right_wrist_y kurtosis                             float64
#  576   right_wrist_y skew                                 float64
#  577   right_wrist_y quantile 25                          float64
#  578   right_wrist_y quantile 75                          float64
#  579   right_wrist_y RMS                                  float64
#  580   right_wrist_y MAV                                  float64
#  581   right_wrist_y rmse                                 float64
#  582   right_wrist_y mae                                  float64
#  583   right_wrist_y maxerror                             float64
#  584   right_wrist_y minerror                             float64
#  585   right_wrist_y stderror                             float64
#  586   right_wrist_y quantile25e                          float64
#  587   right_wrist_y quantile75e                          float64
#  588   left_hip_x mean_ft                                 float64
#  589   left_hip_x std_ft                                  float64
#  590   left_hip_x max_ft                                  float64
#  591   left_hip_x min_ft                                  float64
#  592   left_hip_x var_ft                                  float64
#  593   left_hip_x med_ft                                  float64
#  594   left_hip_x sum_ft                                  float64
#  595   left_hip_x std                                     float64
#  596   left_hip_x kurtosis                                float64
#  597   left_hip_x skew                                    float64
#  598   left_hip_x quantile 25                             float64
#  599   left_hip_x quantile 75                             float64
#  600   left_hip_x RMS                                     float64
#  601   left_hip_x MAV                                     float64
#  602   left_hip_x rmse                                    float64
#  603   left_hip_x mae                                     float64
#  604   left_hip_x maxerror                                float64
#  605   left_hip_x minerror                                float64
#  606   left_hip_x stderror                                float64
#  607   left_hip_x quantile25e                             float64
#  608   left_hip_x quantile75e                             float64
#  609   left_hip_y mean_ft                                 float64
#  610   left_hip_y std_ft                                  float64
#  611   left_hip_y max_ft                                  float64
#  612   left_hip_y min_ft                                  float64
#  613   left_hip_y var_ft                                  float64
#  614   left_hip_y med_ft                                  float64
#  615   left_hip_y sum_ft                                  float64
#  616   left_hip_y std                                     float64
#  617   left_hip_y kurtosis                                float64
#  618   left_hip_y skew                                    float64
#  619   left_hip_y quantile 25                             float64
#  620   left_hip_y quantile 75                             float64
#  621   left_hip_y RMS                                     float64
#  622   left_hip_y MAV                                     float64
#  623   left_hip_y rmse                                    float64
#  624   left_hip_y mae                                     float64
#  625   left_hip_y maxerror                                float64
#  626   left_hip_y minerror                                float64
#  627   left_hip_y stderror                                float64
#  628   left_hip_y quantile25e                             float64
#  629   left_hip_y quantile75e                             float64
#  630   right_hip_x mean_ft                                float64
#  631   right_hip_x std_ft                                 float64
#  632   right_hip_x max_ft                                 float64
#  633   right_hip_x min_ft                                 float64
#  634   right_hip_x var_ft                                 float64
#  635   right_hip_x med_ft                                 float64
#  636   right_hip_x sum_ft                                 float64
#  637   right_hip_x std                                    float64
#  638   right_hip_x kurtosis                               float64
#  639   right_hip_x skew                                   float64
#  640   right_hip_x quantile 25                            float64
#  641   right_hip_x quantile 75                            float64
#  642   right_hip_x RMS                                    float64
#  643   right_hip_x MAV                                    float64
#  644   right_hip_x rmse                                   float64
#  645   right_hip_x mae                                    float64
#  646   right_hip_x maxerror                               float64
#  647   right_hip_x minerror                               float64
#  648   right_hip_x stderror                               float64
#  649   right_hip_x quantile25e                            float64
#  650   right_hip_x quantile75e                            float64
#  651   right_hip_y mean_ft                                float64
#  652   right_hip_y std_ft                                 float64
#  653   right_hip_y max_ft                                 float64
#  654   right_hip_y min_ft                                 float64
#  655   right_hip_y var_ft                                 float64
#  656   right_hip_y med_ft                                 float64
#  657   right_hip_y sum_ft                                 float64
#  658   right_hip_y std                                    float64
#  659   right_hip_y kurtosis                               float64
#  660   right_hip_y skew                                   float64
#  661   right_hip_y quantile 25                            float64
#  662   right_hip_y quantile 75                            float64
#  663   right_hip_y RMS                                    float64
#  664   right_hip_y MAV                                    float64
#  665   right_hip_y rmse                                   float64
#  666   right_hip_y mae                                    float64
#  667   right_hip_y maxerror                               float64
#  668   right_hip_y minerror                               float64
#  669   right_hip_y stderror                               float64
#  670   right_hip_y quantile25e                            float64
#  671   right_hip_y quantile75e                            float64
#  672   right_shoulder nose dx mean_ft                     float64
#  673   right_shoulder nose dx std_ft                      float64
#  674   right_shoulder nose dx max_ft                      float64
#  675   right_shoulder nose dx min_ft                      float64
#  676   right_shoulder nose dx var_ft                      float64
#  677   right_shoulder nose dx med_ft                      float64
#  678   right_shoulder nose dx sum_ft                      float64
#  679   right_shoulder nose dx std                         float64
#  680   right_shoulder nose dx kurtosis                    float64
#  681   right_shoulder nose dx skew                        float64
#  682   right_shoulder nose dx quantile 25                 float64
#  683   right_shoulder nose dx quantile 75                 float64
#  684   right_shoulder nose dx RMS                         float64
#  685   right_shoulder nose dx MAV                         float64
#  686   right_shoulder nose dx rmse                        float64
#  687   right_shoulder nose dx mae                         float64
#  688   right_shoulder nose dx maxerror                    float64
#  689   right_shoulder nose dx minerror                    float64
#  690   right_shoulder nose dx stderror                    float64
#  691   right_shoulder nose dx quantile25e                 float64
#  692   right_shoulder nose dx quantile75e                 float64
#  693   right_shoulder nose dy mean_ft                     float64
#  694   right_shoulder nose dy std_ft                      float64
#  695   right_shoulder nose dy max_ft                      float64
#  696   right_shoulder nose dy min_ft                      float64
#  697   right_shoulder nose dy var_ft                      float64
#  698   right_shoulder nose dy med_ft                      float64
#  699   right_shoulder nose dy sum_ft                      float64
#  700   right_shoulder nose dy std                         float64
#  701   right_shoulder nose dy kurtosis                    float64
#  702   right_shoulder nose dy skew                        float64
#  703   right_shoulder nose dy quantile 25                 float64
#  704   right_shoulder nose dy quantile 75                 float64
#  705   right_shoulder nose dy RMS                         float64
#  706   right_shoulder nose dy MAV                         float64
#  707   right_shoulder nose dy rmse                        float64
#  708   right_shoulder nose dy mae                         float64
#  709   right_shoulder nose dy maxerror                    float64
#  710   right_shoulder nose dy minerror                    float64
#  711   right_shoulder nose dy stderror                    float64
#  712   right_shoulder nose dy quantile25e                 float64
#  713   right_shoulder nose dy quantile75e                 float64
#  714   right_shoulder left_eye dx mean_ft                 float64
#  715   right_shoulder left_eye dx std_ft                  float64
#  716   right_shoulder left_eye dx max_ft                  float64
#  717   right_shoulder left_eye dx min_ft                  float64
#  718   right_shoulder left_eye dx var_ft                  float64
#  719   right_shoulder left_eye dx med_ft                  float64
#  720   right_shoulder left_eye dx sum_ft                  float64
#  721   right_shoulder left_eye dx std                     float64
#  722   right_shoulder left_eye dx kurtosis                float64
# ...
#  4257  movingright_shoulder right_elbow dx mae            float64
#  4258  movingright_shoulder right_elbow dx maxerror       float64
#  4259  movingright_shoulder right_elbow dx minerror       float64
#  4260  movingright_shoulder right_elbow dx stderror       float64
#  4261  movingright_shoulder right_elbow dx quantile25e    float64
#  4262  movingright_shoulder right_elbow dx quantile75e    float64
#  4263  movingright_shoulder right_elbow dy mean_ft        float64
#  4264  movingright_shoulder right_elbow dy std_ft         float64
#  4265  movingright_shoulder right_elbow dy max_ft         float64
#  4266  movingright_shoulder right_elbow dy min_ft         float64
#  4267  movingright_shoulder right_elbow dy var_ft         float64
#  4268  movingright_shoulder right_elbow dy med_ft         float64
#  4269  movingright_shoulder right_elbow dy sum_ft         float64
#  4270  movingright_shoulder right_elbow dy std            float64
#  4271  movingright_shoulder right_elbow dy kurtosis       float64
#  4272  movingright_shoulder right_elbow dy skew           float64
#  4273  movingright_shoulder right_elbow dy quantile 25    float64
#  4274  movingright_shoulder right_elbow dy quantile 75    float64
#  4275  movingright_shoulder right_elbow dy RMS            float64
#  4276  movingright_shoulder right_elbow dy MAV            float64
#  4277  movingright_shoulder right_elbow dy rmse           float64
#  4278  movingright_shoulder right_elbow dy mae            float64
#  4279  movingright_shoulder right_elbow dy maxerror       float64
#  4280  movingright_shoulder right_elbow dy minerror       float64
#  4281  movingright_shoulder right_elbow dy stderror       float64
#  4282  movingright_shoulder right_elbow dy quantile25e    float64
#  4283  movingright_shoulder right_elbow dy quantile75e    float64
#  4284  movingright_shoulder left_wrist dx mean_ft         float64
#  4285  movingright_shoulder left_wrist dx std_ft          float64
#  4286  movingright_shoulder left_wrist dx max_ft          float64
#  4287  movingright_shoulder left_wrist dx min_ft          float64
#  4288  movingright_shoulder left_wrist dx var_ft          float64
#  4289  movingright_shoulder left_wrist dx med_ft          float64
#  4290  movingright_shoulder left_wrist dx sum_ft          float64
#  4291  movingright_shoulder left_wrist dx std             float64
#  4292  movingright_shoulder left_wrist dx kurtosis        float64
#  4293  movingright_shoulder left_wrist dx skew            float64
#  4294  movingright_shoulder left_wrist dx quantile 25     float64
#  4295  movingright_shoulder left_wrist dx quantile 75     float64
#  4296  movingright_shoulder left_wrist dx RMS             float64
#  4297  movingright_shoulder left_wrist dx MAV             float64
#  4298  movingright_shoulder left_wrist dx rmse            float64
#  4299  movingright_shoulder left_wrist dx mae             float64
#  4300  movingright_shoulder left_wrist dx maxerror        float64
#  4301  movingright_shoulder left_wrist dx minerror        float64
#  4302  movingright_shoulder left_wrist dx stderror        float64
#  4303  movingright_shoulder left_wrist dx quantile25e     float64
#  4304  movingright_shoulder left_wrist dx quantile75e     float64
#  4305  movingright_shoulder left_wrist dy mean_ft         float64
#  4306  movingright_shoulder left_wrist dy std_ft          float64
#  4307  movingright_shoulder left_wrist dy max_ft          float64
#  4308  movingright_shoulder left_wrist dy min_ft          float64
#  4309  movingright_shoulder left_wrist dy var_ft          float64
#  4310  movingright_shoulder left_wrist dy med_ft          float64
#  4311  movingright_shoulder left_wrist dy sum_ft          float64
#  4312  movingright_shoulder left_wrist dy std             float64
#  4313  movingright_shoulder left_wrist dy kurtosis        float64
#  4314  movingright_shoulder left_wrist dy skew            float64
#  4315  movingright_shoulder left_wrist dy quantile 25     float64
#  4316  movingright_shoulder left_wrist dy quantile 75     float64
#  4317  movingright_shoulder left_wrist dy RMS             float64
#  4318  movingright_shoulder left_wrist dy MAV             float64
#  4319  movingright_shoulder left_wrist dy rmse            float64
#  4320  movingright_shoulder left_wrist dy mae             float64
#  4321  movingright_shoulder left_wrist dy maxerror        float64
#  4322  movingright_shoulder left_wrist dy minerror        float64
#  4323  movingright_shoulder left_wrist dy stderror        float64
#  4324  movingright_shoulder left_wrist dy quantile25e     float64
#  4325  movingright_shoulder left_wrist dy quantile75e     float64
#  4326  movingright_shoulder right_wrist dx mean_ft        float64
#  4327  movingright_shoulder right_wrist dx std_ft         float64
#  4328  movingright_shoulder right_wrist dx max_ft         float64
#  4329  movingright_shoulder right_wrist dx min_ft         float64
#  4330  movingright_shoulder right_wrist dx var_ft         float64
#  4331  movingright_shoulder right_wrist dx med_ft         float64
#  4332  movingright_shoulder right_wrist dx sum_ft         float64
#  4333  movingright_shoulder right_wrist dx std            float64
#  4334  movingright_shoulder right_wrist dx kurtosis       float64
#  4335  movingright_shoulder right_wrist dx skew           float64
#  4336  movingright_shoulder right_wrist dx quantile 25    float64
#  4337  movingright_shoulder right_wrist dx quantile 75    float64
#  4338  movingright_shoulder right_wrist dx RMS            float64
#  4339  movingright_shoulder right_wrist dx MAV            float64
#  4340  movingright_shoulder right_wrist dx rmse           float64
#  4341  movingright_shoulder right_wrist dx mae            float64
#  4342  movingright_shoulder right_wrist dx maxerror       float64
#  4343  movingright_shoulder right_wrist dx minerror       float64
#  4344  movingright_shoulder right_wrist dx stderror       float64
#  4345  movingright_shoulder right_wrist dx quantile25e    float64
#  4346  movingright_shoulder right_wrist dx quantile75e    float64
#  4347  movingright_shoulder right_wrist dy mean_ft        float64
#  4348  movingright_shoulder right_wrist dy std_ft         float64
#  4349  movingright_shoulder right_wrist dy max_ft         float64
#  4350  movingright_shoulder right_wrist dy min_ft         float64
#  4351  movingright_shoulder right_wrist dy var_ft         float64
#  4352  movingright_shoulder right_wrist dy med_ft         float64
#  4353  movingright_shoulder right_wrist dy sum_ft         float64
#  4354  movingright_shoulder right_wrist dy std            float64
#  4355  movingright_shoulder right_wrist dy kurtosis       float64
#  4356  movingright_shoulder right_wrist dy skew           float64
#  4357  movingright_shoulder right_wrist dy quantile 25    float64
#  4358  movingright_shoulder right_wrist dy quantile 75    float64
#  4359  movingright_shoulder right_wrist dy RMS            float64
#  4360  movingright_shoulder right_wrist dy MAV            float64
#  4361  movingright_shoulder right_wrist dy rmse           float64
#  4362  movingright_shoulder right_wrist dy mae            float64
#  4363  movingright_shoulder right_wrist dy maxerror       float64
#  4364  movingright_shoulder right_wrist dy minerror       float64
#  4365  movingright_shoulder right_wrist dy stderror       float64
#  4366  movingright_shoulder right_wrist dy quantile25e    float64
#  4367  movingright_shoulder right_wrist dy quantile75e    float64
#  4368  movingright_shoulder left_hip dx mean_ft           float64
#  4369  movingright_shoulder left_hip dx std_ft            float64
#  4370  movingright_shoulder left_hip dx max_ft            float64
#  4371  movingright_shoulder left_hip dx min_ft            float64
#  4372  movingright_shoulder left_hip dx var_ft            float64
#  4373  movingright_shoulder left_hip dx med_ft            float64
#  4374  movingright_shoulder left_hip dx sum_ft            float64
#  4375  movingright_shoulder left_hip dx std               float64
#  4376  movingright_shoulder left_hip dx kurtosis          float64
#  4377  movingright_shoulder left_hip dx skew              float64
#  4378  movingright_shoulder left_hip dx quantile 25       float64
#  4379  movingright_shoulder left_hip dx quantile 75       float64
#  4380  movingright_shoulder left_hip dx RMS               float64
#  4381  movingright_shoulder left_hip dx MAV               float64
#  4382  movingright_shoulder left_hip dx rmse              float64
#  4383  movingright_shoulder left_hip dx mae               float64
#  4384  movingright_shoulder left_hip dx maxerror          float64
#  4385  movingright_shoulder left_hip dx minerror          float64
#  4386  movingright_shoulder left_hip dx stderror          float64
#  4387  movingright_shoulder left_hip dx quantile25e       float64
#  4388  movingright_shoulder left_hip dx quantile75e       float64
#  4389  movingright_shoulder left_hip dy mean_ft           float64
#  4390  movingright_shoulder left_hip dy std_ft            float64
#  4391  movingright_shoulder left_hip dy max_ft            float64
#  4392  movingright_shoulder left_hip dy min_ft            float64
#  4393  movingright_shoulder left_hip dy var_ft            float64
#  4394  movingright_shoulder left_hip dy med_ft            float64
#  4395  movingright_shoulder left_hip dy sum_ft            float64
#  4396  movingright_shoulder left_hip dy std               float64
#  4397  movingright_shoulder left_hip dy kurtosis          float64
#  4398  movingright_shoulder left_hip dy skew              float64
#  4399  movingright_shoulder left_hip dy quantile 25       float64
#  4400  movingright_shoulder left_hip dy quantile 75       float64
#  4401  movingright_shoulder left_hip dy RMS               float64
#  4402  movingright_shoulder left_hip dy MAV               float64
#  4403  movingright_shoulder left_hip dy rmse              float64
#  4404  movingright_shoulder left_hip dy mae               float64
#  4405  movingright_shoulder left_hip dy maxerror          float64
#  4406  movingright_shoulder left_hip dy minerror          float64
#  4407  movingright_shoulder left_hip dy stderror          float64
#  4408  movingright_shoulder left_hip dy quantile25e       float64
#  4409  movingright_shoulder left_hip dy quantile75e       float64
#  4410  movingright_shoulder right_hip dx mean_ft          float64
#  4411  movingright_shoulder right_hip dx std_ft           float64
#  4412  movingright_shoulder right_hip dx max_ft           float64
#  4413  movingright_shoulder right_hip dx min_ft           float64
#  4414  movingright_shoulder right_hip dx var_ft           float64
#  4415  movingright_shoulder right_hip dx med_ft           float64
#  4416  movingright_shoulder right_hip dx sum_ft           float64
#  4417  movingright_shoulder right_hip dx std              float64
#  4418  movingright_shoulder right_hip dx kurtosis         float64
#  4419  movingright_shoulder right_hip dx skew             float64
#  4420  movingright_shoulder right_hip dx quantile 25      float64
#  4421  movingright_shoulder right_hip dx quantile 75      float64
#  4422  movingright_shoulder right_hip dx RMS              float64
#  4423  movingright_shoulder right_hip dx MAV              float64
#  4424  movingright_shoulder right_hip dx rmse             float64
#  4425  movingright_shoulder right_hip dx mae              float64
#  4426  movingright_shoulder right_hip dx maxerror         float64
#  4427  movingright_shoulder right_hip dx minerror         float64
#  4428  movingright_shoulder right_hip dx stderror         float64
#  4429  movingright_shoulder right_hip dx quantile25e      float64
#  4430  movingright_shoulder right_hip dx quantile75e      float64
#  4431  movingright_shoulder right_hip dy mean_ft          float64
#  4432  movingright_shoulder right_hip dy std_ft           float64
#  4433  movingright_shoulder right_hip dy max_ft           float64
#  4434  movingright_shoulder right_hip dy min_ft           float64
#  4435  movingright_shoulder right_hip dy var_ft           float64
#  4436  movingright_shoulder right_hip dy med_ft           float64
#  4437  movingright_shoulder right_hip dy sum_ft           float64
#  4438  movingright_shoulder right_hip dy std              float64
#  4439  movingright_shoulder right_hip dy kurtosis         float64
#  4440  movingright_shoulder right_hip dy skew             float64
#  4441  movingright_shoulder right_hip dy quantile 25      float64
#  4442  movingright_shoulder right_hip dy quantile 75      float64
#  4443  movingright_shoulder right_hip dy RMS              float64
#  4444  movingright_shoulder right_hip dy MAV              float64
#  4445  movingright_shoulder right_hip dy rmse             float64
#  4446  movingright_shoulder right_hip dy mae              float64
#  4447  movingright_shoulder right_hip dy maxerror         float64
#  4448  movingright_shoulder right_hip dy minerror         float64
#  4449  movingright_shoulder right_hip dy stderror         float64
#  4450  movingright_shoulder right_hip dy quantile25e      float64
#  4451  movingright_shoulder right_hip dy quantile75e      float64
#  4452  movingcenter_x mean_ft                             float64
#  4453  movingcenter_x std_ft                              float64
#  4454  movingcenter_x max_ft                              float64
#  4455  movingcenter_x min_ft                              float64
#  4456  movingcenter_x var_ft                              float64
#  4457  movingcenter_x med_ft                              float64
#  4458  movingcenter_x sum_ft                              float64
#  4459  movingcenter_x std                                 float64
#  4460  movingcenter_x kurtosis                            float64
#  4461  movingcenter_x skew                                float64
#  4462  movingcenter_x quantile 25                         float64
#  4463  movingcenter_x quantile 75                         float64
#  4464  movingcenter_x RMS                                 float64
#  4465  movingcenter_x MAV                                 float64
#  4466  movingcenter_x rmse                                float64
#  4467  movingcenter_x mae                                 float64
#  4468  movingcenter_x maxerror                            float64
#  4469  movingcenter_x minerror                            float64
#  4470  movingcenter_x stderror                            float64
#  4471  movingcenter_x quantile25e                         float64
#  4472  movingcenter_x quantile75e                         float64
#  4473  movingcenter_y mean_ft                             float64
#  4474  movingcenter_y std_ft                              float64
#  4475  movingcenter_y max_ft                              float64
#  4476  movingcenter_y min_ft                              float64
#  4477  movingcenter_y var_ft                              float64
#  4478  movingcenter_y med_ft                              float64
#  4479  movingcenter_y sum_ft                              float64
#  4480  movingcenter_y std                                 float64
#  4481  movingcenter_y kurtosis                            float64
#  4482  movingcenter_y skew                                float64
#  4483  movingcenter_y quantile 25                         float64
#  4484  movingcenter_y quantile 75                         float64
#  4485  movingcenter_y RMS                                 float64
#  4486  movingcenter_y MAV                                 float64
#  4487  movingcenter_y rmse                                float64
#  4488  movingcenter_y mae                                 float64
#  4489  movingcenter_y maxerror                            float64
#  4490  movingcenter_y minerror                            float64
#  4491  movingcenter_y stderror                            float64
#  4492  movingcenter_y quantile25e                         float64
#  4493  movingcenter_y quantile75e                         float64
#  4494  previous_label                                     int64
#  4495  label                                              float64
#  4496  after1                                             int64
#  4497  after4                                             int64
# dtypes: float64(4495), int64(3)
# memory usage: 96.8 MB

# %%
sns.histplot(df["label"])
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='label', ylabel='Count'>

# %%
X=df.drop(["label","previous_label",'after1','after4'],axis=1)
y=df['label']

# %%
X.shape
# Out:
# (2817, 4494)

# %%
y.shape
# Out:
# (2817,)

# %%
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='logloss', random_state=10)
# xgbcl.fit(X_train,y_train)
# # filename = './xgb_model.sav'
# # xgbcl=joblib.load(filename)
# pred=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.ensemble import RandomForestClassifier #Random Forest
# rf=RandomForestClassifier(random_state=10)
# rf.fit(X_train,y_train)
# pred=rf.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# import joblib
# filename = './xgb_model.sav'
# joblib.dump(xgbcl, filename)

# %%
# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(X_train,y_train)
# pred=svc.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
# knn = RadiusNeighborsClassifier(radius=175)
# knn.fit(X_train,y_train)
# pred=knn.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.linear_model import SGDClassifier
## sgd=SGDClassifier()loss='epsilon_insensitive'
# sgd.fit(X_train,y_train)
# pred=sgd.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
from sklearn.feature_selection import SelectKBest,f_regression
# Applying SelectKBest class to extract top 15 best features
fs = SelectKBest(score_func=f_regression,k=15)
# Applying feature selection
fit = fs.fit(X,y)
features_score = pd.DataFrame(fit.scores_)
features = pd.DataFrame(X.columns)
feature_score = pd.concat([features,features_score],axis=1)
# Assigning column names
feature_score.columns = ["Input_Features","F_Score"]
print(feature_score.nlargest(300,columns="F_Score"))
# dfi.export(feature_score.nlargest(16,columns="F_Score"),'./image/fulltest/f_test.png')
# feature_score.nlargest(300,columns="F_Score")['Input_Features'].values
# Out:
#                                        Input_Features      F_Score
# 4366  movingright_shoulder right_wrist dy quantile25e  2232.801787
# 4341          movingright_shoulder right_wrist dx mae  2091.255925
# 4330       movingright_shoulder right_wrist dx var_ft  2091.255925
# 4345  movingright_shoulder right_wrist dx quantile25e  2080.020681
# 4351       movingright_shoulder right_wrist dy var_ft  2054.786084
# ...                                               ...          ...
# 4049       movingright_shoulder right_eye dx minerror  1200.548236
# 3925                    movingright_hip_x quantile25e  1197.255048
# 468                              right_elbow_x sum_ft  1195.548073
# 462                             right_elbow_x mean_ft  1195.548073
# 4085     movingright_shoulder left_ear dx quantile 75  1194.393739
#
# [300 rows x 2 columns]

# %%
X_train=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train=y
X_test=test.drop(["label","previous_label"],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test=test['label']

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier #Random Forest
# try:
# oversampling the train dataset using SMOTE

sm = SMOTE()
all_feature_smote, all_label_smote = sm.fit_resample(X_train,y_train)
# rf=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf.fit(all_feature_smote, all_label_smote)
# # filename = './model/smote_rf_model.sav'
# # rf=joblib.load(filename)
# pred_rf=rf.predict(X_test)

# print(metrics.classification_report(pred_rf,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model/smote_rf_model2.sav'
# joblib.dump(rf, filename)

# %%
a=[e for e in X_train if e not in X_test]
a
# Out:
# []

# %%
from xgboost import XGBClassifier#XGBcalssifier
from xgboost import callback
early_stop = callback.EarlyStopping(
    rounds=4, metric_name='mlogloss', save_best=True
)
try:
    filename = './model_window/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    pred_xgb=xgbcl.predict(X_test)
except:
    xgbcl=XGBClassifier( eval_metric='mlogloss', random_state=10,callbacks=[early_stop])
    xgbcl.fit(all_feature_smote, all_label_smote,eval_set=[(X_test, y_test)])
    pred_xgb=xgbcl.predict(X_test)

from sklearn import metrics #accuracy measure
print(metrics.classification_report(pred_xgb,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_xgb,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# [0]	validation_0-mlogloss:1.73572
# [1]	validation_0-mlogloss:1.59413
# [2]	validation_0-mlogloss:1.46003
# [3]	validation_0-mlogloss:1.35758
# [4]	validation_0-mlogloss:1.26517
# [5]	validation_0-mlogloss:1.19937
# [6]	validation_0-mlogloss:1.14048
# [7]	validation_0-mlogloss:1.08495
# [8]	validation_0-mlogloss:1.04357
# [9]	validation_0-mlogloss:1.01763
# [10]	validation_0-mlogloss:0.97850
# [11]	validation_0-mlogloss:0.95654
# [12]	validation_0-mlogloss:0.94915
# [13]	validation_0-mlogloss:0.91653
# [14]	validation_0-mlogloss:0.91596
# [15]	validation_0-mlogloss:0.90056
# [16]	validation_0-mlogloss:0.88591
# [17]	validation_0-mlogloss:0.88230
# [18]	validation_0-mlogloss:0.86980
# [19]	validation_0-mlogloss:0.85191
# [20]	validation_0-mlogloss:0.84708
# [21]	validation_0-mlogloss:0.83924
# [22]	validation_0-mlogloss:0.82599
# [23]	validation_0-mlogloss:0.81973
# [24]	validation_0-mlogloss:0.81252
# [25]	validation_0-mlogloss:0.80168
# [26]	validation_0-mlogloss:0.79983
# [27]	validation_0-mlogloss:0.79058
# [28]	validation_0-mlogloss:0.77811
# [29]	validation_0-mlogloss:0.77546
# [30]	validation_0-mlogloss:0.75711
# [31]	validation_0-mlogloss:0.76111
# [32]	validation_0-mlogloss:0.75950
# [33]	validation_0-mlogloss:0.75714
# [34]	validation_0-mlogloss:0.75842
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81        61
#            1       0.00      0.00      0.00         3
#            2       0.71      0.67      0.69        15
#            3       0.00      0.00      0.00         1
#            4       0.45      0.88      0.60        16
#            5       1.00      0.60      0.75         5
#            6       0.40      0.50      0.44         4
#            7       0.72      0.64      0.68        28
#            8       0.60      1.00      0.75         3
#
#     accuracy                           0.69       136
#    macro avg       0.53      0.56      0.52       136
# weighted avg       0.75      0.69      0.71       136
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# <Axes: >

# %%
# X_train_with_predictions.shape

# %%
# X_train_with_predictions=df.drop(["label"],axis=1)
# y_train_with_predictions=df['label']
# X_test["previous_label"]=pred_xgb
# all_feature_smote_with_predictions, all_label_smote_with_predictions = sm.fit_resample(X_train_with_predictions,y_train_with_predictions)
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='aucs‌', random_state=10)
# xgbcl.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_xgb_with_predictions=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_xgb_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_xgb_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# rf_with_predictions=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf_with_predictions.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_rf_with_predictions=rf_with_predictions.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_rf_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_window4/smote_xgb_model2.sav'
joblib.dump(xgbcl, filename)
# Out:
# ['./model_window4/smote_xgb_model2.sav']

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
HGBC=HistGradientBoostingClassifier(random_state=10)
# HGBC.fit(X_train,y_train)
try:
    filename = './model_window4/smote_HGBC_model2.sav'
    HGBC=joblib.load(filename)
    pred=HGBC.predict(X_test)
except:
    HGBC.fit(all_feature_smote, all_label_smote )
    pred=HGBC.predict(X_test)


print(metrics.classification_report(pred,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.69      0.79        64
#          1.0       0.00      0.00      0.00         2
#          2.0       0.71      0.91      0.80        11
#          3.0       0.00      0.00      0.00         1
#          4.0       0.45      0.78      0.57        18
#          5.0       0.00      0.00      0.00         2
#          6.0       0.20      1.00      0.33         1
#          7.0       0.92      0.68      0.78        34
#          8.0       0.60      1.00      0.75         3
#
#     accuracy                           0.70       136
#    macro avg       0.42      0.56      0.45       136
# weighted avg       0.79      0.70      0.72       136
# <Axes: >

# %%
filename = './model_window4/smote_HGBC_model2.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_window4/smote_HGBC_model2.sav']

# %%
# def predict0_4(df):
# #     print(df['label_pred'])
# #     print(df['label_pred'] in [1,2,3,5,6,7,8])
#     if df['previous_label'] in [1,2,3,5,6,7,8]:
#         return df['previous_label']
#     else:
# #         print(np.array(df.drop(["label","previous_label",'label_pred'])))
# # xgb_class0_4
#         return xgbcl.predict(np.array(df.drop(["label",'previous_label'
#                                     ])).reshape(1,-1)).view().item()

# %%
# from sklearn.ensemble import AdaBoostClassifier
# test['previous_label']=pred_xgb
# # test['previous_label']=list(pred_xgb).insert(0,0)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label",'previous_label'],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4=np.array(X_train_class0_4)
# y_train_class0_4=np.array(y_train_class0_4)
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# xgb_class0_4=RandomForestClassifier(random_state=10,n_estimators=30,criterion='gini')#XGBClassifier( eval_metric='logloss', random_state=10)
# try:
#     print('sm')
# #     xgb_class0_4.fit(X_train_class0_4sm, y_train_class0_4sm)
# except:
#     print('no sm')
# #     xgb_class0_4.fit(X_train_class0_4, y_train_class0_4)
# test['label_pred']=test.apply(lambda x:predict0_4(x),axis=1)

# # test_class0_4=test[(test['label_pred'].isin([0,4]))&(test['label'].isin([0,4]))]
# # X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# # y_test_class0_4=test_class0_4.label
# # # X_test_class0_4=np.array(X_test_class0_4)
# # # y_test_class0_4=np.array(y_test_class0_4)

# # pred_class0_4=xgb_class0_4.predict(X_test_class0_4)
# print(metrics.classification_report(test['label'],test['label_pred']))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(test['label'],test['label_pred'], normalize='true')
# sns.heatmap(conf,annot=True)

# %%
test['label1']=pred
# turn2
test['previous_label']=test['label1']
test['second_turn']=test['previous_label'].diff()
test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
turn=list(test['second_turn'])
turn_2=[]

if (test['label'][0].item()>0): 
    count=2
else: 
    count=1
for i in range(len(turn)):

    if turn[i]<-3:
        count-=1
    if count<=0:
        turn_2.append(1) 
    else:
        turn_2.append(0) 
test['turn']=turn
test['second_turn']=turn_2
            
print(list(test['label'])[0])
def fturn():
    if list(test['label'])[0]>0: 
        after0=1
    else: after0=1
    return after0
after0=fturn()
sturn=True
after1=[]
after4=[]
for i in range(len(test['label'])):

    if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
        after0-=1
    if (list(test['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after1.append(1) 
    else:
        after1.append(0) 
after0=fturn()
sturn=True
for i in range(len(test['label'])):
    if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
        after0-=1
    if (list(test['second_turn'])[i]>0) and sturn==True:
        after0=fturn()
        sturn=False
    if after0<=0:
#         print(after0)
        after4.append(1) 
    else:
        after4.append(0) 


test['after1']=after1
test['after4']=after4
test=test.drop(['second_turn','turn'],axis=1)
# Out:
# 8

# %%
X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test_a=test['label']

X=df.drop(["label","previous_label"],axis=1)
y=df['label']
X_train_a=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train_a=y

all_feature_smote_a, all_label_smote_a = sm.fit_resample(X_train_a,y_train_a)

# %%
try:
    filename = './model_window4/smote_HGBC_model_after.sav'
    HGBC=joblib.load(filename)
    pred_a=HGBC.predict(X_test_a)
except:
    print('learning')
    HGBC=HistGradientBoostingClassifier(random_state=10)
    HGBC.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=HGBC.predict(X_test_a)


print(metrics.classification_report(pred_a,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_a,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.73      0.84        66
#          1.0       0.00      0.00      0.00         0
#          2.0       0.64      0.90      0.75        10
#          3.0       0.00      0.00      0.00         0
#          4.0       0.48      1.00      0.65        15
#          5.0       0.33      0.50      0.40         2
#          6.0       0.60      1.00      0.75         3
#          7.0       0.96      0.65      0.77        37
#          8.0       0.60      1.00      0.75         3
#
#     accuracy                           0.76       136
#    macro avg       0.51      0.64      0.55       136
# weighted avg       0.88      0.76      0.79       136
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <Axes: >

# %%
# XGB=RandomForestClassifier(random_state=10)
# XGB.fit(all_feature_smote_a, all_label_smote_a)

# pred_b=XGB.predict(X_test_a)

# print(metrics.classification_report(pred_b,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_b,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = './model_window4/smote_HGBC_model_after.sav'
joblib.dump(HGBC, filename)
# Out:
# ['./model_window4/smote_HGBC_model_after.sav']

# %%
# import six
# import sys
# sys.modules['sklearn.externals.six'] = six
# from seqlearn.perceptron import StructuredPerceptron

try:
    filename = './model_window4/smote_xgb_model_after.sav'
    xgbafter=joblib.load(filename)
    pred_a=xgbafter.predict(X_test_a)
except:
    print('learning')
    xgbafter=XGBClassifier( eval_metric='mlogloss', random_state=10)
    xgbafter.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=xgbafter.predict(X_test_a)
    
print(metrics.classification_report(pred_a,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_a,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# learning
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79        64
#            1       0.00      0.00      0.00         2
#            2       0.86      0.92      0.89        13
#            3       0.00      0.00      0.00         1
#            4       0.39      0.86      0.53        14
#            5       0.67      0.40      0.50         5
#            6       0.40      0.67      0.50         3
#            7       0.92      0.77      0.84        30
#            8       0.80      1.00      0.89         4
#
#     accuracy                           0.73       136
#    macro avg       0.55      0.59      0.55       136
# weighted avg       0.81      0.73      0.75       136
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# <Axes: >

# %%
filename = './model_window4/smote_xgb_model_after.sav'
joblib.dump(xgbafter, filename)
# Out:
# ['./model_window4/smote_xgb_model_after.sav']

# %%
from sklearn.ensemble import GradientBoostingClassifier
# import six
# import sys
# sys.modules['sklearn.externals.six'] = six
# from seqlearn.perceptron import StructuredPerceptron

try:
    filename = './model_window4/smote_ada_model_after.sav'
    ada=joblib.load(filename)
    pred_a=ada.predict(X_test_a)
except:
    
    print('learning')
    ada=GradientBoostingClassifier(n_estimators=200,max_features=9)
    ada.fit(all_feature_smote_a, all_label_smote_a )
    pred_a=ada.predict(X_test_a)    
print(metrics.classification_report(y_test,pred_a))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(y_test,pred_a, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# learning
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75        48
#            1       0.50      1.00      0.67         1
#            2       1.00      0.50      0.67        14
#            3       0.00      0.00      0.00         4
#            4       0.62      0.74      0.68        31
#            5       0.67      0.67      0.67         3
#            6       0.67      0.40      0.50         5
#            7       0.61      0.92      0.73        25
#            8       1.00      0.60      0.75         5
#
#     accuracy                           0.70       136
#    macro avg       0.65      0.62      0.60       136
# weighted avg       0.71      0.70      0.69       136
# <Axes: >

# %%
filename = './model_window4/smote_ada_model_after.sav'
joblib.dump(ada, filename)
# Out:
# ['./model_window4/smote_ada_model_after.sav']

# %%
# from sklearn.ensemble import AdaBoostClassifier
# ada=AdaBoostClassifier(random_state=10)
# ada.fit(X_train,y_train)
# pred=ada.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from catboost import CatBoostClassifier
# # catboost=CatBoostClassifier()
# # catboost.fit(X_train,y_train)
# filename = './catboost_model.sav'
# catboost=joblib.load(filename)
# pred=catboost.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './catboost_model.sav'
# joblib.dump(catboost, filename)

# %%
# from keras.layers import TimeDistributed
# # # trainX=np.array(X_train)
# # testX=np.array(X_test)
# # # trainY=np.array(y_train)
# # testY=np.array(y_test)
# # trainX=np.array(all_feature_smote)
# # trainY=np.array(all_label_smote)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label","previous_label"],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# trainX=np.array(X_train_class0_4sm)
# trainY=np.array(y_train_class0_4sm)

# test_class0_4=test[test['label'].isin([0,4])]
# X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# y_test_class0_4=test_class0_4.label
# testX=np.array(X_test_class0_4)
# testY=np.array(y_test_class0_4)

# # # testY = tf.keras.utils.to_categorical(testY)
# # # trainY = tf.keras.utils.to_categorical(trainY)
# # trainX = np.expand_dims(trainX, 2)
# # testX = np.expand_dims(testX, 2)

# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# from tensorflow.keras import models
# model = models.Sequential()
# model.add(layers.Input(shape=(len(trainX[1]), 1)))
# model.add(layers.Conv1D(64,64, activation='relu'))
# # model.add(LSTM(units=3, return_sequences=True))
# # model.add(LSTM(units=64, return_sequences=True))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Conv1D(32, 32, activation='relu'))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Conv1D(16, 16, activation='relu'))
# model.add(LSTM(units=64, return_sequences=True))
# # model.add(LSTM(units=32, return_sequences=True))
# model.add(LSTM(units=16, return_sequences=True))
# model.add(Dropout(0.5))

# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(32, activation='relu'))
# model.add(layers.Dense(9,activation='softmax'))
# mcp_save = ModelCheckpoint('DL_model.hdf5', save_best_only=True, monitor='val_loss', mode='min')
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# history = model.fit(trainX,trainY, epochs=100, 
#                     validation_data=(testX,testY), 
#                     callbacks=[early_stopping,mcp_save])

# %%
# plt.clf()
# plt.plot(history.history['loss'], label='loss')
# plt.plot(history.history['val_loss'], label = 'val_loss')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')

# plt.legend(loc='lower right')

# %%
# pred=model.predict(testX)
# pred=np.argmax(pred,axis=1)
# print(metrics.classification_report(pred,testY))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,testY, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# model_rnn = Sequential()
# model_rnn.add(LSTM(units=64, return_sequences=True, input_shape=(len(trainX[1]), 1)))
# model_rnn.add(Conv1D(128, 6))
# model_rnn.add(LSTM(units = 64, return_sequences = True))
# model_rnn.add(Dropout(0.2))
# model_rnn.add(Conv1D(128, 3))
# model_rnn.add(LSTM(units = 64, return_sequences = True))

# model_rnn.add(Dropout(0.2))
# model_rnn.add(LSTM(units = 64))

# model_rnn.add(Dense(units = 128))
# model_rnn.add(Dense(units = 64))

# model_rnn.add(Dense(units = 9, activation="softmax")) #4 as the output classes

# # Define the BRNN model with LSTM layers
# model_brnn = keras.Sequential([
#     layers.Bidirectional(layers.LSTM(64, activation='relu', return_sequences=True), 
#                          input_shape=(len(trainX[1]), 1)),
# #     layers.Bidirectional(layers.LSTM(64, activation='relu')),
# #     layers.Bidirectional(layers.LSTM(32, activation='relu')),
#     layers.Bidirectional(layers.LSTM(16, activation='relu')),
    
#     layers.Dense(9, activation='softmax')
# ])

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# # Compile the RNN model
# model_rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Compile the BRNN model
# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Define early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Train the RNN model with early stopping

# ## model_rnn.fit(all_feature, all_label, epochs=100, batch_size=500, validation_data=(X_vad, y_vad), callbacks=[early_stopping])

# # Train the BRNN model with early stopping

# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# # history_brnn=model_brnn.fit(trainX,trainY, epochs=10, batch_size=500,
# #                             validation_data=(testX,testY), callbacks=[early_stopping])
# # , callbacks=[early_stopping]

# %%
# history_rnn=model_rnn.fit(trainX,trainY, epochs=20,
#                             validation_data=(testX,testY), callbacks=[early_stopping])

# %%
len(all_label_smote)

# %%
# import scipy
# pred_aa=pd.Series(pred_a)
# pred_aa=pred_aa.rolling(3, min_periods=1).apply(scipy.stats.mode)
# pred_aa=pred_aa.apply(np.ceil)
# pred_aa=np.array(pred_aa)
# print(metrics.classification_report(pred_aa,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_aa,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
def output_xgb(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_window4/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_window4/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_window4/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window1/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_window4')
out_xgb=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_xgb(ID,out_xgb)
out_df_xgb=pd.DataFrame(out_xgb,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])

out_df_xgb
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#        ID  accuracy  weighted avg F1-score  F1_score class 0  \
# 0   S08T1  0.757353               0.729362          0.842105
# 1   S08T2  0.700000               0.669038          0.750000
# 2   N11T1  0.829268               0.820426          0.830189
# 3   N11T2  0.875000               0.862165          0.851064
# 4   N06T1  0.637097               0.630392          0.595745
# 5   S02T2  0.718182               0.713743          0.918919
# 6   N06T2  0.676923               0.648450          0.675000
# 7   S02T1  0.691176               0.658599          0.840000
# 8   N02T2  0.750000               0.734454          0.693333
# 9   N02T1  0.800000               0.778791          0.760870
# 10  S03T1  0.772321               0.751418          0.807229
# 11  S03T2  0.753555               0.723021          0.755556
#
#     F1_score class 1  F1_score class 2  F1_score class 3  F1_score class 4  \
# 0                NaN          0.750000               NaN          0.652174
# 1           0.666667          0.838710               NaN          0.530612
# 2                NaN          0.888889          1.000000          0.640000
# 3                NaN          1.000000               NaN          0.640000
# 4                NaN          0.705882               NaN          0.560000
# 5                NaN          0.296296          0.400000          0.787879
# 6                NaN          0.500000          0.500000          0.484848
# 7           0.666667          0.647059          0.153846          0.717949
# 8                NaN          0.800000          0.400000          0.352941
# 9                NaN          0.600000               NaN          0.500000
# 10               NaN          0.810811          0.400000          0.555556
# 11               NaN          0.709677               NaN          0.684211
#
#     F1_score class 5  F1_score class 6  F1_score class 7  F1_score class 8
# 0           0.400000          0.750000          0.774194          0.750000
# 1           0.400000          0.500000          0.793651          0.363636
# 2                NaN               NaN          0.915254          0.833333
# 3                NaN          1.000000          0.984615          1.000000
# 4                NaN               NaN          0.666667          0.903226
# 5           0.545455          0.400000          0.862745          0.142857
# 6                NaN          0.400000          0.851064          0.560000
# 7           0.800000          0.400000          0.655172          0.400000
# 8           0.666667          1.000000          0.984127          0.941176
# 9                NaN          1.000000          0.969697          1.000000
# 10          0.333333          0.400000          0.888889          0.800000
# 11               NaN          0.666667          0.869565          0.800000

# %%
test_set=os.listdir('./test_set_df')
test_set
# Out:
# ['.DS_Store',
#  'S08T1.csv',
#  'S08T2.csv',
#  'N11T1.csv',
#  'N11T2.csv',
#  'N06T1.csv',
#  'S02T2.csv',
#  'N06T2.csv',
#  'S02T1.csv',
#  'N02T2.csv',
#  'N02T1.csv',
#  'S03T1.csv',
#  'S03T2.csv']

# %%
def output_rf(ID,out):
    test=pd.read_csv(f'./test_set_df_acc_window4/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_window4/smote_HGBC_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    after4=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after0=fturn()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_window4/smote_HGBC_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     plt.savefig(f"./image/rf_gan_window1/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_window4')
out_rf=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_rf)
out_df=pd.DataFrame(out_rf,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])

out_df.describe()
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          2.000000
# mean    0.755685               0.734113          0.792305          0.666667
# std     0.075250               0.076688          0.092395          0.000000
# min     0.637097               0.630392          0.595745          0.666667
# 25%     0.708508               0.675825          0.759541          0.666667
# 50%     0.755454               0.726192          0.798676          0.666667
# 75%     0.801389               0.778749          0.840526          0.666667
# max     0.912500               0.894846          0.920000          0.666667
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          6.000000         12.000000          6.000000
# mean           0.712277          0.475641          0.607638          0.524242
# std            0.186790          0.281518          0.110592          0.181160
# min            0.296296          0.153846          0.428571          0.333333
# 25%            0.635294          0.400000          0.539894          0.400000
# 50%            0.729839          0.400000          0.600000          0.472727
# 75%            0.817786          0.475000          0.692645          0.636364
# max            1.000000          1.000000          0.787879          0.800000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         10.000000         12.000000         12.000000
# mean           0.651667          0.851303          0.707852
# std            0.268794          0.111692          0.278332
# min            0.400000          0.655172          0.142857
# 25%            0.400000          0.788786          0.520000
# 50%            0.583333          0.866155          0.800000
# 75%            0.937500          0.928865          0.912713
# max            1.000000          0.984615          1.000000

# %%
def output_xgb_2(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_window4/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_window4/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_window4/smote_xgb_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window1/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_window4')
out_xgb2=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_xgb2)
out_df2=pd.DataFrame(out_xgb2,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8

# %%
def output_ada(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_window4/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = './model_window4/smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    
    test['label1']=pred
    # turn2
    test['previous_label']=test['label1']
    test['second_turn']=test['previous_label'].diff()
    test['second_turn']=test.apply(lambda test:second_turn(test['label'],test['second_turn']),axis=1)
    turn=list(test['second_turn'])
    turn_2=[]

    if (test['label'][0].item()>0): 
        count=2
    else: 
        count=1
    for i in range(len(turn)):

        if turn[i]<-3:
            count-=1
        if count<=0:
            turn_2.append(1) 
        else:
            turn_2.append(0) 
    test['turn']=turn
    test['second_turn']=turn_2

    print(list(test['label'])[0])
    def fturn():
        if list(test['label'])[0]>0: 
            after0=1
        else: after0=1
        return after0
    after0=fturn()
    sturn=True
    after1=[]
    for i in range(len(test['label'])):

        if (list(test['label'])[i]==1)|(list(test['label'])[i]==2)|(list(test['label'])[i]==3):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after1.append(1) 
        else:
            after1.append(0) 
    test['after1']=after1
    after4=[]
    after0=fturn()
    sturn=True
    for i in range(len(test['label'])):
        if (list(test['label'])[i]==4)|(list(test['label'])[i]==5)|(list(test['label'])[i]==6):
            after0-=1
        if (list(test['second_turn'])[i]>0) and sturn==True:
            after0=fturn()
            sturn=False
        if after0<=0:
    #         print(after0)
            after4.append(1) 
        else:
            after4.append(0) 

    test['after4']=after4
    test=test.drop(['second_turn','turn'],axis=1)
    X_test_a=test.drop(["label","previous_label",'label1'],axis=1)
    # X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test_a=test['label']
    filename = './model_window4/smote_ada_model_after.sav'
    HGBC=joblib.load( filename)
    pred=HGBC.predict(X_test_a)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(y_test,pred,average='weighted')
    f1=metrics.f1_score(y_test,pred,average=None,labels=range(9),zero_division= np.nan)
    f1s0=f1[0]
    f1s1=f1[1]
    f1s2=f1[2]
    f1s3=f1[3]
    f1s4=f1[4]
    f1s5=f1[5]
    f1s6=f1[6]
    f1s7=f1[7]
    f1s8=f1[8]
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(y_test,pred,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_window1/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s,f1s0,f1s1,f1s2,f1s3,f1s4,f1s5,f1s6,f1s7,f1s8])

# %%
test_set=os.listdir('./test_set_df_acc_window4')
out_ada=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_ada(ID,out_ada)
out_ada=pd.DataFrame(out_ada,columns=['ID','accuracy','weighted avg F1-score',
                                       'F1_score class 0',
                                      'F1_score class 1',
                                      'F1_score class 2',
                                      'F1_score class 3',
                                      'F1_score class 4',
                                      'F1_score class 5',
                                      'F1_score class 6',
                                      'F1_score class 7',
                                      'F1_score class 8'])
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8

# %%
out_df.describe()#HGBC not rf model :(  HGBC HGBC
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          2.000000
# mean    0.755685               0.734113          0.792305          0.666667
# std     0.075250               0.076688          0.092395          0.000000
# min     0.637097               0.630392          0.595745          0.666667
# 25%     0.708508               0.675825          0.759541          0.666667
# 50%     0.755454               0.726192          0.798676          0.666667
# 75%     0.801389               0.778749          0.840526          0.666667
# max     0.912500               0.894846          0.920000          0.666667
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          6.000000         12.000000          6.000000
# mean           0.712277          0.475641          0.607638          0.524242
# std            0.186790          0.281518          0.110592          0.181160
# min            0.296296          0.153846          0.428571          0.333333
# 25%            0.635294          0.400000          0.539894          0.400000
# 50%            0.729839          0.400000          0.600000          0.472727
# 75%            0.817786          0.475000          0.692645          0.636364
# max            1.000000          1.000000          0.787879          0.800000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         10.000000         12.000000         12.000000
# mean           0.651667          0.851303          0.707852
# std            0.268794          0.111692          0.278332
# min            0.400000          0.655172          0.142857
# 25%            0.400000          0.788786          0.520000
# 50%            0.583333          0.866155          0.800000
# 75%            0.937500          0.928865          0.912713
# max            1.000000          0.984615          1.000000

# %%
out_df_xgb.describe()#XGB HGBC
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          2.000000
# mean    0.746740               0.726655          0.776667          0.666667
# std     0.067356               0.070110          0.090092          0.000000
# min     0.637097               0.630392          0.595745          0.666667
# 25%     0.697794               0.666429          0.735833          0.666667
# 50%     0.751777               0.726192          0.784049          0.666667
# 75%     0.779241               0.758261          0.840526          0.666667
# max     0.875000               0.862165          0.918919          0.666667
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          6.000000         12.000000          6.000000
# mean           0.712277          0.475641          0.592181          0.524242
# std            0.186790          0.281518          0.118390          0.181160
# min            0.296296          0.153846          0.352941          0.333333
# 25%            0.635294          0.400000          0.522959          0.400000
# 50%            0.729839          0.400000          0.600000          0.472727
# 75%            0.817786          0.475000          0.660183          0.636364
# max            1.000000          1.000000          0.787879          0.800000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         10.000000         12.000000         12.000000
# mean           0.651667          0.851303          0.707852
# std            0.268794          0.111692          0.278332
# min            0.400000          0.655172          0.142857
# 25%            0.400000          0.788786          0.520000
# 50%            0.583333          0.866155          0.800000
# 75%            0.937500          0.928865          0.912713
# max            1.000000          0.984615          1.000000

# %%
out_df2.describe()#XGB XGB
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          2.000000
# mean    0.755685               0.734113          0.792305          0.666667
# std     0.075250               0.076688          0.092395          0.000000
# min     0.637097               0.630392          0.595745          0.666667
# 25%     0.708508               0.675825          0.759541          0.666667
# 50%     0.755454               0.726192          0.798676          0.666667
# 75%     0.801389               0.778749          0.840526          0.666667
# max     0.912500               0.894846          0.920000          0.666667
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          6.000000         12.000000          6.000000
# mean           0.712277          0.475641          0.607638          0.524242
# std            0.186790          0.281518          0.110592          0.181160
# min            0.296296          0.153846          0.428571          0.333333
# 25%            0.635294          0.400000          0.539894          0.400000
# 50%            0.729839          0.400000          0.600000          0.472727
# 75%            0.817786          0.475000          0.692645          0.636364
# max            1.000000          1.000000          0.787879          0.800000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count         10.000000         12.000000         12.000000
# mean           0.651667          0.851303          0.707852
# std            0.268794          0.111692          0.278332
# min            0.400000          0.655172          0.142857
# 25%            0.400000          0.788786          0.520000
# 50%            0.583333          0.866155          0.800000
# 75%            0.937500          0.928865          0.912713
# max            1.000000          0.984615          1.000000

# %%
out_ada.describe()
# Out:
#         accuracy  weighted avg F1-score  F1_score class 0  F1_score class 1  \
# count  12.000000              12.000000         12.000000          3.000000
# mean    0.696286               0.678462          0.710972          0.822222
# std     0.074774               0.081717          0.102621          0.167774
# min     0.610294               0.584612          0.523077          0.666667
# 25%     0.639662               0.605537          0.649367          0.733333
# 50%     0.688047               0.661913          0.732684          0.800000
# 75%     0.739381               0.732256          0.764387          0.900000
# max     0.825000               0.816874          0.851064          1.000000
#
#        F1_score class 2  F1_score class 3  F1_score class 4  F1_score class 5  \
# count         12.000000          4.000000         12.000000          7.000000
# mean           0.610474          0.516667          0.586267          0.614966
# std            0.093882          0.257481          0.081629          0.217445
# min            0.421053          0.266667          0.390244          0.333333
# 25%            0.588889          0.316667          0.554968          0.485714
# 50%            0.612040          0.500000          0.584350          0.666667
# 75%            0.666667          0.700000          0.641329          0.666667
# max            0.800000          0.800000          0.692308          1.000000
#
#        F1_score class 6  F1_score class 7  F1_score class 8
# count          7.000000         12.000000         11.000000
# mean           0.665079          0.816689          0.610564
# std            0.314690          0.124014          0.258370
# min            0.222222          0.600000          0.222222
# 25%            0.416667          0.726724          0.366667
# 50%            0.800000          0.852688          0.666667
# 75%            0.900000          0.889037          0.828431
# max            1.000000          0.984615          0.909091
