# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd # data processing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D,Dropout,LSTM, Bidirectional
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.layers import BatchNormalization, Dropout
from keras.layers import Dense, Activation
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import torch
from torch.nn import Transformer
from sklearn.preprocessing import StandardScaler #good
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
from sklearn import metrics #accuracy measure
import joblib
import warnings

# %%
training_set=os.listdir("./training_set_df_acc_win3/")
df=None
for data in training_set:
    if data.endswith('.csv'):
        file=f"./training_set_df_acc_win3/{data}"
        if df is None:
            df=pd.read_csv(file)
        else:
            d=pd.read_csv(file)
            df=pd.concat([df,d])

# %%
df=df.astype(float)
df['label']=df['label'].astype(int)
df['label']=df['label'].astype("category")

# %%
test=pd.read_csv('./test_set_df_acc_win3/S08T1.csv')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3883 entries, 0 to 171
# Data columns (total 2998 columns):
#  #     Column                                              Dtype
# ---    ------                                              -----
#  0     left_elbow_shoulder_hip mean_ft                     float64
#  1     left_elbow_shoulder_hip std_ft                      float64
#  2     left_elbow_shoulder_hip max_ft                      float64
#  3     left_elbow_shoulder_hip min_ft                      float64
#  4     left_elbow_shoulder_hip var_ft                      float64
#  5     left_elbow_shoulder_hip med_ft                      float64
#  6     left_elbow_shoulder_hip sum_ft                      float64
#  7     left_elbow_shoulder_hip std                         float64
#  8     left_elbow_shoulder_hip kurtosis                    float64
#  9     left_elbow_shoulder_hip skew                        float64
#  10    left_elbow_shoulder_hip quantile 25                 float64
#  11    left_elbow_shoulder_hip quantile 75                 float64
#  12    left_elbow_shoulder_hip RMS                         float64
#  13    left_elbow_shoulder_hip MAV                         float64
#  14    right_elbow_shoulder_hip mean_ft                    float64
#  15    right_elbow_shoulder_hip std_ft                     float64
#  16    right_elbow_shoulder_hip max_ft                     float64
#  17    right_elbow_shoulder_hip min_ft                     float64
#  18    right_elbow_shoulder_hip var_ft                     float64
#  19    right_elbow_shoulder_hip med_ft                     float64
#  20    right_elbow_shoulder_hip sum_ft                     float64
#  21    right_elbow_shoulder_hip std                        float64
#  22    right_elbow_shoulder_hip kurtosis                   float64
#  23    right_elbow_shoulder_hip skew                       float64
#  24    right_elbow_shoulder_hip quantile 25                float64
#  25    right_elbow_shoulder_hip quantile 75                float64
#  26    right_elbow_shoulder_hip RMS                        float64
#  27    right_elbow_shoulder_hip MAV                        float64
#  28    left_wrist_elbow_shoulder mean_ft                   float64
#  29    left_wrist_elbow_shoulder std_ft                    float64
#  30    left_wrist_elbow_shoulder max_ft                    float64
#  31    left_wrist_elbow_shoulder min_ft                    float64
#  32    left_wrist_elbow_shoulder var_ft                    float64
#  33    left_wrist_elbow_shoulder med_ft                    float64
#  34    left_wrist_elbow_shoulder sum_ft                    float64
#  35    left_wrist_elbow_shoulder std                       float64
#  36    left_wrist_elbow_shoulder kurtosis                  float64
#  37    left_wrist_elbow_shoulder skew                      float64
#  38    left_wrist_elbow_shoulder quantile 25               float64
#  39    left_wrist_elbow_shoulder quantile 75               float64
#  40    left_wrist_elbow_shoulder RMS                       float64
#  41    left_wrist_elbow_shoulder MAV                       float64
#  42    right_wrist_elbow_shoulder mean_ft                  float64
#  43    right_wrist_elbow_shoulder std_ft                   float64
#  44    right_wrist_elbow_shoulder max_ft                   float64
#  45    right_wrist_elbow_shoulder min_ft                   float64
#  46    right_wrist_elbow_shoulder var_ft                   float64
#  47    right_wrist_elbow_shoulder med_ft                   float64
#  48    right_wrist_elbow_shoulder sum_ft                   float64
#  49    right_wrist_elbow_shoulder std                      float64
#  50    right_wrist_elbow_shoulder kurtosis                 float64
#  51    right_wrist_elbow_shoulder skew                     float64
#  52    right_wrist_elbow_shoulder quantile 25              float64
#  53    right_wrist_elbow_shoulder quantile 75              float64
#  54    right_wrist_elbow_shoulder RMS                      float64
#  55    right_wrist_elbow_shoulder MAV                      float64
#  56     right_elbow_shoulder mean_ft                       float64
#  57     right_elbow_shoulder std_ft                        float64
#  58     right_elbow_shoulder max_ft                        float64
#  59     right_elbow_shoulder min_ft                        float64
#  60     right_elbow_shoulder var_ft                        float64
#  61     right_elbow_shoulder med_ft                        float64
#  62     right_elbow_shoulder sum_ft                        float64
#  63     right_elbow_shoulder std                           float64
#  64     right_elbow_shoulder kurtosis                      float64
#  65     right_elbow_shoulder skew                          float64
#  66     right_elbow_shoulder quantile 25                   float64
#  67     right_elbow_shoulder quantile 75                   float64
#  68     right_elbow_shoulder RMS                           float64
#  69     right_elbow_shoulder MAV                           float64
#  70    left_elbow_shoulder mean_ft                         float64
#  71    left_elbow_shoulder std_ft                          float64
#  72    left_elbow_shoulder max_ft                          float64
#  73    left_elbow_shoulder min_ft                          float64
#  74    left_elbow_shoulder var_ft                          float64
#  75    left_elbow_shoulder med_ft                          float64
#  76    left_elbow_shoulder sum_ft                          float64
#  77    left_elbow_shoulder std                             float64
#  78    left_elbow_shoulder kurtosis                        float64
#  79    left_elbow_shoulder skew                            float64
#  80    left_elbow_shoulder quantile 25                     float64
#  81    left_elbow_shoulder quantile 75                     float64
#  82    left_elbow_shoulder RMS                             float64
#  83    left_elbow_shoulder MAV                             float64
#  84    right_shoulder_y mean_ft                            float64
#  85    right_shoulder_y std_ft                             float64
#  86    right_shoulder_y max_ft                             float64
#  87    right_shoulder_y min_ft                             float64
#  88    right_shoulder_y var_ft                             float64
#  89    right_shoulder_y med_ft                             float64
#  90    right_shoulder_y sum_ft                             float64
#  91    right_shoulder_y std                                float64
#  92    right_shoulder_y kurtosis                           float64
#  93    right_shoulder_y skew                               float64
#  94    right_shoulder_y quantile 25                        float64
#  95    right_shoulder_y quantile 75                        float64
#  96    right_shoulder_y RMS                                float64
#  97    right_shoulder_y MAV                                float64
#  98    right_shoulder_x mean_ft                            float64
#  99    right_shoulder_x std_ft                             float64
#  100   right_shoulder_x max_ft                             float64
#  101   right_shoulder_x min_ft                             float64
#  102   right_shoulder_x var_ft                             float64
#  103   right_shoulder_x med_ft                             float64
#  104   right_shoulder_x sum_ft                             float64
#  105   right_shoulder_x std                                float64
#  106   right_shoulder_x kurtosis                           float64
#  107   right_shoulder_x skew                               float64
#  108   right_shoulder_x quantile 25                        float64
#  109   right_shoulder_x quantile 75                        float64
#  110   right_shoulder_x RMS                                float64
#  111   right_shoulder_x MAV                                float64
#  112   nose_right_shoulder  dx mean_ft                     float64
#  113   nose_right_shoulder  dx std_ft                      float64
#  114   nose_right_shoulder  dx max_ft                      float64
#  115   nose_right_shoulder  dx min_ft                      float64
#  116   nose_right_shoulder  dx var_ft                      float64
#  117   nose_right_shoulder  dx med_ft                      float64
#  118   nose_right_shoulder  dx sum_ft                      float64
#  119   nose_right_shoulder  dx std                         float64
#  120   nose_right_shoulder  dx kurtosis                    float64
#  121   nose_right_shoulder  dx skew                        float64
#  122   nose_right_shoulder  dx quantile 25                 float64
#  123   nose_right_shoulder  dx quantile 75                 float64
#  124   nose_right_shoulder  dx RMS                         float64
#  125   nose_right_shoulder  dx MAV                         float64
#  126   noseright_shoulder  dy mean_ft                      float64
#  127   noseright_shoulder  dy std_ft                       float64
#  128   noseright_shoulder  dy max_ft                       float64
#  129   noseright_shoulder  dy min_ft                       float64
#  130   noseright_shoulder  dy var_ft                       float64
#  131   noseright_shoulder  dy med_ft                       float64
#  132   noseright_shoulder  dy sum_ft                       float64
#  133   noseright_shoulder  dy std                          float64
#  134   noseright_shoulder  dy kurtosis                     float64
#  135   noseright_shoulder  dy skew                         float64
#  136   noseright_shoulder  dy quantile 25                  float64
#  137   noseright_shoulder  dy quantile 75                  float64
#  138   noseright_shoulder  dy RMS                          float64
#  139   noseright_shoulder  dy MAV                          float64
#  140   left_eye_right_shoulder  dx mean_ft                 float64
#  141   left_eye_right_shoulder  dx std_ft                  float64
#  142   left_eye_right_shoulder  dx max_ft                  float64
#  143   left_eye_right_shoulder  dx min_ft                  float64
#  144   left_eye_right_shoulder  dx var_ft                  float64
#  145   left_eye_right_shoulder  dx med_ft                  float64
#  146   left_eye_right_shoulder  dx sum_ft                  float64
#  147   left_eye_right_shoulder  dx std                     float64
#  148   left_eye_right_shoulder  dx kurtosis                float64
#  149   left_eye_right_shoulder  dx skew                    float64
#  150   left_eye_right_shoulder  dx quantile 25             float64
#  151   left_eye_right_shoulder  dx quantile 75             float64
#  152   left_eye_right_shoulder  dx RMS                     float64
#  153   left_eye_right_shoulder  dx MAV                     float64
#  154   left_eyeright_shoulder  dy mean_ft                  float64
#  155   left_eyeright_shoulder  dy std_ft                   float64
#  156   left_eyeright_shoulder  dy max_ft                   float64
#  157   left_eyeright_shoulder  dy min_ft                   float64
#  158   left_eyeright_shoulder  dy var_ft                   float64
#  159   left_eyeright_shoulder  dy med_ft                   float64
#  160   left_eyeright_shoulder  dy sum_ft                   float64
#  161   left_eyeright_shoulder  dy std                      float64
#  162   left_eyeright_shoulder  dy kurtosis                 float64
#  163   left_eyeright_shoulder  dy skew                     float64
#  164   left_eyeright_shoulder  dy quantile 25              float64
#  165   left_eyeright_shoulder  dy quantile 75              float64
#  166   left_eyeright_shoulder  dy RMS                      float64
#  167   left_eyeright_shoulder  dy MAV                      float64
#  168   right_eye_right_shoulder  dx mean_ft                float64
#  169   right_eye_right_shoulder  dx std_ft                 float64
#  170   right_eye_right_shoulder  dx max_ft                 float64
#  171   right_eye_right_shoulder  dx min_ft                 float64
#  172   right_eye_right_shoulder  dx var_ft                 float64
#  173   right_eye_right_shoulder  dx med_ft                 float64
#  174   right_eye_right_shoulder  dx sum_ft                 float64
#  175   right_eye_right_shoulder  dx std                    float64
#  176   right_eye_right_shoulder  dx kurtosis               float64
#  177   right_eye_right_shoulder  dx skew                   float64
#  178   right_eye_right_shoulder  dx quantile 25            float64
#  179   right_eye_right_shoulder  dx quantile 75            float64
#  180   right_eye_right_shoulder  dx RMS                    float64
#  181   right_eye_right_shoulder  dx MAV                    float64
#  182   right_eyeright_shoulder  dy mean_ft                 float64
#  183   right_eyeright_shoulder  dy std_ft                  float64
#  184   right_eyeright_shoulder  dy max_ft                  float64
#  185   right_eyeright_shoulder  dy min_ft                  float64
#  186   right_eyeright_shoulder  dy var_ft                  float64
#  187   right_eyeright_shoulder  dy med_ft                  float64
#  188   right_eyeright_shoulder  dy sum_ft                  float64
#  189   right_eyeright_shoulder  dy std                     float64
#  190   right_eyeright_shoulder  dy kurtosis                float64
#  191   right_eyeright_shoulder  dy skew                    float64
#  192   right_eyeright_shoulder  dy quantile 25             float64
#  193   right_eyeright_shoulder  dy quantile 75             float64
#  194   right_eyeright_shoulder  dy RMS                     float64
#  195   right_eyeright_shoulder  dy MAV                     float64
#  196   left_ear_right_shoulder  dx mean_ft                 float64
#  197   left_ear_right_shoulder  dx std_ft                  float64
#  198   left_ear_right_shoulder  dx max_ft                  float64
#  199   left_ear_right_shoulder  dx min_ft                  float64
#  200   left_ear_right_shoulder  dx var_ft                  float64
#  201   left_ear_right_shoulder  dx med_ft                  float64
#  202   left_ear_right_shoulder  dx sum_ft                  float64
#  203   left_ear_right_shoulder  dx std                     float64
#  204   left_ear_right_shoulder  dx kurtosis                float64
#  205   left_ear_right_shoulder  dx skew                    float64
#  206   left_ear_right_shoulder  dx quantile 25             float64
#  207   left_ear_right_shoulder  dx quantile 75             float64
#  208   left_ear_right_shoulder  dx RMS                     float64
#  209   left_ear_right_shoulder  dx MAV                     float64
#  210   left_earright_shoulder  dy mean_ft                  float64
#  211   left_earright_shoulder  dy std_ft                   float64
#  212   left_earright_shoulder  dy max_ft                   float64
#  213   left_earright_shoulder  dy min_ft                   float64
#  214   left_earright_shoulder  dy var_ft                   float64
#  215   left_earright_shoulder  dy med_ft                   float64
#  216   left_earright_shoulder  dy sum_ft                   float64
#  217   left_earright_shoulder  dy std                      float64
#  218   left_earright_shoulder  dy kurtosis                 float64
#  219   left_earright_shoulder  dy skew                     float64
#  220   left_earright_shoulder  dy quantile 25              float64
#  221   left_earright_shoulder  dy quantile 75              float64
#  222   left_earright_shoulder  dy RMS                      float64
#  223   left_earright_shoulder  dy MAV                      float64
#  224   right_ear_right_shoulder  dx mean_ft                float64
#  225   right_ear_right_shoulder  dx std_ft                 float64
#  226   right_ear_right_shoulder  dx max_ft                 float64
#  227   right_ear_right_shoulder  dx min_ft                 float64
#  228   right_ear_right_shoulder  dx var_ft                 float64
#  229   right_ear_right_shoulder  dx med_ft                 float64
#  230   right_ear_right_shoulder  dx sum_ft                 float64
#  231   right_ear_right_shoulder  dx std                    float64
#  232   right_ear_right_shoulder  dx kurtosis               float64
#  233   right_ear_right_shoulder  dx skew                   float64
#  234   right_ear_right_shoulder  dx quantile 25            float64
#  235   right_ear_right_shoulder  dx quantile 75            float64
#  236   right_ear_right_shoulder  dx RMS                    float64
#  237   right_ear_right_shoulder  dx MAV                    float64
#  238   right_earright_shoulder  dy mean_ft                 float64
#  239   right_earright_shoulder  dy std_ft                  float64
#  240   right_earright_shoulder  dy max_ft                  float64
#  241   right_earright_shoulder  dy min_ft                  float64
#  242   right_earright_shoulder  dy var_ft                  float64
#  243   right_earright_shoulder  dy med_ft                  float64
#  244   right_earright_shoulder  dy sum_ft                  float64
#  245   right_earright_shoulder  dy std                     float64
#  246   right_earright_shoulder  dy kurtosis                float64
#  247   right_earright_shoulder  dy skew                    float64
#  248   right_earright_shoulder  dy quantile 25             float64
#  249   right_earright_shoulder  dy quantile 75             float64
#  250   right_earright_shoulder  dy RMS                     float64
#  251   right_earright_shoulder  dy MAV                     float64
#  252   left_shoulder_right_shoulder  dx mean_ft            float64
#  253   left_shoulder_right_shoulder  dx std_ft             float64
#  254   left_shoulder_right_shoulder  dx max_ft             float64
#  255   left_shoulder_right_shoulder  dx min_ft             float64
#  256   left_shoulder_right_shoulder  dx var_ft             float64
#  257   left_shoulder_right_shoulder  dx med_ft             float64
#  258   left_shoulder_right_shoulder  dx sum_ft             float64
#  259   left_shoulder_right_shoulder  dx std                float64
#  260   left_shoulder_right_shoulder  dx kurtosis           float64
#  261   left_shoulder_right_shoulder  dx skew               float64
#  262   left_shoulder_right_shoulder  dx quantile 25        float64
#  263   left_shoulder_right_shoulder  dx quantile 75        float64
#  264   left_shoulder_right_shoulder  dx RMS                float64
#  265   left_shoulder_right_shoulder  dx MAV                float64
#  266   left_shoulderright_shoulder  dy mean_ft             float64
#  267   left_shoulderright_shoulder  dy std_ft              float64
#  268   left_shoulderright_shoulder  dy max_ft              float64
#  269   left_shoulderright_shoulder  dy min_ft              float64
#  270   left_shoulderright_shoulder  dy var_ft              float64
#  271   left_shoulderright_shoulder  dy med_ft              float64
#  272   left_shoulderright_shoulder  dy sum_ft              float64
#  273   left_shoulderright_shoulder  dy std                 float64
#  274   left_shoulderright_shoulder  dy kurtosis            float64
#  275   left_shoulderright_shoulder  dy skew                float64
#  276   left_shoulderright_shoulder  dy quantile 25         float64
#  277   left_shoulderright_shoulder  dy quantile 75         float64
#  278   left_shoulderright_shoulder  dy RMS                 float64
#  279   left_shoulderright_shoulder  dy MAV                 float64
#  280   left_elbow_right_shoulder  dx mean_ft               float64
#  281   left_elbow_right_shoulder  dx std_ft                float64
#  282   left_elbow_right_shoulder  dx max_ft                float64
#  283   left_elbow_right_shoulder  dx min_ft                float64
#  284   left_elbow_right_shoulder  dx var_ft                float64
#  285   left_elbow_right_shoulder  dx med_ft                float64
#  286   left_elbow_right_shoulder  dx sum_ft                float64
#  287   left_elbow_right_shoulder  dx std                   float64
#  288   left_elbow_right_shoulder  dx kurtosis              float64
#  289   left_elbow_right_shoulder  dx skew                  float64
#  290   left_elbow_right_shoulder  dx quantile 25           float64
#  291   left_elbow_right_shoulder  dx quantile 75           float64
#  292   left_elbow_right_shoulder  dx RMS                   float64
#  293   left_elbow_right_shoulder  dx MAV                   float64
#  294   left_elbowright_shoulder  dy mean_ft                float64
#  295   left_elbowright_shoulder  dy std_ft                 float64
#  296   left_elbowright_shoulder  dy max_ft                 float64
#  297   left_elbowright_shoulder  dy min_ft                 float64
#  298   left_elbowright_shoulder  dy var_ft                 float64
#  299   left_elbowright_shoulder  dy med_ft                 float64
#  300   left_elbowright_shoulder  dy sum_ft                 float64
#  301   left_elbowright_shoulder  dy std                    float64
#  302   left_elbowright_shoulder  dy kurtosis               float64
#  303   left_elbowright_shoulder  dy skew                   float64
#  304   left_elbowright_shoulder  dy quantile 25            float64
#  305   left_elbowright_shoulder  dy quantile 75            float64
#  306   left_elbowright_shoulder  dy RMS                    float64
#  307   left_elbowright_shoulder  dy MAV                    float64
#  308   right_elbow_right_shoulder  dx mean_ft              float64
#  309   right_elbow_right_shoulder  dx std_ft               float64
#  310   right_elbow_right_shoulder  dx max_ft               float64
#  311   right_elbow_right_shoulder  dx min_ft               float64
#  312   right_elbow_right_shoulder  dx var_ft               float64
#  313   right_elbow_right_shoulder  dx med_ft               float64
#  314   right_elbow_right_shoulder  dx sum_ft               float64
#  315   right_elbow_right_shoulder  dx std                  float64
#  316   right_elbow_right_shoulder  dx kurtosis             float64
#  317   right_elbow_right_shoulder  dx skew                 float64
#  318   right_elbow_right_shoulder  dx quantile 25          float64
#  319   right_elbow_right_shoulder  dx quantile 75          float64
#  320   right_elbow_right_shoulder  dx RMS                  float64
#  321   right_elbow_right_shoulder  dx MAV                  float64
#  322   right_elbowright_shoulder  dy mean_ft               float64
#  323   right_elbowright_shoulder  dy std_ft                float64
#  324   right_elbowright_shoulder  dy max_ft                float64
#  325   right_elbowright_shoulder  dy min_ft                float64
#  326   right_elbowright_shoulder  dy var_ft                float64
#  327   right_elbowright_shoulder  dy med_ft                float64
#  328   right_elbowright_shoulder  dy sum_ft                float64
#  329   right_elbowright_shoulder  dy std                   float64
#  330   right_elbowright_shoulder  dy kurtosis              float64
#  331   right_elbowright_shoulder  dy skew                  float64
#  332   right_elbowright_shoulder  dy quantile 25           float64
#  333   right_elbowright_shoulder  dy quantile 75           float64
#  334   right_elbowright_shoulder  dy RMS                   float64
#  335   right_elbowright_shoulder  dy MAV                   float64
#  336   left_wrist_right_shoulder  dx mean_ft               float64
#  337   left_wrist_right_shoulder  dx std_ft                float64
#  338   left_wrist_right_shoulder  dx max_ft                float64
#  339   left_wrist_right_shoulder  dx min_ft                float64
#  340   left_wrist_right_shoulder  dx var_ft                float64
#  341   left_wrist_right_shoulder  dx med_ft                float64
#  342   left_wrist_right_shoulder  dx sum_ft                float64
#  343   left_wrist_right_shoulder  dx std                   float64
#  344   left_wrist_right_shoulder  dx kurtosis              float64
#  345   left_wrist_right_shoulder  dx skew                  float64
#  346   left_wrist_right_shoulder  dx quantile 25           float64
#  347   left_wrist_right_shoulder  dx quantile 75           float64
#  348   left_wrist_right_shoulder  dx RMS                   float64
#  349   left_wrist_right_shoulder  dx MAV                   float64
#  350   left_wristright_shoulder  dy mean_ft                float64
#  351   left_wristright_shoulder  dy std_ft                 float64
#  352   left_wristright_shoulder  dy max_ft                 float64
#  353   left_wristright_shoulder  dy min_ft                 float64
#  354   left_wristright_shoulder  dy var_ft                 float64
#  355   left_wristright_shoulder  dy med_ft                 float64
#  356   left_wristright_shoulder  dy sum_ft                 float64
#  357   left_wristright_shoulder  dy std                    float64
#  358   left_wristright_shoulder  dy kurtosis               float64
#  359   left_wristright_shoulder  dy skew                   float64
#  360   left_wristright_shoulder  dy quantile 25            float64
#  361   left_wristright_shoulder  dy quantile 75            float64
#  362   left_wristright_shoulder  dy RMS                    float64
#  363   left_wristright_shoulder  dy MAV                    float64
#  364   right_wrist_right_shoulder  dx mean_ft              float64
#  365   right_wrist_right_shoulder  dx std_ft               float64
#  366   right_wrist_right_shoulder  dx max_ft               float64
#  367   right_wrist_right_shoulder  dx min_ft               float64
#  368   right_wrist_right_shoulder  dx var_ft               float64
#  369   right_wrist_right_shoulder  dx med_ft               float64
#  370   right_wrist_right_shoulder  dx sum_ft               float64
#  371   right_wrist_right_shoulder  dx std                  float64
#  372   right_wrist_right_shoulder  dx kurtosis             float64
#  373   right_wrist_right_shoulder  dx skew                 float64
#  374   right_wrist_right_shoulder  dx quantile 25          float64
#  375   right_wrist_right_shoulder  dx quantile 75          float64
#  376   right_wrist_right_shoulder  dx RMS                  float64
#  377   right_wrist_right_shoulder  dx MAV                  float64
#  378   right_wristright_shoulder  dy mean_ft               float64
#  379   right_wristright_shoulder  dy std_ft                float64
#  380   right_wristright_shoulder  dy max_ft                float64
#  381   right_wristright_shoulder  dy min_ft                float64
#  382   right_wristright_shoulder  dy var_ft                float64
#  383   right_wristright_shoulder  dy med_ft                float64
#  384   right_wristright_shoulder  dy sum_ft                float64
#  385   right_wristright_shoulder  dy std                   float64
#  386   right_wristright_shoulder  dy kurtosis              float64
#  387   right_wristright_shoulder  dy skew                  float64
#  388   right_wristright_shoulder  dy quantile 25           float64
#  389   right_wristright_shoulder  dy quantile 75           float64
#  390   right_wristright_shoulder  dy RMS                   float64
#  391   right_wristright_shoulder  dy MAV                   float64
#  392   left_hip_right_shoulder  dx mean_ft                 float64
#  393   left_hip_right_shoulder  dx std_ft                  float64
#  394   left_hip_right_shoulder  dx max_ft                  float64
#  395   left_hip_right_shoulder  dx min_ft                  float64
#  396   left_hip_right_shoulder  dx var_ft                  float64
#  397   left_hip_right_shoulder  dx med_ft                  float64
#  398   left_hip_right_shoulder  dx sum_ft                  float64
#  399   left_hip_right_shoulder  dx std                     float64
#  400   left_hip_right_shoulder  dx kurtosis                float64
#  401   left_hip_right_shoulder  dx skew                    float64
#  402   left_hip_right_shoulder  dx quantile 25             float64
#  403   left_hip_right_shoulder  dx quantile 75             float64
#  404   left_hip_right_shoulder  dx RMS                     float64
#  405   left_hip_right_shoulder  dx MAV                     float64
#  406   left_hipright_shoulder  dy mean_ft                  float64
#  407   left_hipright_shoulder  dy std_ft                   float64
#  408   left_hipright_shoulder  dy max_ft                   float64
#  409   left_hipright_shoulder  dy min_ft                   float64
#  410   left_hipright_shoulder  dy var_ft                   float64
#  411   left_hipright_shoulder  dy med_ft                   float64
#  412   left_hipright_shoulder  dy sum_ft                   float64
#  413   left_hipright_shoulder  dy std                      float64
#  414   left_hipright_shoulder  dy kurtosis                 float64
#  415   left_hipright_shoulder  dy skew                     float64
#  416   left_hipright_shoulder  dy quantile 25              float64
#  417   left_hipright_shoulder  dy quantile 75              float64
#  418   left_hipright_shoulder  dy RMS                      float64
#  419   left_hipright_shoulder  dy MAV                      float64
#  420   right_hip_right_shoulder  dx mean_ft                float64
#  421   right_hip_right_shoulder  dx std_ft                 float64
#  422   right_hip_right_shoulder  dx max_ft                 float64
#  423   right_hip_right_shoulder  dx min_ft                 float64
#  424   right_hip_right_shoulder  dx var_ft                 float64
#  425   right_hip_right_shoulder  dx med_ft                 float64
#  426   right_hip_right_shoulder  dx sum_ft                 float64
#  427   right_hip_right_shoulder  dx std                    float64
#  428   right_hip_right_shoulder  dx kurtosis               float64
#  429   right_hip_right_shoulder  dx skew                   float64
#  430   right_hip_right_shoulder  dx quantile 25            float64
#  431   right_hip_right_shoulder  dx quantile 75            float64
#  432   right_hip_right_shoulder  dx RMS                    float64
#  433   right_hip_right_shoulder  dx MAV                    float64
#  434   right_hipright_shoulder  dy mean_ft                 float64
#  435   right_hipright_shoulder  dy std_ft                  float64
#  436   right_hipright_shoulder  dy max_ft                  float64
#  437   right_hipright_shoulder  dy min_ft                  float64
#  438   right_hipright_shoulder  dy var_ft                  float64
#  439   right_hipright_shoulder  dy med_ft                  float64
#  440   right_hipright_shoulder  dy sum_ft                  float64
#  441   right_hipright_shoulder  dy std                     float64
#  442   right_hipright_shoulder  dy kurtosis                float64
#  443   right_hipright_shoulder  dy skew                    float64
#  444   right_hipright_shoulder  dy quantile 25             float64
#  445   right_hipright_shoulder  dy quantile 75             float64
#  446   right_hipright_shoulder  dy RMS                     float64
#  447   right_hipright_shoulder  dy MAV                     float64
#  448   nose_ mean_ft                                       float64
#  449   nose_ std_ft                                        float64
#  450   nose_ max_ft                                        float64
#  451   nose_ min_ft                                        float64
#  452   nose_ var_ft                                        float64
#  453   nose_ med_ft                                        float64
#  454   nose_ sum_ft                                        float64
#  455   nose_ std                                           float64
#  456   nose_ kurtosis                                      float64
#  457   nose_ skew                                          float64
#  458   nose_ quantile 25                                   float64
#  459   nose_ quantile 75                                   float64
#  460   nose_ RMS                                           float64
#  461   nose_ MAV                                           float64
#  462   nose mean_ft                                        float64
#  463   nose std_ft                                         float64
#  464   nose max_ft                                         float64
#  465   nose min_ft                                         float64
#  466   nose var_ft                                         float64
#  467   nose med_ft                                         float64
#  468   nose sum_ft                                         float64
#  469   nose std                                            float64
#  470   nose kurtosis                                       float64
#  471   nose skew                                           float64
#  472   nose quantile 25                                    float64
#  473   nose quantile 75                                    float64
#  474   nose RMS                                            float64
#  475   nose MAV                                            float64
#  476   left_eye_ mean_ft                                   float64
#  477   left_eye_ std_ft                                    float64
#  478   left_eye_ max_ft                                    float64
#  479   left_eye_ min_ft                                    float64
#  480   left_eye_ var_ft                                    float64
#  481   left_eye_ med_ft                                    float64
#  482   left_eye_ sum_ft                                    float64
#  483   left_eye_ std                                       float64
#  484   left_eye_ kurtosis                                  float64
#  485   left_eye_ skew                                      float64
#  486   left_eye_ quantile 25                               float64
#  487   left_eye_ quantile 75                               float64
#  488   left_eye_ RMS                                       float64
#  489   left_eye_ MAV                                       float64
#  490   left_eye mean_ft                                    float64
#  491   left_eye std_ft                                     float64
#  492   left_eye max_ft                                     float64
#  493   left_eye min_ft                                     float64
#  494   left_eye var_ft                                     float64
#  495   left_eye med_ft                                     float64
#  496   left_eye sum_ft                                     float64
#  497   left_eye std                                        float64
#  498   left_eye kurtosis                                   float64
#  499   left_eye skew                                       float64
#  500   left_eye quantile 25                                float64
#  501   left_eye quantile 75                                float64
#  502   left_eye RMS                                        float64
#  503   left_eye MAV                                        float64
#  504   right_eye_ mean_ft                                  float64
#  505   right_eye_ std_ft                                   float64
#  506   right_eye_ max_ft                                   float64
#  507   right_eye_ min_ft                                   float64
#  508   right_eye_ var_ft                                   float64
#  509   right_eye_ med_ft                                   float64
#  510   right_eye_ sum_ft                                   float64
#  511   right_eye_ std                                      float64
#  512   right_eye_ kurtosis                                 float64
#  513   right_eye_ skew                                     float64
#  514   right_eye_ quantile 25                              float64
#  515   right_eye_ quantile 75                              float64
#  516   right_eye_ RMS                                      float64
#  517   right_eye_ MAV                                      float64
#  518   right_eye mean_ft                                   float64
#  519   right_eye std_ft                                    float64
#  520   right_eye max_ft                                    float64
#  521   right_eye min_ft                                    float64
#  522   right_eye var_ft                                    float64
#  523   right_eye med_ft                                    float64
#  524   right_eye sum_ft                                    float64
#  525   right_eye std                                       float64
#  526   right_eye kurtosis                                  float64
#  527   right_eye skew                                      float64
#  528   right_eye quantile 25                               float64
#  529   right_eye quantile 75                               float64
#  530   right_eye RMS                                       float64
#  531   right_eye MAV                                       float64
#  532   left_ear_ mean_ft                                   float64
#  533   left_ear_ std_ft                                    float64
#  534   left_ear_ max_ft                                    float64
#  535   left_ear_ min_ft                                    float64
#  536   left_ear_ var_ft                                    float64
#  537   left_ear_ med_ft                                    float64
#  538   left_ear_ sum_ft                                    float64
#  539   left_ear_ std                                       float64
#  540   left_ear_ kurtosis                                  float64
#  541   left_ear_ skew                                      float64
#  542   left_ear_ quantile 25                               float64
#  543   left_ear_ quantile 75                               float64
#  544   left_ear_ RMS                                       float64
#  545   left_ear_ MAV                                       float64
#  546   left_ear mean_ft                                    float64
#  547   left_ear std_ft                                     float64
#  548   left_ear max_ft                                     float64
#  549   left_ear min_ft                                     float64
#  550   left_ear var_ft                                     float64
#  551   left_ear med_ft                                     float64
#  552   left_ear sum_ft                                     float64
#  553   left_ear std                                        float64
#  554   left_ear kurtosis                                   float64
#  555   left_ear skew                                       float64
#  556   left_ear quantile 25                                float64
#  557   left_ear quantile 75                                float64
#  558   left_ear RMS                                        float64
#  559   left_ear MAV                                        float64
#  560   right_ear_ mean_ft                                  float64
#  561   right_ear_ std_ft                                   float64
#  562   right_ear_ max_ft                                   float64
#  563   right_ear_ min_ft                                   float64
#  564   right_ear_ var_ft                                   float64
#  565   right_ear_ med_ft                                   float64
#  566   right_ear_ sum_ft                                   float64
#  567   right_ear_ std                                      float64
#  568   right_ear_ kurtosis                                 float64
#  569   right_ear_ skew                                     float64
#  570   right_ear_ quantile 25                              float64
#  571   right_ear_ quantile 75                              float64
#  572   right_ear_ RMS                                      float64
#  573   right_ear_ MAV                                      float64
#  574   right_ear mean_ft                                   float64
#  575   right_ear std_ft                                    float64
#  576   right_ear max_ft                                    float64
#  577   right_ear min_ft                                    float64
#  578   right_ear var_ft                                    float64
#  579   right_ear med_ft                                    float64
#  580   right_ear sum_ft                                    float64
#  581   right_ear std                                       float64
#  582   right_ear kurtosis                                  float64
#  583   right_ear skew                                      float64
#  584   right_ear quantile 25                               float64
#  585   right_ear quantile 75                               float64
#  586   right_ear RMS                                       float64
#  587   right_ear MAV                                       float64
#  588   left_shoulder_ mean_ft                              float64
#  589   left_shoulder_ std_ft                               float64
#  590   left_shoulder_ max_ft                               float64
#  591   left_shoulder_ min_ft                               float64
#  592   left_shoulder_ var_ft                               float64
#  593   left_shoulder_ med_ft                               float64
#  594   left_shoulder_ sum_ft                               float64
#  595   left_shoulder_ std                                  float64
#  596   left_shoulder_ kurtosis                             float64
#  597   left_shoulder_ skew                                 float64
#  598   left_shoulder_ quantile 25                          float64
#  599   left_shoulder_ quantile 75                          float64
#  600   left_shoulder_ RMS                                  float64
#  601   left_shoulder_ MAV                                  float64
#  602   left_shoulder mean_ft                               float64
#  603   left_shoulder std_ft                                float64
#  604   left_shoulder max_ft                                float64
#  605   left_shoulder min_ft                                float64
#  606   left_shoulder var_ft                                float64
#  607   left_shoulder med_ft                                float64
#  608   left_shoulder sum_ft                                float64
#  609   left_shoulder std                                   float64
#  610   left_shoulder kurtosis                              float64
#  611   left_shoulder skew                                  float64
#  612   left_shoulder quantile 25                           float64
#  613   left_shoulder quantile 75                           float64
#  614   left_shoulder RMS                                   float64
#  615   left_shoulder MAV                                   float64
#  616   left_elbow_ mean_ft                                 float64
#  617   left_elbow_ std_ft                                  float64
#  618   left_elbow_ max_ft                                  float64
#  619   left_elbow_ min_ft                                  float64
#  620   left_elbow_ var_ft                                  float64
#  621   left_elbow_ med_ft                                  float64
#  622   left_elbow_ sum_ft                                  float64
#  623   left_elbow_ std                                     float64
#  624   left_elbow_ kurtosis                                float64
#  625   left_elbow_ skew                                    float64
#  626   left_elbow_ quantile 25                             float64
#  627   left_elbow_ quantile 75                             float64
#  628   left_elbow_ RMS                                     float64
#  629   left_elbow_ MAV                                     float64
#  630   left_elbow mean_ft                                  float64
#  631   left_elbow std_ft                                   float64
#  632   left_elbow max_ft                                   float64
#  633   left_elbow min_ft                                   float64
#  634   left_elbow var_ft                                   float64
#  635   left_elbow med_ft                                   float64
#  636   left_elbow sum_ft                                   float64
#  637   left_elbow std                                      float64
#  638   left_elbow kurtosis                                 float64
#  639   left_elbow skew                                     float64
#  640   left_elbow quantile 25                              float64
#  641   left_elbow quantile 75                              float64
#  642   left_elbow RMS                                      float64
#  643   left_elbow MAV                                      float64
#  644   right_elbow_ mean_ft                                float64
#  645   right_elbow_ std_ft                                 float64
#  646   right_elbow_ max_ft                                 float64
#  647   right_elbow_ min_ft                                 float64
#  648   right_elbow_ var_ft                                 float64
#  649   right_elbow_ med_ft                                 float64
#  650   right_elbow_ sum_ft                                 float64
#  651   right_elbow_ std                                    float64
#  652   right_elbow_ kurtosis                               float64
#  653   right_elbow_ skew                                   float64
#  654   right_elbow_ quantile 25                            float64
#  655   right_elbow_ quantile 75                            float64
#  656   right_elbow_ RMS                                    float64
#  657   right_elbow_ MAV                                    float64
#  658   right_elbow mean_ft                                 float64
#  659   right_elbow std_ft                                  float64
#  660   right_elbow max_ft                                  float64
#  661   right_elbow min_ft                                  float64
#  662   right_elbow var_ft                                  float64
#  663   right_elbow med_ft                                  float64
#  664   right_elbow sum_ft                                  float64
#  665   right_elbow std                                     float64
#  666   right_elbow kurtosis                                float64
#  667   right_elbow skew                                    float64
#  668   right_elbow quantile 25                             float64
#  669   right_elbow quantile 75                             float64
#  670   right_elbow RMS                                     float64
#  671   right_elbow MAV                                     float64
#  672   left_wrist_ mean_ft                                 float64
#  673   left_wrist_ std_ft                                  float64
#  674   left_wrist_ max_ft                                  float64
#  675   left_wrist_ min_ft                                  float64
#  676   left_wrist_ var_ft                                  float64
#  677   left_wrist_ med_ft                                  float64
#  678   left_wrist_ sum_ft                                  float64
#  679   left_wrist_ std                                     float64
#  680   left_wrist_ kurtosis                                float64
#  681   left_wrist_ skew                                    float64
#  682   left_wrist_ quantile 25                             float64
#  683   left_wrist_ quantile 75                             float64
#  684   left_wrist_ RMS                                     float64
#  685   left_wrist_ MAV                                     float64
#  686   left_wrist mean_ft                                  float64
#  687   left_wrist std_ft                                   float64
#  688   left_wrist max_ft                                   float64
#  689   left_wrist min_ft                                   float64
#  690   left_wrist var_ft                                   float64
#  691   left_wrist med_ft                                   float64
#  692   left_wrist sum_ft                                   float64
#  693   left_wrist std                                      float64
#  694   left_wrist kurtosis                                 float64
#  695   left_wrist skew                                     float64
#  696   left_wrist quantile 25                              float64
#  697   left_wrist quantile 75                              float64
#  698   left_wrist RMS                                      float64
#  699   left_wrist MAV                                      float64
#  700   right_wrist_ mean_ft                                float64
#  701   right_wrist_ std_ft                                 float64
# ...
#  2764  movingright_ear sum_ft                              float64
#  2765  movingright_ear std                                 float64
#  2766  movingright_ear kurtosis                            float64
#  2767  movingright_ear skew                                float64
#  2768  movingright_ear quantile 25                         float64
#  2769  movingright_ear quantile 75                         float64
#  2770  movingright_ear RMS                                 float64
#  2771  movingright_ear MAV                                 float64
#  2772  movingleft_shoulder_ mean_ft                        float64
#  2773  movingleft_shoulder_ std_ft                         float64
#  2774  movingleft_shoulder_ max_ft                         float64
#  2775  movingleft_shoulder_ min_ft                         float64
#  2776  movingleft_shoulder_ var_ft                         float64
#  2777  movingleft_shoulder_ med_ft                         float64
#  2778  movingleft_shoulder_ sum_ft                         float64
#  2779  movingleft_shoulder_ std                            float64
#  2780  movingleft_shoulder_ kurtosis                       float64
#  2781  movingleft_shoulder_ skew                           float64
#  2782  movingleft_shoulder_ quantile 25                    float64
#  2783  movingleft_shoulder_ quantile 75                    float64
#  2784  movingleft_shoulder_ RMS                            float64
#  2785  movingleft_shoulder_ MAV                            float64
#  2786  movingleft_shoulder mean_ft                         float64
#  2787  movingleft_shoulder std_ft                          float64
#  2788  movingleft_shoulder max_ft                          float64
#  2789  movingleft_shoulder min_ft                          float64
#  2790  movingleft_shoulder var_ft                          float64
#  2791  movingleft_shoulder med_ft                          float64
#  2792  movingleft_shoulder sum_ft                          float64
#  2793  movingleft_shoulder std                             float64
#  2794  movingleft_shoulder kurtosis                        float64
#  2795  movingleft_shoulder skew                            float64
#  2796  movingleft_shoulder quantile 25                     float64
#  2797  movingleft_shoulder quantile 75                     float64
#  2798  movingleft_shoulder RMS                             float64
#  2799  movingleft_shoulder MAV                             float64
#  2800  movingleft_elbow_ mean_ft                           float64
#  2801  movingleft_elbow_ std_ft                            float64
#  2802  movingleft_elbow_ max_ft                            float64
#  2803  movingleft_elbow_ min_ft                            float64
#  2804  movingleft_elbow_ var_ft                            float64
#  2805  movingleft_elbow_ med_ft                            float64
#  2806  movingleft_elbow_ sum_ft                            float64
#  2807  movingleft_elbow_ std                               float64
#  2808  movingleft_elbow_ kurtosis                          float64
#  2809  movingleft_elbow_ skew                              float64
#  2810  movingleft_elbow_ quantile 25                       float64
#  2811  movingleft_elbow_ quantile 75                       float64
#  2812  movingleft_elbow_ RMS                               float64
#  2813  movingleft_elbow_ MAV                               float64
#  2814  movingleft_elbow mean_ft                            float64
#  2815  movingleft_elbow std_ft                             float64
#  2816  movingleft_elbow max_ft                             float64
#  2817  movingleft_elbow min_ft                             float64
#  2818  movingleft_elbow var_ft                             float64
#  2819  movingleft_elbow med_ft                             float64
#  2820  movingleft_elbow sum_ft                             float64
#  2821  movingleft_elbow std                                float64
#  2822  movingleft_elbow kurtosis                           float64
#  2823  movingleft_elbow skew                               float64
#  2824  movingleft_elbow quantile 25                        float64
#  2825  movingleft_elbow quantile 75                        float64
#  2826  movingleft_elbow RMS                                float64
#  2827  movingleft_elbow MAV                                float64
#  2828  movingright_elbow_ mean_ft                          float64
#  2829  movingright_elbow_ std_ft                           float64
#  2830  movingright_elbow_ max_ft                           float64
#  2831  movingright_elbow_ min_ft                           float64
#  2832  movingright_elbow_ var_ft                           float64
#  2833  movingright_elbow_ med_ft                           float64
#  2834  movingright_elbow_ sum_ft                           float64
#  2835  movingright_elbow_ std                              float64
#  2836  movingright_elbow_ kurtosis                         float64
#  2837  movingright_elbow_ skew                             float64
#  2838  movingright_elbow_ quantile 25                      float64
#  2839  movingright_elbow_ quantile 75                      float64
#  2840  movingright_elbow_ RMS                              float64
#  2841  movingright_elbow_ MAV                              float64
#  2842  movingright_elbow mean_ft                           float64
#  2843  movingright_elbow std_ft                            float64
#  2844  movingright_elbow max_ft                            float64
#  2845  movingright_elbow min_ft                            float64
#  2846  movingright_elbow var_ft                            float64
#  2847  movingright_elbow med_ft                            float64
#  2848  movingright_elbow sum_ft                            float64
#  2849  movingright_elbow std                               float64
#  2850  movingright_elbow kurtosis                          float64
#  2851  movingright_elbow skew                              float64
#  2852  movingright_elbow quantile 25                       float64
#  2853  movingright_elbow quantile 75                       float64
#  2854  movingright_elbow RMS                               float64
#  2855  movingright_elbow MAV                               float64
#  2856  movingleft_wrist_ mean_ft                           float64
#  2857  movingleft_wrist_ std_ft                            float64
#  2858  movingleft_wrist_ max_ft                            float64
#  2859  movingleft_wrist_ min_ft                            float64
#  2860  movingleft_wrist_ var_ft                            float64
#  2861  movingleft_wrist_ med_ft                            float64
#  2862  movingleft_wrist_ sum_ft                            float64
#  2863  movingleft_wrist_ std                               float64
#  2864  movingleft_wrist_ kurtosis                          float64
#  2865  movingleft_wrist_ skew                              float64
#  2866  movingleft_wrist_ quantile 25                       float64
#  2867  movingleft_wrist_ quantile 75                       float64
#  2868  movingleft_wrist_ RMS                               float64
#  2869  movingleft_wrist_ MAV                               float64
#  2870  movingleft_wrist mean_ft                            float64
#  2871  movingleft_wrist std_ft                             float64
#  2872  movingleft_wrist max_ft                             float64
#  2873  movingleft_wrist min_ft                             float64
#  2874  movingleft_wrist var_ft                             float64
#  2875  movingleft_wrist med_ft                             float64
#  2876  movingleft_wrist sum_ft                             float64
#  2877  movingleft_wrist std                                float64
#  2878  movingleft_wrist kurtosis                           float64
#  2879  movingleft_wrist skew                               float64
#  2880  movingleft_wrist quantile 25                        float64
#  2881  movingleft_wrist quantile 75                        float64
#  2882  movingleft_wrist RMS                                float64
#  2883  movingleft_wrist MAV                                float64
#  2884  movingright_wrist_ mean_ft                          float64
#  2885  movingright_wrist_ std_ft                           float64
#  2886  movingright_wrist_ max_ft                           float64
#  2887  movingright_wrist_ min_ft                           float64
#  2888  movingright_wrist_ var_ft                           float64
#  2889  movingright_wrist_ med_ft                           float64
#  2890  movingright_wrist_ sum_ft                           float64
#  2891  movingright_wrist_ std                              float64
#  2892  movingright_wrist_ kurtosis                         float64
#  2893  movingright_wrist_ skew                             float64
#  2894  movingright_wrist_ quantile 25                      float64
#  2895  movingright_wrist_ quantile 75                      float64
#  2896  movingright_wrist_ RMS                              float64
#  2897  movingright_wrist_ MAV                              float64
#  2898  movingright_wrist mean_ft                           float64
#  2899  movingright_wrist std_ft                            float64
#  2900  movingright_wrist max_ft                            float64
#  2901  movingright_wrist min_ft                            float64
#  2902  movingright_wrist var_ft                            float64
#  2903  movingright_wrist med_ft                            float64
#  2904  movingright_wrist sum_ft                            float64
#  2905  movingright_wrist std                               float64
#  2906  movingright_wrist kurtosis                          float64
#  2907  movingright_wrist skew                              float64
#  2908  movingright_wrist quantile 25                       float64
#  2909  movingright_wrist quantile 75                       float64
#  2910  movingright_wrist RMS                               float64
#  2911  movingright_wrist MAV                               float64
#  2912  movingleft_hip_ mean_ft                             float64
#  2913  movingleft_hip_ std_ft                              float64
#  2914  movingleft_hip_ max_ft                              float64
#  2915  movingleft_hip_ min_ft                              float64
#  2916  movingleft_hip_ var_ft                              float64
#  2917  movingleft_hip_ med_ft                              float64
#  2918  movingleft_hip_ sum_ft                              float64
#  2919  movingleft_hip_ std                                 float64
#  2920  movingleft_hip_ kurtosis                            float64
#  2921  movingleft_hip_ skew                                float64
#  2922  movingleft_hip_ quantile 25                         float64
#  2923  movingleft_hip_ quantile 75                         float64
#  2924  movingleft_hip_ RMS                                 float64
#  2925  movingleft_hip_ MAV                                 float64
#  2926  movingleft_hip mean_ft                              float64
#  2927  movingleft_hip std_ft                               float64
#  2928  movingleft_hip max_ft                               float64
#  2929  movingleft_hip min_ft                               float64
#  2930  movingleft_hip var_ft                               float64
#  2931  movingleft_hip med_ft                               float64
#  2932  movingleft_hip sum_ft                               float64
#  2933  movingleft_hip std                                  float64
#  2934  movingleft_hip kurtosis                             float64
#  2935  movingleft_hip skew                                 float64
#  2936  movingleft_hip quantile 25                          float64
#  2937  movingleft_hip quantile 75                          float64
#  2938  movingleft_hip RMS                                  float64
#  2939  movingleft_hip MAV                                  float64
#  2940  movingright_hip_ mean_ft                            float64
#  2941  movingright_hip_ std_ft                             float64
#  2942  movingright_hip_ max_ft                             float64
#  2943  movingright_hip_ min_ft                             float64
#  2944  movingright_hip_ var_ft                             float64
#  2945  movingright_hip_ med_ft                             float64
#  2946  movingright_hip_ sum_ft                             float64
#  2947  movingright_hip_ std                                float64
#  2948  movingright_hip_ kurtosis                           float64
#  2949  movingright_hip_ skew                               float64
#  2950  movingright_hip_ quantile 25                        float64
#  2951  movingright_hip_ quantile 75                        float64
#  2952  movingright_hip_ RMS                                float64
#  2953  movingright_hip_ MAV                                float64
#  2954  movingright_hip mean_ft                             float64
#  2955  movingright_hip std_ft                              float64
#  2956  movingright_hip max_ft                              float64
#  2957  movingright_hip min_ft                              float64
#  2958  movingright_hip var_ft                              float64
#  2959  movingright_hip med_ft                              float64
#  2960  movingright_hip sum_ft                              float64
#  2961  movingright_hip std                                 float64
#  2962  movingright_hip kurtosis                            float64
#  2963  movingright_hip skew                                float64
#  2964  movingright_hip quantile 25                         float64
#  2965  movingright_hip quantile 75                         float64
#  2966  movingright_hip RMS                                 float64
#  2967  movingright_hip MAV                                 float64
#  2968  movingcenter_x mean_ft                              float64
#  2969  movingcenter_x std_ft                               float64
#  2970  movingcenter_x max_ft                               float64
#  2971  movingcenter_x min_ft                               float64
#  2972  movingcenter_x var_ft                               float64
#  2973  movingcenter_x med_ft                               float64
#  2974  movingcenter_x sum_ft                               float64
#  2975  movingcenter_x std                                  float64
#  2976  movingcenter_x kurtosis                             float64
#  2977  movingcenter_x skew                                 float64
#  2978  movingcenter_x quantile 25                          float64
#  2979  movingcenter_x quantile 75                          float64
#  2980  movingcenter_x RMS                                  float64
#  2981  movingcenter_x MAV                                  float64
#  2982  movingcenter_y mean_ft                              float64
#  2983  movingcenter_y std_ft                               float64
#  2984  movingcenter_y max_ft                               float64
#  2985  movingcenter_y min_ft                               float64
#  2986  movingcenter_y var_ft                               float64
#  2987  movingcenter_y med_ft                               float64
#  2988  movingcenter_y sum_ft                               float64
#  2989  movingcenter_y std                                  float64
#  2990  movingcenter_y kurtosis                             float64
#  2991  movingcenter_y skew                                 float64
#  2992  movingcenter_y quantile 25                          float64
#  2993  movingcenter_y quantile 75                          float64
#  2994  movingcenter_y RMS                                  float64
#  2995  movingcenter_y MAV                                  float64
#  2996  previous_label                                      float64
#  2997  label                                               category
# dtypes: category(1), float64(2997)
# memory usage: 88.8 MB

# %%
sns.histplot(df["label"])
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='label', ylabel='Count'>

# %%
X=df.drop(["label","previous_label"],axis=1)
y=df['label']

# %%
X.shape
# Out:
# (3883, 2996)

# %%
y.shape
# Out:
# (3883,)

# %%
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='logloss', random_state=10)
# xgbcl.fit(X_train,y_train)
# # filename = './xgb_model.sav'
# # xgbcl=joblib.load(filename)
# pred=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.ensemble import RandomForestClassifier #Random Forest
# rf=RandomForestClassifier(random_state=10)
# rf.fit(X_train,y_train)
# pred=rf.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# import joblib
# filename = './xgb_model.sav'
# joblib.dump(xgbcl, filename)

# %%
# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(X_train,y_train)
# pred=svc.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
# knn = RadiusNeighborsClassifier(radius=175)
# knn.fit(X_train,y_train)
# pred=knn.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from sklearn.linear_model import SGDClassifier
## sgd=SGDClassifier()loss='epsilon_insensitive'
# sgd.fit(X_train,y_train)
# pred=sgd.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
from sklearn.feature_selection import SelectKBest,f_regression
# Applying SelectKBest class to extract top 15 best features
fs = SelectKBest(score_func=f_regression,k=15)
# Applying feature selection
fit = fs.fit(X,y)
features_score = pd.DataFrame(fit.scores_)
features = pd.DataFrame(X.columns)
feature_score = pd.concat([features,features_score],axis=1)
# Assigning column names
feature_score.columns = ["Input_Features","F_Score"]
print(feature_score.nlargest(300,columns="F_Score"))
# dfi.export(feature_score.nlargest(16,columns="F_Score"),'./image/fulltest/f_test.png')
# feature_score.nlargest(300,columns="F_Score")['Input_Features'].values
# Out:
#                                    Input_Features      F_Score
# 2888                    movingright_wrist_ var_ft  2635.057111
# 2902                     movingright_wrist var_ft  2612.171356
# 2552  movingright_wrist_right_shoulder  dx var_ft  2604.613651
# 2566   movingright_wristright_shoulder  dy var_ft  2601.776503
# 2895               movingright_wrist_ quantile 75  2532.937812
# ...                                           ...          ...
# 2309            movingnose_right_shoulder  dx MAV  1276.220435
# 2302         movingnose_right_shoulder  dx sum_ft  1276.220435
# 2732                        movingleft_ear max_ft  1272.738727
# 2396      movingleft_earright_shoulder  dy max_ft  1270.501275
# 2270                movingright_shoulder_y max_ft  1267.685383
#
# [300 rows x 2 columns]

# %%
X_train=X#[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_train=y
X_test=test.drop(["label","previous_label"],axis=1)
# X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
y_test=test['label']

# %%
testcol=test.columns
traincol=df.columns
a=[e for e in testcol if e not in traincol]
a
# Out:
# []

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier #Random Forest
# try:
# oversampling the train dataset using SMOTE

sm = SMOTE()
all_feature_smote, all_label_smote = sm.fit_resample(X_train,y_train)
# rf=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf.fit(all_feature_smote, all_label_smote)
# # filename = './model/smote_rf_model.sav'
# # rf=joblib.load(filename)
# pred_rf=rf.predict(X_test)

# print(metrics.classification_report(pred_rf,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './model/smote_rf_model2.sav'
# joblib.dump(rf, filename)

# %%
from xgboost import XGBClassifier#XGBcalssifier
from xgboost import callback
early_stop = callback.EarlyStopping(
    rounds=4, metric_name='mlogloss', save_best=True
)
try:
    filename = '.smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
except:
    xgbcl=XGBClassifier( eval_metric='mlogloss', random_state=10,callbacks=[early_stop])
    xgbcl.fit(all_feature_smote, all_label_smote,eval_set=[(X_test, y_test)])

pred_xgb=xgbcl.predict(X_test)
from sklearn import metrics #accuracy measure
print(metrics.classification_report(pred_xgb,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred_xgb,y_test, normalize='true')
sns.heatmap(conf,annot=True)
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 13
#      10     xgbcl=XGBClassifier( eval_metric='mlogloss', random_state=10,callbacks=[early_stop])
#      11     xgbcl.fit(all_feature_smote, all_label_smote,eval_set=[(X_test, y_test)])
# ---> 13 pred_xgb=xgbcl.predict(X_test)
#      14 from sklearn import metrics #accuracy measure
#      15 print(metrics.classification_report(pred_xgb,y_test))
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1525, in XGBClassifier.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1515 def predict(
#    1516     self,
#    1517     X: ArrayLike,
#    (...)
#    1522     iteration_range: Optional[Tuple[int, int]] = None,
#    1523 ) -> np.ndarray:
#    1524     with config_context(verbosity=self.verbosity):
# -> 1525         class_probs = super().predict(
#    1526             X=X,
#    1527             output_margin=output_margin,
#    1528             ntree_limit=ntree_limit,
#    1529             validate_features=validate_features,
#    1530             base_margin=base_margin,
#    1531             iteration_range=iteration_range,
#    1532         )
#    1533         if output_margin:
#    1534             # If output_margin is active, simply return the scores
#    1535             return class_probs
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1114, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1112 if self._can_use_inplace_predict():
#    1113     try:
# -> 1114         predts = self.get_booster().inplace_predict(
#    1115             data=X,
#    1116             iteration_range=iteration_range,
#    1117             predict_type="margin" if output_margin else "value",
#    1118             missing=self.missing,
#    1119             base_margin=base_margin,
#    1120             validate_features=validate_features,
#    1121         )
#    1122         if _is_cupy_array(predts):
#    1123             import cupy  # pylint: disable=import-error
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:2286, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2284     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2285     if validate_features:
# -> 2286         self._validate_features(fns)
#    2288 if isinstance(data, np.ndarray):
#    2289     from .data import _ensure_np_dtype
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:2782, in Booster._validate_features(self, feature_names)
#    2776 if my_missing:
#    2777     msg += (
#    2778         "\ntraining data did not have the following fields: "
#    2779         + ", ".join(str(s) for s in my_missing)
#    2780     )
# -> 2782 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['left_elbow_shoulder_hip mean_ft', 'left_elbow_shoulder_hip std_ft', 'left_elbow_shoulder_hip max_ft', 'left_elbow_shoulder_hip min_ft', 'left_elbow_shoulder_hip var_ft', 'left_elbow_shoulder_hip med_ft', 'left_elbow_shoulder_hip sum_ft', 'left_elbow_shoulder_hip std', 'left_elbow_shoulder_hip kurtosis', 'left_elbow_shoulder_hip skew', 'left_elbow_shoulder_hip quantile 25', 'left_elbow_shoulder_hip quantile 75', 'left_elbow_shoulder_hip RMS', 'left_elbow_shoulder_hip MAV', 'right_elbow_shoulder_hip mean_ft', 'right_elbow_shoulder_hip std_ft', 'right_elbow_shoulder_hip max_ft', 'right_elbow_shoulder_hip min_ft', 'right_elbow_shoulder_hip var_ft', 'right_elbow_shoulder_hip med_ft', 'right_elbow_shoulder_hip sum_ft', 'right_elbow_shoulder_hip std', 'right_elbow_shoulder_hip kurtosis', 'right_elbow_shoulder_hip skew', 'right_elbow_shoulder_hip quantile 25', 'right_elbow_shoulder_hip quantile 75', 'right_elbow_shoulder_hip RMS', 'right_elbow_shoulder_hip MAV', 'left_wrist_elbow_shoulder mean_ft', 'left_wrist_elbow_shoulder std_ft', 'left_wrist_elbow_shoulder max_ft', 'left_wrist_elbow_shoulder min_ft', 'left_wrist_elbow_shoulder var_ft', 'left_wrist_elbow_shoulder med_ft', 'left_wrist_elbow_shoulder sum_ft', 'left_wrist_elbow_shoulder std', 'left_wrist_elbow_shoulder kurtosis', 'left_wrist_elbow_shoulder skew', 'left_wrist_elbow_shoulder quantile 25', 'left_wrist_elbow_shoulder quantile 75', 'left_wrist_elbow_shoulder RMS', 'left_wrist_elbow_shoulder MAV', 'right_wrist_elbow_shoulder mean_ft', 'right_wrist_elbow_shoulder std_ft', 'right_wrist_elbow_shoulder max_ft', 'right_wrist_elbow_shoulder min_ft', 'right_wrist_elbow_shoulder var_ft', 'right_wrist_elbow_shoulder med_ft', 'right_wrist_elbow_shoulder sum_ft', 'right_wrist_elbow_shoulder std', 'right_wrist_elbow_shoulder kurtosis', 'right_wrist_elbow_shoulder skew', 'right_wrist_elbow_shoulder quantile 25', 'right_wrist_elbow_shoulder quantile 75', 'right_wrist_elbow_shoulder RMS', 'right_wrist_elbow_shoulder MAV', ' right_elbow_shoulder mean_ft', ' right_elbow_shoulder std_ft', ' right_elbow_shoulder max_ft', ' right_elbow_shoulder min_ft', ' right_elbow_shoulder var_ft', ' right_elbow_shoulder med_ft', ' right_elbow_shoulder sum_ft', ' right_elbow_shoulder std', ' right_elbow_shoulder kurtosis', ' right_elbow_shoulder skew', ' right_elbow_shoulder quantile 25', ' right_elbow_shoulder quantile 75', ' right_elbow_shoulder RMS', ' right_elbow_shoulder MAV', 'left_elbow_shoulder mean_ft', 'left_elbow_shoulder std_ft', 'left_elbow_shoulder max_ft', 'left_elbow_shoulder min_ft', 'left_elbow_shoulder var_ft', 'left_elbow_shoulder med_ft', 'left_elbow_shoulder sum_ft', 'left_elbow_shoulder std', 'left_elbow_shoulder kurtosis', 'left_elbow_shoulder skew', 'left_elbow_shoulder quantile 25', 'left_elbow_shoulder quantile 75', 'left_elbow_shoulder RMS', 'left_elbow_shoulder MAV', 'nose_right_shoulder  dx mean_ft', 'nose_right_shoulder  dx std_ft', 'nose_right_shoulder  dx max_ft', 'nose_right_shoulder  dx min_ft', 'nose_right_shoulder  dx var_ft', 'nose_right_shoulder  dx med_ft', 'nose_right_shoulder  dx sum_ft', 'nose_right_shoulder  dx std', 'nose_right_shoulder  dx kurtosis', 'nose_right_shoulder  dx skew', 'nose_right_shoulder  dx quantile 25', 'nose_right_shoulder  dx quantile 75', 'nose_right_shoulder  dx RMS', 'nose_right_shoulder  dx MAV', 'noseright_shoulder  dy mean_ft', 'noseright_shoulder  dy std_ft', 'noseright_shoulder  dy max_ft', 'noseright_shoulder  dy min_ft', 'noseright_shoulder  dy var_ft', 'noseright_shoulder  dy med_ft', 'noseright_shoulder  dy sum_ft', 'noseright_shoulder  dy std', 'noseright_shoulder  dy kurtosis', 'noseright_shoulder  dy skew', 'noseright_shoulder  dy quantile 25', 'noseright_shoulder  dy quantile 75', 'noseright_shoulder  dy RMS', 'noseright_shoulder  dy MAV', 'left_eye_right_shoulder  dx mean_ft', 'left_eye_right_shoulder  dx std_ft', 'left_eye_right_shoulder  dx max_ft', 'left_eye_right_shoulder  dx min_ft',  ...

# %%
# X_train_with_predictions.shape

# %%
# X_train_with_predictions=df.drop(["label"],axis=1)
# y_train_with_predictions=df['label']
# X_test["previous_label"]=pred_xgb
# all_feature_smote_with_predictions, all_label_smote_with_predictions = sm.fit_resample(X_train_with_predictions,y_train_with_predictions)
# from xgboost import XGBClassifier#XGBcalssifier
# xgbcl=XGBClassifier( eval_metric='aucs‌', random_state=10)
# xgbcl.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_xgb_with_predictions=xgbcl.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_xgb_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_xgb_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# rf_with_predictions=RandomForestClassifier(random_state=10,n_estimators=3000,criterion='log_loss')
# rf_with_predictions.fit(all_feature_smote_with_predictions, all_label_smote_with_predictions)
# # filename = './smote_xgb_model_acc.sav'
# # xgbcl=joblib.load(filename)
# pred_rf_with_predictions=rf_with_predictions.predict(X_test)
# from sklearn import metrics #accuracy measure
# print(metrics.classification_report(pred_rf_with_predictions,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred_rf_with_predictions,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
filename = '.smote_xgb_model2.sav'
joblib.dump(xgbcl, filename)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
HGBC=HistGradientBoostingClassifier(random_state=10)
# HGBC.fit(X_train,y_train)
try:
    filename = '.smote_HGBC_model2.sav'
    HGBC=joblib.load(filename)
except:
    HGBC.fit(all_feature_smote, all_label_smote )

pred=HGBC.predict(X_test)

print(metrics.classification_report(pred,y_test))
ax,fig=plt.subplots(figsize=(10,10))
conf=metrics.confusion_matrix(pred,y_test, normalize='true')
sns.heatmap(conf,annot=True)

# %%
filename = '.smote_HGBC_model2.sav'
joblib.dump(HGBC, filename)

# %%
def predict0_4(df):
#     print(df['label_pred'])
#     print(df['label_pred'] in [1,2,3,5,6,7,8])
    if df['previous_label'] in [1,2,3,5,6,7,8]:
        return df['previous_label']
    else:
#         print(np.array(df.drop(["label","previous_label",'label_pred'])))
# xgb_class0_4
        return xgbcl.predict(np.array(df.drop(["label",'previous_label'
                                    ])).reshape(1,-1)).view().item()

# %%
# from sklearn.ensemble import AdaBoostClassifier
# test['previous_label']=pred_xgb
# # test['previous_label']=list(pred_xgb).insert(0,0)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label",'previous_label'],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4=np.array(X_train_class0_4)
# y_train_class0_4=np.array(y_train_class0_4)
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# xgb_class0_4=RandomForestClassifier(random_state=10,n_estimators=30,criterion='gini')#XGBClassifier( eval_metric='logloss', random_state=10)
# try:
#     print('sm')
# #     xgb_class0_4.fit(X_train_class0_4sm, y_train_class0_4sm)
# except:
#     print('no sm')
# #     xgb_class0_4.fit(X_train_class0_4, y_train_class0_4)
# test['label_pred']=test.apply(lambda x:predict0_4(x),axis=1)

# # test_class0_4=test[(test['label_pred'].isin([0,4]))&(test['label'].isin([0,4]))]
# # X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# # y_test_class0_4=test_class0_4.label
# # # X_test_class0_4=np.array(X_test_class0_4)
# # # y_test_class0_4=np.array(y_test_class0_4)

# # pred_class0_4=xgb_class0_4.predict(X_test_class0_4)
# print(metrics.classification_report(test['label'],test['label_pred']))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(test['label'],test['label_pred'], normalize='true')
# sns.heatmap(conf,annot=True)

# %%
test

# %%
# int([1])

# %%
# from sklearn.ensemble import AdaBoostClassifier
# ada=AdaBoostClassifier(random_state=10)
# ada.fit(X_train,y_train)
# pred=ada.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# from catboost import CatBoostClassifier
# # catboost=CatBoostClassifier()
# # catboost.fit(X_train,y_train)
# filename = './catboost_model.sav'
# catboost=joblib.load(filename)
# pred=catboost.predict(X_test)

# print(metrics.classification_report(pred,y_test))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,y_test, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# filename = './catboost_model.sav'
# joblib.dump(catboost, filename)

# %%
# from keras.layers import TimeDistributed
# # # trainX=np.array(X_train)
# # testX=np.array(X_test)
# # # trainY=np.array(y_train)
# # testY=np.array(y_test)
# # trainX=np.array(all_feature_smote)
# # trainY=np.array(all_label_smote)
# df_class0_4=df[df['label'].isin([0,4])]
# X_train_class0_4=df_class0_4.drop(["label","previous_label"],axis=1)
# y_train_class0_4=df_class0_4.label
# X_train_class0_4sm,y_train_class0_4sm = sm.fit_resample(X_train_class0_4,y_train_class0_4)
# trainX=np.array(X_train_class0_4sm)
# trainY=np.array(y_train_class0_4sm)

# test_class0_4=test[test['label'].isin([0,4])]
# X_test_class0_4=test_class0_4.drop(["label","previous_label",'label_pred'],axis=1)
# y_test_class0_4=test_class0_4.label
# testX=np.array(X_test_class0_4)
# testY=np.array(y_test_class0_4)

# # # testY = tf.keras.utils.to_categorical(testY)
# # # trainY = tf.keras.utils.to_categorical(trainY)
# # trainX = np.expand_dims(trainX, 2)
# # testX = np.expand_dims(testX, 2)

# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# from tensorflow.keras import models
# model = models.Sequential()
# model.add(layers.Input(shape=(len(trainX[1]), 1)))
# model.add(layers.Conv1D(64,64, activation='relu'))
# # model.add(LSTM(units=3, return_sequences=True))
# # model.add(LSTM(units=64, return_sequences=True))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Conv1D(32, 32, activation='relu'))
# model.add(layers.MaxPooling1D(4))
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Conv1D(16, 16, activation='relu'))
# model.add(LSTM(units=64, return_sequences=True))
# # model.add(LSTM(units=32, return_sequences=True))
# model.add(LSTM(units=16, return_sequences=True))
# model.add(Dropout(0.5))

# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(32, activation='relu'))
# model.add(layers.Dense(9,activation='softmax'))
# mcp_save = ModelCheckpoint('DL_model.hdf5', save_best_only=True, monitor='val_loss', mode='min')
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# history = model.fit(trainX,trainY, epochs=100, 
#                     validation_data=(testX,testY), 
#                     callbacks=[early_stopping,mcp_save])

# %%
# plt.clf()
# plt.plot(history.history['loss'], label='loss')
# plt.plot(history.history['val_loss'], label = 'val_loss')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')

# plt.legend(loc='lower right')

# %%
# pred=model.predict(testX)
# pred=np.argmax(pred,axis=1)
# print(metrics.classification_report(pred,testY))
# ax,fig=plt.subplots(figsize=(10,10))
# conf=metrics.confusion_matrix(pred,testY, normalize='true')
# sns.heatmap(conf,annot=True)

# %%
# model_rnn = Sequential()
# model_rnn.add(LSTM(units=64, return_sequences=True, input_shape=(len(trainX[1]), 1)))
# model_rnn.add(Conv1D(128, 6))
# model_rnn.add(LSTM(units = 64, return_sequences = True))
# model_rnn.add(Dropout(0.2))
# model_rnn.add(Conv1D(128, 3))
# model_rnn.add(LSTM(units = 64, return_sequences = True))

# model_rnn.add(Dropout(0.2))
# model_rnn.add(LSTM(units = 64))

# model_rnn.add(Dense(units = 128))
# model_rnn.add(Dense(units = 64))

# model_rnn.add(Dense(units = 9, activation="softmax")) #4 as the output classes

# # Define the BRNN model with LSTM layers
# model_brnn = keras.Sequential([
#     layers.Bidirectional(layers.LSTM(64, activation='relu', return_sequences=True), 
#                          input_shape=(len(trainX[1]), 1)),
# #     layers.Bidirectional(layers.LSTM(64, activation='relu')),
# #     layers.Bidirectional(layers.LSTM(32, activation='relu')),
#     layers.Bidirectional(layers.LSTM(16, activation='relu')),
    
#     layers.Dense(9, activation='softmax')
# ])

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# # Compile the RNN model
# model_rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Compile the BRNN model
# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Define early stopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Train the RNN model with early stopping

# ## model_rnn.fit(all_feature, all_label, epochs=100, batch_size=500, validation_data=(X_vad, y_vad), callbacks=[early_stopping])

# # Train the BRNN model with early stopping

# model_brnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# # history_brnn=model_brnn.fit(trainX,trainY, epochs=10, batch_size=500,
# #                             validation_data=(testX,testY), callbacks=[early_stopping])
# # , callbacks=[early_stopping]

# %%
# history_rnn=model_rnn.fit(trainX,trainY, epochs=20,
#                             validation_data=(testX,testY), callbacks=[early_stopping])

# %%
len(all_label_smote)

# %%
def output_xgb(ID,out):
    warnings.simplefilter('ignore')
    test=pd.read_csv(f'./test_set_df_acc_win3/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = '.smote_xgb_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(pred,y_test,average='weighted')
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(pred,y_test, normalize='true',labels=[i for i in range(9)])
    sns.heatmap(conf,annot=True)
#     print(ID)
#     print(np.unique(pred))
#     print(np.unique(y_test))
#     plt.savefig(f"./image/xgb_gan_win3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s])

# %%
test_set=os.listdir('./test_set_df_acc_win3')
out_xgb=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_xgb(ID,out_xgb)
out_df_xgb=pd.DataFrame(out_xgb,columns=['ID','accuracy','weighted avg F1-score'])
out_df_xgb

# %%
test_set=os.listdir('./test_set_df')
test_set

# %%
def output_rf(ID,out):
    test=pd.read_csv(f'./test_set_df_acc_win3/{ID}')
    X_test=test.drop(["label","previous_label"],axis=1)
#     X_test=X_test[feature_score.nlargest(300,columns="F_Score")['Input_Features'].values]
    y_test=test['label']
    filename = '.smote_HGBC_model2.sav'
    xgbcl=joblib.load(filename)
    # xgbcl=joblib.load(filename)
    pred=xgbcl.predict(X_test)
    acc= metrics.accuracy_score(pred,y_test)
    f1s=metrics.f1_score(pred,y_test,average='weighted')
    ax,fig=plt.subplots(figsize=(10,10))
    conf=metrics.confusion_matrix(pred,y_test,labels=[i for i in range(9)]
                                  , normalize='true')
    sns.heatmap(conf,annot=True)
#     plt.savefig(f"./image/rf_gan_win3/confusion_matrix_{ID[:5]}.png")
    return out.append([ID[:5],acc,f1s])

# %%
test_set=os.listdir('./test_set_df_acc_win3')
out_rf=[]
for ID in test_set:
    if ID.endswith(".csv"):
        output_rf(ID,out_rf)
out_df=pd.DataFrame(out_rf,columns=['ID','accuracy','weighted avg F1-score'])
out_df.describe()

# %%
out_df.describe()#HGBC not rf model :(

# %%
out_df_xgb.describe()
